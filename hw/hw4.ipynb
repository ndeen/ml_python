# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
heart_raw = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/00519/heart_failure_clinical_records_dataset.csv")
heart_df = heart_raw.copy()[["creatinine_phosphokinase","serum_creatinine", "serum_sodium","platelets", "DEATH_EVENT"]]
heart_df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
df_0 = heart_df[heart_df["DEATH_EVENT"]==0]
df_0.head()
# Out:
#     creatinine_phosphokinase  serum_creatinine  serum_sodium  platelets  \
# 14                        80               1.0           138   427000.0
# 20                        52               1.3           137   276000.0
# 23                        63               0.8           135   368000.0
# 33                       159               1.2           138   302000.0
# 38                      2656               2.3           137   305000.0
#
#     DEATH_EVENT
# 14            0
# 20            0
# 23            0
# 33            0
# 38            0

# %%
df_1 = heart_df[heart_df["DEATH_EVENT"]==1]
df_1.head()
# Out:
#    creatinine_phosphokinase  serum_creatinine  serum_sodium  platelets  \
# 0                       582               1.9           130  265000.00
# 1                      7861               1.1           136  263358.03
# 2                       146               1.3           129  162000.00
# 3                       111               1.9           137  210000.00
# 4                       160               2.7           116  327000.00
#
#    DEATH_EVENT
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
corr = df_1.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d85b9_row0_col0, #T_d85b9_row1_col1, #T_d85b9_row2_col2, #T_d85b9_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d85b9_row0_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_d85b9_row0_col2 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_d85b9_row0_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_d85b9_row0_col4, #T_d85b9_row1_col4, #T_d85b9_row2_col4, #T_d85b9_row3_col4, #T_d85b9_row4_col0, #T_d85b9_row4_col1, #T_d85b9_row4_col2, #T_d85b9_row4_col3, #T_d85b9_row4_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_d85b9_row1_col0, #T_d85b9_row1_col2, #T_d85b9_row1_col3, #T_d85b9_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d85b9_row2_col0 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_d85b9_row2_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_d85b9_row3_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_d85b9_row3_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_d85b9_row3_col2 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d85b9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >creatinine_phosphokinase</th>
#       <th class="col_heading level0 col1" >serum_creatinine</th>
#       <th class="col_heading level0 col2" >serum_sodium</th>
#       <th class="col_heading level0 col3" >platelets</th>
#       <th class="col_heading level0 col4" >DEATH_EVENT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d85b9_level0_row0" class="row_heading level0 row0" >creatinine_phosphokinase</th>
#       <td id="T_d85b9_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d85b9_row0_col1" class="data row0 col1" >-0.033407</td>
#       <td id="T_d85b9_row0_col2" class="data row0 col2" >0.148823</td>
#       <td id="T_d85b9_row0_col3" class="data row0 col3" >0.078808</td>
#       <td id="T_d85b9_row0_col4" class="data row0 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d85b9_level0_row1" class="row_heading level0 row1" >serum_creatinine</th>
#       <td id="T_d85b9_row1_col0" class="data row1 col0" >-0.033407</td>
#       <td id="T_d85b9_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d85b9_row1_col2" class="data row1 col2" >-0.094011</td>
#       <td id="T_d85b9_row1_col3" class="data row1 col3" >-0.029384</td>
#       <td id="T_d85b9_row1_col4" class="data row1 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d85b9_level0_row2" class="row_heading level0 row2" >serum_sodium</th>
#       <td id="T_d85b9_row2_col0" class="data row2 col0" >0.148823</td>
#       <td id="T_d85b9_row2_col1" class="data row2 col1" >-0.094011</td>
#       <td id="T_d85b9_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_d85b9_row2_col3" class="data row2 col3" >0.141284</td>
#       <td id="T_d85b9_row2_col4" class="data row2 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d85b9_level0_row3" class="row_heading level0 row3" >platelets</th>
#       <td id="T_d85b9_row3_col0" class="data row3 col0" >0.078808</td>
#       <td id="T_d85b9_row3_col1" class="data row3 col1" >-0.029384</td>
#       <td id="T_d85b9_row3_col2" class="data row3 col2" >0.141284</td>
#       <td id="T_d85b9_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_d85b9_row3_col4" class="data row3 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d85b9_level0_row4" class="row_heading level0 row4" >DEATH_EVENT</th>
#       <td id="T_d85b9_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_d85b9_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_d85b9_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_d85b9_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_d85b9_row4_col4" class="data row4 col4" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
heart_df.corr()
# Out:
#                           creatinine_phosphokinase  serum_creatinine  \
# creatinine_phosphokinase                  1.000000         -0.016408
# serum_creatinine                         -0.016408          1.000000
# serum_sodium                              0.059550         -0.189095
# platelets                                 0.024463         -0.041198
# DEATH_EVENT                               0.062728          0.294278
#
#                           serum_sodium  platelets  DEATH_EVENT
# creatinine_phosphokinase      0.059550   0.024463     0.062728
# serum_creatinine             -0.189095  -0.041198     0.294278
# serum_sodium                  1.000000   0.062125    -0.195204
# platelets                     0.062125   1.000000    -0.049139
# DEATH_EVENT                  -0.195204  -0.049139     1.000000
