# %%
import os
import statistics as stats
import pandas as pd
from operator import itemgetter

# %%
input_dir = os.path.abspath('')
ticker = 'DIS'
ticker_file = os.path.join(input_dir, ticker + '.csv')

# %%
try:
    with open(ticker_file) as f:
        lines = f.read().splitlines()
    print('opened file for ticker: ', ticker)
    print(lines[0])
except Exception as e:
    print(e)
    print('failed to read stock data for ticker: ', ticker)
# Out:
# opened file for ticker:  DIS
# Date,Year,Month,Day,Weekday,Week_Number,Year_Week,Open,High,Low,Close,Volume,Adj Close,Return,Short_MA,Long_MA

# %%
# each line represents a row of data
# the first line represents the columns
cols = lines[0].split(',')

# %%
cols
# Out:
# ['Date',
#  'Year',
#  'Month',
#  'Day',
#  'Weekday',
#  'Week_Number',
#  'Year_Week',
#  'Open',
#  'High',
#  'Low',
#  'Close',
#  'Volume',
#  'Adj Close',
#  'Return',
#  'Short_MA',
#  'Long_MA']

# %%
date_l = []
year_l = []
weekday_l = []
ac_l = []

for row in lines[1:]:
    date = row.split(',')[0]
    date_l.append(date)
    
    year = row.split(',')[1]
    year_l.append(year)
    
    weekday = row.split(',')[4]
    weekday_l.append(weekday)
    
    ac = float(row.split(',')[12])
    ac_l.append(ac)

# %%
ac_l
# Out:
# [97.16,
#  95.19,
#  94.68,
#  93.87,
#  93.64,
#  94.27,
#  95.72,
#  92.91,
#  93.5,
#  88.59,
#  88.66,
#  87.31,
#  88.7,
#  91.42,
#  89.9,
#  90.83,
#  88.99,
#  88.24,
#  90.4,
#  89.77,
#  87.85,
#  89.76,
#  90.03,
#  88.59,
#  86.91,
#  87.1,
#  83.82,
#  85.2,
#  85.99,
#  87.66,
#  90.1,
#  89.79,
#  89.64,
#  90.92,
#  89.99,
#  90.03,
#  90.24,
#  89.92,
#  90.12,
#  92.13,
#  91.51,
#  93.23,
#  92.91,
#  93.77,
#  92.29,
#  92.14,
#  91.55,
#  92.4,
#  93.22,
#  92.68,
#  92.87,
#  93.97,
#  93.59,
#  92.89,
#  92.06,
#  91.35,
#  91.72,
#  92.54,
#  92.61,
#  93.32,
#  93.69,
#  93.47,
#  93.1,
#  91.51,
#  91.97,
#  90.72,
#  90.97,
#  90.83,
#  91.84,
#  93.85,
#  93.05,
#  93.01,
#  95.74,
#  96.84,
#  97.43,
#  97.09,
#  97.9,
#  98.66,
#  98.96,
#  99.33,
#  98.15,
#  97.42,
#  98.46,
#  97.91,
#  97.81,
#  99.0,
#  99.57,
#  99.38,
#  100.57,
#  96.5,
#  95.96,
#  94.83,
#  94.68,
#  94.29,
#  93.4,
#  92.84,
#  94.14,
#  93.57,
#  93.88,
#  94.21,
#  94.17,
#  94.62,
#  93.61,
#  92.95,
#  93.14,
#  93.17,
#  93.19,
#  92.79,
#  92.5,
#  92.31,
#  91.83,
#  92.05,
#  92.83,
#  92.71,
#  92.82,
#  93.4,
#  93.94,
#  93.23,
#  93.2,
#  93.42,
#  90.31,
#  89.04,
#  90.62,
#  91.5,
#  92.29,
#  92.49,
#  92.14,
#  92.88,
#  93.52,
#  94.67,
#  95.01,
#  95.22,
#  94.92,
#  95.0,
#  94.84,
#  95.17,
#  94.53,
#  93.34,
#  93.14,
#  92.85,
#  92.55,
#  91.88,
#  91.54,
#  91.14,
#  91.18,
#  90.79,
#  90.29,
#  91.31,
#  90.43,
#  91.07,
#  90.99,
#  91.87,
#  93.0,
#  92.91,
#  92.03,
#  92.27,
#  92.06,
#  92.06,
#  91.85,
#  91.6,
#  91.1,
#  91.2,
#  91.06,
#  90.8,
#  90.48,
#  90.15,
#  90.15,
#  89.77,
#  89.57,
#  89.73,
#  89.14,
#  89.05,
#  89.41,
#  87.83,
#  88.99,
#  88.09,
#  87.67,
#  87.9,
#  87.96,
#  88.03,
#  88.33,
#  87.8,
#  88.77,
#  88.63,
#  87.39,
#  87.16,
#  87.62,
#  87.24,
#  88.24,
#  87.89,
#  87.99,
#  87.85,
#  88.22,
#  87.89,
#  87.89,
#  87.29,
#  86.87,
#  86.59,
#  86.76,
#  86.32,
#  86.64,
#  87.36,
#  87.46,
#  88.41,
#  88.73,
#  88.14,
#  88.84,
#  89.35,
#  89.19,
#  88.08,
#  87.8,
#  87.34,
#  88.73,
#  87.85,
#  89.74,
#  89.69,
#  89.94,
#  90.24,
#  92.82,
#  93.05,
#  92.84,
#  94.19,
#  94.43,
#  93.36,
#  92.78,
#  92.85,
#  93.38,
#  93.91,
#  94.05,
#  94.72,
#  94.19,
#  94.02,
#  93.6,
#  94.99,
#  95.66,
#  96.92,
#  99.0,
#  100.42,
#  99.65,
#  99.45,
#  99.64,
#  99.97,
#  99.51,
#  100.84,
#  100.99,
#  101.09,
#  100.95,
#  100.69,
#  100.71,
#  99.88,
#  100.13,
#  99.8,
#  101.58,
#  102.89,
#  102.83,
#  104.36,
#  103.77,
#  103.79,
#  104.8,
#  102.97,
#  103.48,
#  103.39,
#  103.58,
#  102.73,
#  103.1,
#  102.58,
#  103.33,
#  103.46,
#  103.48,
#  104.67,
#  106.24,
#  105.96,
#  106.58,
#  105.92,
#  105.63,
#  104.93,
#  104.38,
#  104.38,
#  104.85,
#  104.63,
#  105.0,
#  105.65,
#  105.51,
#  106.02,
#  105.4,
#  105.35,
#  105.45,
#  105.08,
#  105.64,
#  105.56,
#  105.42,
#  106.33,
#  105.9,
#  106.53,
#  105.98,
#  106.16,
#  106.14,
#  106.32,
#  106.22,
#  106.79,
#  107.55,
#  107.13,
#  106.98,
#  107.02,
#  107.93,
#  107.01,
#  107.33,
#  107.48,
#  107.39,
#  107.62,
#  108.26,
#  107.76,
#  108.38,
#  108.58,
#  108.4,
#  108.25,
#  108.21,
#  108.26,
#  107.81,
#  107.67,
#  108.28,
#  108.25,
#  108.4,
#  108.96,
#  109.35,
#  108.91,
#  109.93,
#  109.59,
#  108.88,
#  110.3,
#  110.68,
#  110.93,
#  110.7,
#  109.87,
#  109.52,
#  106.89,
#  106.46,
#  107.24,
#  106.7,
#  107.32,
#  105.01,
#  104.94,
#  105.04,
#  104.51,
#  103.4,
#  101.8,
#  102.16,
#  102.96,
#  103.07,
#  102.48,
#  103.15,
#  102.72,
#  103.82,
#  103.75,
#  103.37,
#  103.62,
#  102.64,
#  102.01,
#  101.03,
#  101.43,
#  99.9,
#  101.14,
#  102.5,
#  102.04,
#  101.64,
#  101.49,
#  101.04,
#  100.9,
#  99.54,
#  100.36,
#  99.8,
#  99.94,
#  101.1,
#  100.94,
#  102.33,
#  101.23,
#  101.75,
#  102.91,
#  101.15,
#  99.71,
#  99.68,
#  99.94,
#  100.18,
#  100.7,
#  100.61,
#  101.38,
#  101.1,
#  102.02,
#  103.05,
#  103.57,
#  103.31,
#  103.23,
#  102.67,
#  103.17,
#  106.12,
#  106.08,
#  106.05,
#  106.71,
#  104.84,
#  105.27,
#  103.89,
#  102.6,
#  103.21,
#  99.2,
#  97.78,
#  98.39,
#  97.83,
#  97.93,
#  98.6,
#  97.81,
#  97.15,
#  97.6,
#  99.15,
#  97.92,
#  97.94,
#  98.8,
#  98.94,
#  98.95,
#  99.24,
#  97.63,
#  97.92,
#  98.02,
#  97.92,
#  93.64,
#  93.65,
#  93.67,
#  94.44,
#  95.34,
#  94.45,
#  95.05,
#  94.64,
#  94.96,
#  95.71,
#  95.4,
#  95.12,
#  96.06,
#  95.15,
#  95.74,
#  94.59,
#  95.09,
#  96.34,
#  97.24,
#  97.01,
#  96.58,
#  96.54,
#  96.06,
#  96.07,
#  95.08,
#  93.51,
#  93.95,
#  94.67,
#  94.89,
#  94.79,
#  95.52,
#  95.9,
#  95.22,
#  94.82,
#  94.35,
#  95.09,
#  94.84,
#  94.58,
#  94.36,
#  95.54,
#  94.88,
#  95.16,
#  97.09,
#  98.03,
#  97.61,
#  99.06,
#  101.09,
#  101.05,
#  99.53,
#  100.03,
#  99.95,
#  99.79,
#  99.13,
#  99.37,
#  99.12,
#  99.02,
#  99.17,
#  99.76,
#  101.53,
#  101.12,
#  101.54,
#  106.33,
#  103.44,
#  101.74,
#  101.55,
#  101.36,
#  103.89,
#  104.48,
#  104.65,
#  107.53,
#  108.21,
#  107.98,
#  108.74,
#  106.67,
#  106.56,
#  105.68,
#  105.15,
#  104.68,
#  104.81,
#  104.55,
#  108.73,
#  109.19,
#  109.14,
#  108.55,
#  106.99,
#  106.92,
#  106.46,
#  107.94,
#  109.38,
#  107.65,
#  108.89,
#  107.38,
#  107.55,
#  108.05,
#  107.37,
#  107.46,
#  107.51,
#  109.11,
#  108.47,
#  107.08,
#  105.68,
#  107.45,
#  105.71,
#  101.82,
#  103.25,
#  101.88,
#  98.56,
#  100.26,
#  100.55,
#  101.26,
#  101.72,
#  102.29,
#  103.6,
#  103.07,
#  102.16,
#  102.35,
#  104.3,
#  106.79,
#  101.99,
#  100.32,
#  99.75,
#  100.16,
#  100.57,
#  102.05,
#  100.74,
#  101.17,
#  101.85,
#  102.28,
#  100.88,
#  101.04,
#  100.4,
#  100.04,
#  98.69,
#  98.56,
#  99.02,
#  97.83,
#  95.83,
#  97.88,
#  96.63,
#  95.83,
#  97.68,
#  95.95,
#  96.69,
#  98.17,
#  99.3,
#  97.59,
#  96.96,
#  98.58,
#  98.03,
#  97.63,
#  97.59,
#  97.48,
#  99.36,
#  98.43,
#  98.12,
#  97.48,
#  97.4,
#  96.73,
#  98.37,
#  97.09,
#  96.5,
#  97.57,
#  97.31,
#  96.88,
#  96.04,
#  98.37,
#  99.66,
#  98.99,
#  97.22,
#  98.88,
#  99.26,
#  99.62,
#  100.09,
#  102.15,
#  101.47,
#  101.07,
#  101.2,
#  101.21,
#  100.06,
#  99.3,
#  99.39,
#  96.95,
#  97.23,
#  96.74,
#  96.63,
#  97.48,
#  97.19,
#  99.11,
#  99.65,
#  101.12,
#  101.48,
#  101.46,
#  103.39,
#  105.76,
#  105.86,
#  104.12,
#  103.18,
#  104.2,
#  102.98,
#  103.42,
#  101.58,
#  101.39,
#  101.1,
#  101.89,
#  101.93,
#  102.43,
#  101.18,
#  102.44,
#  102.72,
#  103.93,
#  103.94,
#  105.91,
#  106.12,
#  107.84,
#  108.03,
#  108.13,
#  108.51,
#  109.92,
#  109.29,
#  108.9,
#  108.52,
#  108.99,
#  111.28,
#  110.4,
#  110.41,
#  111.33,
#  110.75,
#  110.53,
#  111.84,
#  113.66,
#  114.27,
#  111.74,
#  111.91,
#  110.46,
#  109.91,
#  110.53,
#  110.63,
#  110.27,
#  110.27,
#  109.79,
#  110.18,
#  109.74,
#  109.8,
#  109.73,
#  110.12,
#  110.36,
#  110.24,
#  109.72,
#  109.82,
#  108.67,
#  107.71,
#  108.09,
#  108.79,
#  108.5,
#  107.44,
#  107.31,
#  108.49,
#  107.11,
#  107.21,
#  107.37,
#  107.63,
#  109.42,
#  108.23,
#  110.55,
#  111.39,
#  112.94,
#  113.76,
#  114.64,
#  113.95,
#  115.34,
#  114.61,
#  113.84,
#  112.52,
#  113.74,
#  114.59,
#  110.64,
#  108.96,
#  110.39,
#  111.21,
#  113.9,
#  114.83,
#  113.89,
#  116.56,
#  115.94,
#  115.53,
#  109.41,
#  111.91,
#  110.96,
#  110.82,
#  112.5,
#  112.57,
#  113.82,
#  112.91,
#  113.18,
#  114.41,
#  114.75,
#  113.72,
#  115.68,
#  114.4,
#  114.55,
#  114.82,
#  114.81,
#  113.9,
#  113.15,
#  109.67,
#  110.81,
#  109.87,
#  110.34,
#  111.66,
#  113.82,
#  114.32,
#  113.22,
#  113.46,
#  110.65,
#  112.08,
#  110.63,
#  110.51,
#  110.62,
#  110.86,
#  112.02,
#  110.85,
#  109.28,
#  108.13,
#  107.9,
#  105.71,
#  102.96,
#  99.14,
#  104.55,
#  105.23,
#  106.0,
#  108.33,
#  107.65,
#  105.05,
#  108.29,
#  109.23,
#  110.07,
#  111.31,
#  111.44,
#  111.29,
#  111.06,
#  110.41,
#  109.57,
#  109.67,
#  109.7,
#  109.26,
#  109.78,
#  109.22,
#  109.75,
#  109.47,
#  109.56,
#  108.8,
#  110.17,
#  109.96,
#  110.45,
#  111.3,
#  110.06,
#  109.61,
#  110.16,
#  108.12,
#  107.88,
#  108.87,
#  109.32,
#  111.23,
#  112.14,
#  112.31,
#  112.91,
#  113.86,
#  112.22,
#  112.13,
#  111.42,
#  111.48,
#  112.63,
#  112.95,
#  112.62,
#  113.46,
#  112.63,
#  112.44,
#  113.36,
#  113.34,
#  112.71,
#  113.1,
#  113.57,
#  111.75,
#  108.67,
#  108.66,
#  107.35,
#  106.92,
#  106.49,
#  108.81,
#  108.95,
#  109.37,
#  109.69,
#  111.15,
#  110.61,
#  111.16,
#  113.36,
#  113.61,
#  113.57,
#  115.45,
#  115.75,
#  115.19,
#  128.49,
#  130.45,
#  128.33,
#  130.16,
#  130.85,
#  130.09,
#  131.75,
#  133.47,
#  135.58,
#  138.23,
#  137.62,
#  135.32,
#  134.73,
#  132.52,
#  132.71,
#  133.37,
#  131.83,
#  133.36,
#  131.98,
#  132.42,
#  129.75,
#  131.59,
#  133.05,
#  133.86,
#  133.41,
#  132.29,
#  132.47,
#  132.23,
#  131.13,
#  131.19,
#  131.02,
#  129.98,
#  130.6,
#  130.45,
#  130.87,
#  133.19,
#  134.3,
#  135.55,
#  136.37,
#  135.42,
#  133.45,
#  134.08,
#  140.03,
#  139.94,
#  139.27,
#  137.56,
#  139.22,
#  140.31,
#  138.54,
#  137.54,
#  138.25,
#  138.7,
#  137.62,
#  137.95,
#  139.94,
#  140.81,
#  141.25,
#  141.6,
#  140.18,
#  140.77,
#  142.69,
#  142.71,
#  144.02,
#  144.2,
#  143.44,
#  141.72,
#  140.79,
#  139.02,
#  140.0,
#  140.42,
#  140.45,
#  142.36,
#  143.79,
#  145.52,
#  144.07,
#  142.16,
#  141.01,
#  140.87,
#  137.48,
#  141.03,
#  134.06,
#  137.07,
#  137.7,
#  134.94,
#  136.19,
#  132.06,
#  132.62,
#  134.39,
#  134.48,
#  134.33,
#  134.95,
#  135.27,
#  130.89,
#  133.81,
#  133.69,
#  135.74,
#  137.02,
#  136.44,
#  135.5,
#  137.07,
#  138.01,
#  138.72,
#  138.0,
#  134.98,
#  135.38,
#  136.68,
#  137.2,
#  134.99,
#  135.5,
#  135.99,
#  132.51,
#  131.48,
#  131.67,
#  131.18,
#  132.3,
#  130.49,
#  129.19,
#  129.54,
#  128.78,
#  128.37,
#  127.39,
#  129.49,
#  130.12,
#  127.7,
#  128.56,
#  128.57,
#  129.25,
#  128.93,
#  128.99,
#  130.08,
#  131.58,
#  130.11,
#  129.48,
#  131.61,
#  130.35,
#  129.48,
#  130.12,
#  129.75,
#  128.71,
#  128.83,
#  129.15,
#  131.96,
#  132.13,
#  130.67,
#  130.49,
#  132.17,
#  137.14,
#  135.93,
#  137.75,
#  147.83,
#  146.27,
#  143.81,
#  146.77,
#  147.5,
#  146.05,
#  146.03,
#  147.41,
#  148.8,
#  150.74,
#  150.58,
#  150.68,
#  149.72,
#  147.7,
#  147.4,
#  146.56,
#  146.78,
#  145.34,
#  145.23,
#  146.71,
#  146.88,
#  146.38,
#  148.46,
#  147.73,
#  146.26,
#  146.15,
#  146.88,
#  ...]

# %%
def daily_ret_pct_diff(l):
    '''
    calculates the daily return and pct diff between a value and its predecessor in a list.
    '''
    
    diff_l = [] # create an empty list to hold the results
    pct_diff_l = [] # create an empty list to hold the results
    i = 0 # identify starting point
    
    # loop through list
    for val in l[i:len(l)]: # iterater from the starting point to the last value in list
        print("current iteration:",i)
        
        if i == 0:
            diff = 0
            pct_diff = 0
        
        elif i == 1:
            diff = l[i] - l[0] # calculate diff b/w values
            pct_diff = diff / l[0] # calcuate the pct diff
        
        else:
            diff = l[i] - l[i-1] # calculate diff b/w values
            pct_diff = diff / l[i] # calculate the pct diff
        
        diff_l.append(diff)
        pct_diff_l.append(pct_diff) # append results to container
        i+=1 # increment from starting point
        
        print("diff:",diff)
        print("pct diff:", pct_diff)
        print("next iteration:",i)
        print("\n")
    return diff_l, pct_diff_l # return the results

# %%
diff_l, pct_diff_l = daily_ret_pct_diff(ac_l)
# Out:
# current iteration: 0
# diff: 0
# pct diff: 0
# next iteration: 1
#
#
# current iteration: 1
# diff: -1.97
# pct diff: -0.02
# next iteration: 2
#
#
# current iteration: 2
# diff: -0.51
# pct diff: -0.01
# next iteration: 3
#
#
# current iteration: 3
# diff: -0.81
# pct diff: -0.01
# next iteration: 4
#
#
# current iteration: 4
# diff: -0.23
# pct diff: -0.0
# next iteration: 5
#
#
# current iteration: 5
# diff: 0.63
# pct diff: 0.01
# next iteration: 6
#
#
# current iteration: 6
# diff: 1.45
# pct diff: 0.02
# next iteration: 7
#
#
# current iteration: 7
# diff: -2.81
# pct diff: -0.03
# next iteration: 8
#
#
# current iteration: 8
# diff: 0.59
# pct diff: 0.01
# next iteration: 9
#
#
# current iteration: 9
# diff: -4.91
# pct diff: -0.06
# next iteration: 10
#
#
# current iteration: 10
# diff: 0.07
# pct diff: 0.0
# next iteration: 11
#
#
# current iteration: 11
# diff: -1.35
# pct diff: -0.02
# next iteration: 12
#
#
# current iteration: 12
# diff: 1.39
# pct diff: 0.02
# next iteration: 13
#
#
# current iteration: 13
# diff: 2.72
# pct diff: 0.03
# next iteration: 14
#
#
# current iteration: 14
# diff: -1.52
# pct diff: -0.02
# next iteration: 15
#
#
# current iteration: 15
# diff: 0.93
# pct diff: 0.01
# next iteration: 16
#
#
# current iteration: 16
# diff: -1.84
# pct diff: -0.02
# next iteration: 17
#
#
# current iteration: 17
# diff: -0.75
# pct diff: -0.01
# next iteration: 18
#
#
# current iteration: 18
# diff: 2.16
# pct diff: 0.02
# next iteration: 19
#
#
# current iteration: 19
# diff: -0.63
# pct diff: -0.01
# next iteration: 20
#
#
# current iteration: 20
# diff: -1.92
# pct diff: -0.02
# next iteration: 21
#
#
# current iteration: 21
# diff: 1.91
# pct diff: 0.02
# next iteration: 22
#
#
# current iteration: 22
# diff: 0.27
# pct diff: 0.0
# next iteration: 23
#
#
# current iteration: 23
# diff: -1.44
# pct diff: -0.02
# next iteration: 24
#
#
# current iteration: 24
# diff: -1.68
# pct diff: -0.02
# next iteration: 25
#
#
# current iteration: 25
# diff: 0.19
# pct diff: 0.0
# next iteration: 26
#
#
# current iteration: 26
# diff: -3.28
# pct diff: -0.04
# next iteration: 27
#
#
# current iteration: 27
# diff: 1.38
# pct diff: 0.02
# next iteration: 28
#
#
# current iteration: 28
# diff: 0.79
# pct diff: 0.01
# next iteration: 29
#
#
# current iteration: 29
# diff: 1.67
# pct diff: 0.02
# next iteration: 30
#
#
# current iteration: 30
# diff: 2.44
# pct diff: 0.03
# next iteration: 31
#
#
# current iteration: 31
# diff: -0.31
# pct diff: -0.0
# next iteration: 32
#
#
# current iteration: 32
# diff: -0.15
# pct diff: -0.0
# next iteration: 33
#
#
# current iteration: 33
# diff: 1.28
# pct diff: 0.01
# next iteration: 34
#
#
# current iteration: 34
# diff: -0.93
# pct diff: -0.01
# next iteration: 35
#
#
# current iteration: 35
# diff: 0.04
# pct diff: 0.0
# next iteration: 36
#
#
# current iteration: 36
# diff: 0.21
# pct diff: 0.0
# next iteration: 37
#
#
# current iteration: 37
# diff: -0.32
# pct diff: -0.0
# next iteration: 38
#
#
# current iteration: 38
# diff: 0.2
# pct diff: 0.0
# next iteration: 39
#
#
# current iteration: 39
# diff: 2.01
# pct diff: 0.02
# next iteration: 40
#
#
# current iteration: 40
# diff: -0.62
# pct diff: -0.01
# next iteration: 41
#
#
# current iteration: 41
# diff: 1.72
# pct diff: 0.02
# next iteration: 42
#
#
# current iteration: 42
# diff: -0.32
# pct diff: -0.0
# next iteration: 43
#
#
# current iteration: 43
# diff: 0.86
# pct diff: 0.01
# next iteration: 44
#
#
# current iteration: 44
# diff: -1.48
# pct diff: -0.02
# next iteration: 45
#
#
# current iteration: 45
# diff: -0.15
# pct diff: -0.0
# next iteration: 46
#
#
# current iteration: 46
# diff: -0.59
# pct diff: -0.01
# next iteration: 47
#
#
# current iteration: 47
# diff: 0.85
# pct diff: 0.01
# next iteration: 48
#
#
# current iteration: 48
# diff: 0.82
# pct diff: 0.01
# next iteration: 49
#
#
# current iteration: 49
# diff: -0.54
# pct diff: -0.01
# next iteration: 50
#
#
# current iteration: 50
# diff: 0.19
# pct diff: 0.0
# next iteration: 51
#
#
# current iteration: 51
# diff: 1.1
# pct diff: 0.01
# next iteration: 52
#
#
# current iteration: 52
# diff: -0.38
# pct diff: -0.0
# next iteration: 53
#
#
# current iteration: 53
# diff: -0.7
# pct diff: -0.01
# next iteration: 54
#
#
# current iteration: 54
# diff: -0.83
# pct diff: -0.01
# next iteration: 55
#
#
# current iteration: 55
# diff: -0.71
# pct diff: -0.01
# next iteration: 56
#
#
# current iteration: 56
# diff: 0.37
# pct diff: 0.0
# next iteration: 57
#
#
# current iteration: 57
# diff: 0.82
# pct diff: 0.01
# next iteration: 58
#
#
# current iteration: 58
# diff: 0.07
# pct diff: 0.0
# next iteration: 59
#
#
# current iteration: 59
# diff: 0.71
# pct diff: 0.01
# next iteration: 60
#
#
# current iteration: 60
# diff: 0.37
# pct diff: 0.0
# next iteration: 61
#
#
# current iteration: 61
# diff: -0.22
# pct diff: -0.0
# next iteration: 62
#
#
# current iteration: 62
# diff: -0.37
# pct diff: -0.0
# next iteration: 63
#
#
# current iteration: 63
# diff: -1.59
# pct diff: -0.02
# next iteration: 64
#
#
# current iteration: 64
# diff: 0.46
# pct diff: 0.01
# next iteration: 65
#
#
# current iteration: 65
# diff: -1.25
# pct diff: -0.01
# next iteration: 66
#
#
# current iteration: 66
# diff: 0.25
# pct diff: 0.0
# next iteration: 67
#
#
# current iteration: 67
# diff: -0.14
# pct diff: -0.0
# next iteration: 68
#
#
# current iteration: 68
# diff: 1.01
# pct diff: 0.01
# next iteration: 69
#
#
# current iteration: 69
# diff: 2.01
# pct diff: 0.02
# next iteration: 70
#
#
# current iteration: 70
# diff: -0.8
# pct diff: -0.01
# next iteration: 71
#
#
# current iteration: 71
# diff: -0.04
# pct diff: -0.0
# next iteration: 72
#
#
# current iteration: 72
# diff: 2.73
# pct diff: 0.03
# next iteration: 73
#
#
# current iteration: 73
# diff: 1.1
# pct diff: 0.01
# next iteration: 74
#
#
# current iteration: 74
# diff: 0.59
# pct diff: 0.01
# next iteration: 75
#
#
# current iteration: 75
# diff: -0.34
# pct diff: -0.0
# next iteration: 76
#
#
# current iteration: 76
# diff: 0.81
# pct diff: 0.01
# next iteration: 77
#
#
# current iteration: 77
# diff: 0.76
# pct diff: 0.01
# next iteration: 78
#
#
# current iteration: 78
# diff: 0.3
# pct diff: 0.0
# next iteration: 79
#
#
# current iteration: 79
# diff: 0.37
# pct diff: 0.0
# next iteration: 80
#
#
# current iteration: 80
# diff: -1.18
# pct diff: -0.01
# next iteration: 81
#
#
# current iteration: 81
# diff: -0.73
# pct diff: -0.01
# next iteration: 82
#
#
# current iteration: 82
# diff: 1.04
# pct diff: 0.01
# next iteration: 83
#
#
# current iteration: 83
# diff: -0.55
# pct diff: -0.01
# next iteration: 84
#
#
# current iteration: 84
# diff: -0.1
# pct diff: -0.0
# next iteration: 85
#
#
# current iteration: 85
# diff: 1.19
# pct diff: 0.01
# next iteration: 86
#
#
# current iteration: 86
# diff: 0.57
# pct diff: 0.01
# next iteration: 87
#
#
# current iteration: 87
# diff: -0.19
# pct diff: -0.0
# next iteration: 88
#
#
# current iteration: 88
# diff: 1.19
# pct diff: 0.01
# next iteration: 89
#
#
# current iteration: 89
# diff: -4.07
# pct diff: -0.04
# next iteration: 90
#
#
# current iteration: 90
# diff: -0.54
# pct diff: -0.01
# next iteration: 91
#
#
# current iteration: 91
# diff: -1.13
# pct diff: -0.01
# next iteration: 92
#
#
# current iteration: 92
# diff: -0.15
# pct diff: -0.0
# next iteration: 93
#
#
# current iteration: 93
# diff: -0.39
# pct diff: -0.0
# next iteration: 94
#
#
# current iteration: 94
# diff: -0.89
# pct diff: -0.01
# next iteration: 95
#
#
# current iteration: 95
# diff: -0.56
# pct diff: -0.01
# next iteration: 96
#
#
# current iteration: 96
# diff: 1.3
# pct diff: 0.01
# next iteration: 97
#
#
# current iteration: 97
# diff: -0.57
# pct diff: -0.01
# next iteration: 98
#
#
# current iteration: 98
# diff: 0.31
# pct diff: 0.0
# next iteration: 99
#
#
# current iteration: 99
# diff: 0.33
# pct diff: 0.0
# next iteration: 100
#
#
# current iteration: 100
# diff: -0.04
# pct diff: -0.0
# next iteration: 101
#
#
# current iteration: 101
# diff: 0.45
# pct diff: 0.0
# next iteration: 102
#
#
# current iteration: 102
# diff: -1.01
# pct diff: -0.01
# next iteration: 103
#
#
# current iteration: 103
# diff: -0.66
# pct diff: -0.01
# next iteration: 104
#
#
# current iteration: 104
# diff: 0.19
# pct diff: 0.0
# next iteration: 105
#
#
# current iteration: 105
# diff: 0.03
# pct diff: 0.0
# next iteration: 106
#
#
# current iteration: 106
# diff: 0.02
# pct diff: 0.0
# next iteration: 107
#
#
# current iteration: 107
# diff: -0.4
# pct diff: -0.0
# next iteration: 108
#
#
# current iteration: 108
# diff: -0.29
# pct diff: -0.0
# next iteration: 109
#
#
# current iteration: 109
# diff: -0.19
# pct diff: -0.0
# next iteration: 110
#
#
# current iteration: 110
# diff: -0.48
# pct diff: -0.01
# next iteration: 111
#
#
# current iteration: 111
# diff: 0.22
# pct diff: 0.0
# next iteration: 112
#
#
# current iteration: 112
# diff: 0.78
# pct diff: 0.01
# next iteration: 113
#
#
# current iteration: 113
# diff: -0.12
# pct diff: -0.0
# next iteration: 114
#
#
# current iteration: 114
# diff: 0.11
# pct diff: 0.0
# next iteration: 115
#
#
# current iteration: 115
# diff: 0.58
# pct diff: 0.01
# next iteration: 116
#
#
# current iteration: 116
# diff: 0.54
# pct diff: 0.01
# next iteration: 117
#
#
# current iteration: 117
# diff: -0.71
# pct diff: -0.01
# next iteration: 118
#
#
# current iteration: 118
# diff: -0.03
# pct diff: -0.0
# next iteration: 119
#
#
# current iteration: 119
# diff: 0.22
# pct diff: 0.0
# next iteration: 120
#
#
# current iteration: 120
# diff: -3.11
# pct diff: -0.03
# next iteration: 121
#
#
# current iteration: 121
# diff: -1.27
# pct diff: -0.01
# next iteration: 122
#
#
# current iteration: 122
# diff: 1.58
# pct diff: 0.02
# next iteration: 123
#
#
# current iteration: 123
# diff: 0.88
# pct diff: 0.01
# next iteration: 124
#
#
# current iteration: 124
# diff: 0.79
# pct diff: 0.01
# next iteration: 125
#
#
# current iteration: 125
# diff: 0.2
# pct diff: 0.0
# next iteration: 126
#
#
# current iteration: 126
# diff: -0.35
# pct diff: -0.0
# next iteration: 127
#
#
# current iteration: 127
# diff: 0.74
# pct diff: 0.01
# next iteration: 128
#
#
# current iteration: 128
# diff: 0.64
# pct diff: 0.01
# next iteration: 129
#
#
# current iteration: 129
# diff: 1.15
# pct diff: 0.01
# next iteration: 130
#
#
# current iteration: 130
# diff: 0.34
# pct diff: 0.0
# next iteration: 131
#
#
# current iteration: 131
# diff: 0.21
# pct diff: 0.0
# next iteration: 132
#
#
# current iteration: 132
# diff: -0.3
# pct diff: -0.0
# next iteration: 133
#
#
# current iteration: 133
# diff: 0.08
# pct diff: 0.0
# next iteration: 134
#
#
# current iteration: 134
# diff: -0.16
# pct diff: -0.0
# next iteration: 135
#
#
# current iteration: 135
# diff: 0.33
# pct diff: 0.0
# next iteration: 136
#
#
# current iteration: 136
# diff: -0.64
# pct diff: -0.01
# next iteration: 137
#
#
# current iteration: 137
# diff: -1.19
# pct diff: -0.01
# next iteration: 138
#
#
# current iteration: 138
# diff: -0.2
# pct diff: -0.0
# next iteration: 139
#
#
# current iteration: 139
# diff: -0.29
# pct diff: -0.0
# next iteration: 140
#
#
# current iteration: 140
# diff: -0.3
# pct diff: -0.0
# next iteration: 141
#
#
# current iteration: 141
# diff: -0.67
# pct diff: -0.01
# next iteration: 142
#
#
# current iteration: 142
# diff: -0.34
# pct diff: -0.0
# next iteration: 143
#
#
# current iteration: 143
# diff: -0.4
# pct diff: -0.0
# next iteration: 144
#
#
# current iteration: 144
# diff: 0.04
# pct diff: 0.0
# next iteration: 145
#
#
# current iteration: 145
# diff: -0.39
# pct diff: -0.0
# next iteration: 146
#
#
# current iteration: 146
# diff: -0.5
# pct diff: -0.01
# next iteration: 147
#
#
# current iteration: 147
# diff: 1.02
# pct diff: 0.01
# next iteration: 148
#
#
# current iteration: 148
# diff: -0.88
# pct diff: -0.01
# next iteration: 149
#
#
# current iteration: 149
# diff: 0.64
# pct diff: 0.01
# next iteration: 150
#
#
# current iteration: 150
# diff: -0.08
# pct diff: -0.0
# next iteration: 151
#
#
# current iteration: 151
# diff: 0.88
# pct diff: 0.01
# next iteration: 152
#
#
# current iteration: 152
# diff: 1.13
# pct diff: 0.01
# next iteration: 153
#
#
# current iteration: 153
# diff: -0.09
# pct diff: -0.0
# next iteration: 154
#
#
# current iteration: 154
# diff: -0.88
# pct diff: -0.01
# next iteration: 155
#
#
# current iteration: 155
# diff: 0.24
# pct diff: 0.0
# next iteration: 156
#
#
# current iteration: 156
# diff: -0.21
# pct diff: -0.0
# next iteration: 157
#
#
# current iteration: 157
# diff: 0.0
# pct diff: 0.0
# next iteration: 158
#
#
# current iteration: 158
# diff: -0.21
# pct diff: -0.0
# next iteration: 159
#
#
# current iteration: 159
# diff: -0.25
# pct diff: -0.0
# next iteration: 160
#
#
# current iteration: 160
# diff: -0.5
# pct diff: -0.01
# next iteration: 161
#
#
# current iteration: 161
# diff: 0.1
# pct diff: 0.0
# next iteration: 162
#
#
# current iteration: 162
# diff: -0.14
# pct diff: -0.0
# next iteration: 163
#
#
# current iteration: 163
# diff: -0.26
# pct diff: -0.0
# next iteration: 164
#
#
# current iteration: 164
# diff: -0.32
# pct diff: -0.0
# next iteration: 165
#
#
# current iteration: 165
# diff: -0.33
# pct diff: -0.0
# next iteration: 166
#
#
# current iteration: 166
# diff: 0.0
# pct diff: 0.0
# next iteration: 167
#
#
# current iteration: 167
# diff: -0.38
# pct diff: -0.0
# next iteration: 168
#
#
# current iteration: 168
# diff: -0.2
# pct diff: -0.0
# next iteration: 169
#
#
# current iteration: 169
# diff: 0.16
# pct diff: 0.0
# next iteration: 170
#
#
# current iteration: 170
# diff: -0.59
# pct diff: -0.01
# next iteration: 171
#
#
# current iteration: 171
# diff: -0.09
# pct diff: -0.0
# next iteration: 172
#
#
# current iteration: 172
# diff: 0.36
# pct diff: 0.0
# next iteration: 173
#
#
# current iteration: 173
# diff: -1.58
# pct diff: -0.02
# next iteration: 174
#
#
# current iteration: 174
# diff: 1.16
# pct diff: 0.01
# next iteration: 175
#
#
# current iteration: 175
# diff: -0.9
# pct diff: -0.01
# next iteration: 176
#
#
# current iteration: 176
# diff: -0.42
# pct diff: -0.0
# next iteration: 177
#
#
# current iteration: 177
# diff: 0.23
# pct diff: 0.0
# next iteration: 178
#
#
# current iteration: 178
# diff: 0.06
# pct diff: 0.0
# next iteration: 179
#
#
# current iteration: 179
# diff: 0.07
# pct diff: 0.0
# next iteration: 180
#
#
# current iteration: 180
# diff: 0.3
# pct diff: 0.0
# next iteration: 181
#
#
# current iteration: 181
# diff: -0.53
# pct diff: -0.01
# next iteration: 182
#
#
# current iteration: 182
# diff: 0.97
# pct diff: 0.01
# next iteration: 183
#
#
# current iteration: 183
# diff: -0.14
# pct diff: -0.0
# next iteration: 184
#
#
# current iteration: 184
# diff: -1.24
# pct diff: -0.01
# next iteration: 185
#
#
# current iteration: 185
# diff: -0.23
# pct diff: -0.0
# next iteration: 186
#
#
# current iteration: 186
# diff: 0.46
# pct diff: 0.01
# next iteration: 187
#
#
# current iteration: 187
# diff: -0.38
# pct diff: -0.0
# next iteration: 188
#
#
# current iteration: 188
# diff: 1.0
# pct diff: 0.01
# next iteration: 189
#
#
# current iteration: 189
# diff: -0.35
# pct diff: -0.0
# next iteration: 190
#
#
# current iteration: 190
# diff: 0.1
# pct diff: 0.0
# next iteration: 191
#
#
# current iteration: 191
# diff: -0.14
# pct diff: -0.0
# next iteration: 192
#
#
# current iteration: 192
# diff: 0.37
# pct diff: 0.0
# next iteration: 193
#
#
# current iteration: 193
# diff: -0.33
# pct diff: -0.0
# next iteration: 194
#
#
# current iteration: 194
# diff: 0.0
# pct diff: 0.0
# next iteration: 195
#
#
# current iteration: 195
# diff: -0.6
# pct diff: -0.01
# next iteration: 196
#
#
# current iteration: 196
# diff: -0.42
# pct diff: -0.0
# next iteration: 197
#
#
# current iteration: 197
# diff: -0.28
# pct diff: -0.0
# next iteration: 198
#
#
# current iteration: 198
# diff: 0.17
# pct diff: 0.0
# next iteration: 199
#
#
# current iteration: 199
# diff: -0.44
# pct diff: -0.01
# next iteration: 200
#
#
# current iteration: 200
# diff: 0.32
# pct diff: 0.0
# next iteration: 201
#
#
# current iteration: 201
# diff: 0.72
# pct diff: 0.01
# next iteration: 202
#
#
# current iteration: 202
# diff: 0.1
# pct diff: 0.0
# next iteration: 203
#
#
# current iteration: 203
# diff: 0.95
# pct diff: 0.01
# next iteration: 204
#
#
# current iteration: 204
# diff: 0.32
# pct diff: 0.0
# next iteration: 205
#
#
# current iteration: 205
# diff: -0.59
# pct diff: -0.01
# next iteration: 206
#
#
# current iteration: 206
# diff: 0.7
# pct diff: 0.01
# next iteration: 207
#
#
# current iteration: 207
# diff: 0.51
# pct diff: 0.01
# next iteration: 208
#
#
# current iteration: 208
# diff: -0.16
# pct diff: -0.0
# next iteration: 209
#
#
# current iteration: 209
# diff: -1.11
# pct diff: -0.01
# next iteration: 210
#
#
# current iteration: 210
# diff: -0.28
# pct diff: -0.0
# next iteration: 211
#
#
# current iteration: 211
# diff: -0.46
# pct diff: -0.01
# next iteration: 212
#
#
# current iteration: 212
# diff: 1.39
# pct diff: 0.02
# next iteration: 213
#
#
# current iteration: 213
# diff: -0.88
# pct diff: -0.01
# next iteration: 214
#
#
# current iteration: 214
# diff: 1.89
# pct diff: 0.02
# next iteration: 215
#
#
# current iteration: 215
# diff: -0.05
# pct diff: -0.0
# next iteration: 216
#
#
# current iteration: 216
# diff: 0.25
# pct diff: 0.0
# next iteration: 217
#
#
# current iteration: 217
# diff: 0.3
# pct diff: 0.0
# next iteration: 218
#
#
# current iteration: 218
# diff: 2.58
# pct diff: 0.03
# next iteration: 219
#
#
# current iteration: 219
# diff: 0.23
# pct diff: 0.0
# next iteration: 220
#
#
# current iteration: 220
# diff: -0.21
# pct diff: -0.0
# next iteration: 221
#
#
# current iteration: 221
# diff: 1.35
# pct diff: 0.01
# next iteration: 222
#
#
# current iteration: 222
# diff: 0.24
# pct diff: 0.0
# next iteration: 223
#
#
# current iteration: 223
# diff: -1.07
# pct diff: -0.01
# next iteration: 224
#
#
# current iteration: 224
# diff: -0.58
# pct diff: -0.01
# next iteration: 225
#
#
# current iteration: 225
# diff: 0.07
# pct diff: 0.0
# next iteration: 226
#
#
# current iteration: 226
# diff: 0.53
# pct diff: 0.01
# next iteration: 227
#
#
# current iteration: 227
# diff: 0.53
# pct diff: 0.01
# next iteration: 228
#
#
# current iteration: 228
# diff: 0.14
# pct diff: 0.0
# next iteration: 229
#
#
# current iteration: 229
# diff: 0.67
# pct diff: 0.01
# next iteration: 230
#
#
# current iteration: 230
# diff: -0.53
# pct diff: -0.01
# next iteration: 231
#
#
# current iteration: 231
# diff: -0.17
# pct diff: -0.0
# next iteration: 232
#
#
# current iteration: 232
# diff: -0.42
# pct diff: -0.0
# next iteration: 233
#
#
# current iteration: 233
# diff: 1.39
# pct diff: 0.01
# next iteration: 234
#
#
# current iteration: 234
# diff: 0.67
# pct diff: 0.01
# next iteration: 235
#
#
# current iteration: 235
# diff: 1.26
# pct diff: 0.01
# next iteration: 236
#
#
# current iteration: 236
# diff: 2.08
# pct diff: 0.02
# next iteration: 237
#
#
# current iteration: 237
# diff: 1.42
# pct diff: 0.01
# next iteration: 238
#
#
# current iteration: 238
# diff: -0.77
# pct diff: -0.01
# next iteration: 239
#
#
# current iteration: 239
# diff: -0.2
# pct diff: -0.0
# next iteration: 240
#
#
# current iteration: 240
# diff: 0.19
# pct diff: 0.0
# next iteration: 241
#
#
# current iteration: 241
# diff: 0.33
# pct diff: 0.0
# next iteration: 242
#
#
# current iteration: 242
# diff: -0.46
# pct diff: -0.0
# next iteration: 243
#
#
# current iteration: 243
# diff: 1.33
# pct diff: 0.01
# next iteration: 244
#
#
# current iteration: 244
# diff: 0.15
# pct diff: 0.0
# next iteration: 245
#
#
# current iteration: 245
# diff: 0.1
# pct diff: 0.0
# next iteration: 246
#
#
# current iteration: 246
# diff: -0.14
# pct diff: -0.0
# next iteration: 247
#
#
# current iteration: 247
# diff: -0.26
# pct diff: -0.0
# next iteration: 248
#
#
# current iteration: 248
# diff: 0.02
# pct diff: 0.0
# next iteration: 249
#
#
# current iteration: 249
# diff: -0.83
# pct diff: -0.01
# next iteration: 250
#
#
# current iteration: 250
# diff: 0.25
# pct diff: 0.0
# next iteration: 251
#
#
# current iteration: 251
# diff: -0.33
# pct diff: -0.0
# next iteration: 252
#
#
# current iteration: 252
# diff: 1.78
# pct diff: 0.02
# next iteration: 253
#
#
# current iteration: 253
# diff: 1.31
# pct diff: 0.01
# next iteration: 254
#
#
# current iteration: 254
# diff: -0.06
# pct diff: -0.0
# next iteration: 255
#
#
# current iteration: 255
# diff: 1.53
# pct diff: 0.01
# next iteration: 256
#
#
# current iteration: 256
# diff: -0.59
# pct diff: -0.01
# next iteration: 257
#
#
# current iteration: 257
# diff: 0.02
# pct diff: 0.0
# next iteration: 258
#
#
# current iteration: 258
# diff: 1.01
# pct diff: 0.01
# next iteration: 259
#
#
# current iteration: 259
# diff: -1.83
# pct diff: -0.02
# next iteration: 260
#
#
# current iteration: 260
# diff: 0.51
# pct diff: 0.0
# next iteration: 261
#
#
# current iteration: 261
# diff: -0.09
# pct diff: -0.0
# next iteration: 262
#
#
# current iteration: 262
# diff: 0.19
# pct diff: 0.0
# next iteration: 263
#
#
# current iteration: 263
# diff: -0.85
# pct diff: -0.01
# next iteration: 264
#
#
# current iteration: 264
# diff: 0.37
# pct diff: 0.0
# next iteration: 265
#
#
# current iteration: 265
# diff: -0.52
# pct diff: -0.01
# next iteration: 266
#
#
# current iteration: 266
# diff: 0.75
# pct diff: 0.01
# next iteration: 267
#
#
# current iteration: 267
# diff: 0.13
# pct diff: 0.0
# next iteration: 268
#
#
# current iteration: 268
# diff: 0.02
# pct diff: 0.0
# next iteration: 269
#
#
# current iteration: 269
# diff: 1.19
# pct diff: 0.01
# next iteration: 270
#
#
# current iteration: 270
# diff: 1.57
# pct diff: 0.01
# next iteration: 271
#
#
# current iteration: 271
# diff: -0.28
# pct diff: -0.0
# next iteration: 272
#
#
# current iteration: 272
# diff: 0.62
# pct diff: 0.01
# next iteration: 273
#
#
# current iteration: 273
# diff: -0.66
# pct diff: -0.01
# next iteration: 274
#
#
# current iteration: 274
# diff: -0.29
# pct diff: -0.0
# next iteration: 275
#
#
# current iteration: 275
# diff: -0.7
# pct diff: -0.01
# next iteration: 276
#
#
# current iteration: 276
# diff: -0.55
# pct diff: -0.01
# next iteration: 277
#
#
# current iteration: 277
# diff: 0.0
# pct diff: 0.0
# next iteration: 278
#
#
# current iteration: 278
# diff: 0.47
# pct diff: 0.0
# next iteration: 279
#
#
# current iteration: 279
# diff: -0.22
# pct diff: -0.0
# next iteration: 280
#
#
# current iteration: 280
# diff: 0.37
# pct diff: 0.0
# next iteration: 281
#
#
# current iteration: 281
# diff: 0.65
# pct diff: 0.01
# next iteration: 282
#
#
# current iteration: 282
# diff: -0.14
# pct diff: -0.0
# next iteration: 283
#
#
# current iteration: 283
# diff: 0.51
# pct diff: 0.0
# next iteration: 284
#
#
# current iteration: 284
# diff: -0.62
# pct diff: -0.01
# next iteration: 285
#
#
# current iteration: 285
# diff: -0.05
# pct diff: -0.0
# next iteration: 286
#
#
# current iteration: 286
# diff: 0.1
# pct diff: 0.0
# next iteration: 287
#
#
# current iteration: 287
# diff: -0.37
# pct diff: -0.0
# next iteration: 288
#
#
# current iteration: 288
# diff: 0.56
# pct diff: 0.01
# next iteration: 289
#
#
# current iteration: 289
# diff: -0.08
# pct diff: -0.0
# next iteration: 290
#
#
# current iteration: 290
# diff: -0.14
# pct diff: -0.0
# next iteration: 291
#
#
# current iteration: 291
# diff: 0.91
# pct diff: 0.01
# next iteration: 292
#
#
# current iteration: 292
# diff: -0.43
# pct diff: -0.0
# next iteration: 293
#
#
# current iteration: 293
# diff: 0.63
# pct diff: 0.01
# next iteration: 294
#
#
# current iteration: 294
# diff: -0.55
# pct diff: -0.01
# next iteration: 295
#
#
# current iteration: 295
# diff: 0.18
# pct diff: 0.0
# next iteration: 296
#
#
# current iteration: 296
# diff: -0.02
# pct diff: -0.0
# next iteration: 297
#
#
# current iteration: 297
# diff: 0.18
# pct diff: 0.0
# next iteration: 298
#
#
# current iteration: 298
# diff: -0.1
# pct diff: -0.0
# next iteration: 299
#
#
# current iteration: 299
# diff: 0.57
# pct diff: 0.01
# next iteration: 300
#
#
# current iteration: 300
# diff: 0.76
# pct diff: 0.01
# next iteration: 301
#
#
# current iteration: 301
# diff: -0.42
# pct diff: -0.0
# next iteration: 302
#
#
# current iteration: 302
# diff: -0.15
# pct diff: -0.0
# next iteration: 303
#
#
# current iteration: 303
# diff: 0.04
# pct diff: 0.0
# next iteration: 304
#
#
# current iteration: 304
# diff: 0.91
# pct diff: 0.01
# next iteration: 305
#
#
# current iteration: 305
# diff: -0.92
# pct diff: -0.01
# next iteration: 306
#
#
# current iteration: 306
# diff: 0.32
# pct diff: 0.0
# next iteration: 307
#
#
# current iteration: 307
# diff: 0.15
# pct diff: 0.0
# next iteration: 308
#
#
# current iteration: 308
# diff: -0.09
# pct diff: -0.0
# next iteration: 309
#
#
# current iteration: 309
# diff: 0.23
# pct diff: 0.0
# next iteration: 310
#
#
# current iteration: 310
# diff: 0.64
# pct diff: 0.01
# next iteration: 311
#
#
# current iteration: 311
# diff: -0.5
# pct diff: -0.0
# next iteration: 312
#
#
# current iteration: 312
# diff: 0.62
# pct diff: 0.01
# next iteration: 313
#
#
# current iteration: 313
# diff: 0.2
# pct diff: 0.0
# next iteration: 314
#
#
# current iteration: 314
# diff: -0.18
# pct diff: -0.0
# next iteration: 315
#
#
# current iteration: 315
# diff: -0.15
# pct diff: -0.0
# next iteration: 316
#
#
# current iteration: 316
# diff: -0.04
# pct diff: -0.0
# next iteration: 317
#
#
# current iteration: 317
# diff: 0.05
# pct diff: 0.0
# next iteration: 318
#
#
# current iteration: 318
# diff: -0.45
# pct diff: -0.0
# next iteration: 319
#
#
# current iteration: 319
# diff: -0.14
# pct diff: -0.0
# next iteration: 320
#
#
# current iteration: 320
# diff: 0.61
# pct diff: 0.01
# next iteration: 321
#
#
# current iteration: 321
# diff: -0.03
# pct diff: -0.0
# next iteration: 322
#
#
# current iteration: 322
# diff: 0.15
# pct diff: 0.0
# next iteration: 323
#
#
# current iteration: 323
# diff: 0.56
# pct diff: 0.01
# next iteration: 324
#
#
# current iteration: 324
# diff: 0.39
# pct diff: 0.0
# next iteration: 325
#
#
# current iteration: 325
# diff: -0.44
# pct diff: -0.0
# next iteration: 326
#
#
# current iteration: 326
# diff: 1.02
# pct diff: 0.01
# next iteration: 327
#
#
# current iteration: 327
# diff: -0.34
# pct diff: -0.0
# next iteration: 328
#
#
# current iteration: 328
# diff: -0.71
# pct diff: -0.01
# next iteration: 329
#
#
# current iteration: 329
# diff: 1.42
# pct diff: 0.01
# next iteration: 330
#
#
# current iteration: 330
# diff: 0.38
# pct diff: 0.0
# next iteration: 331
#
#
# current iteration: 331
# diff: 0.25
# pct diff: 0.0
# next iteration: 332
#
#
# current iteration: 332
# diff: -0.23
# pct diff: -0.0
# next iteration: 333
#
#
# current iteration: 333
# diff: -0.83
# pct diff: -0.01
# next iteration: 334
#
#
# current iteration: 334
# diff: -0.35
# pct diff: -0.0
# next iteration: 335
#
#
# current iteration: 335
# diff: -2.63
# pct diff: -0.02
# next iteration: 336
#
#
# current iteration: 336
# diff: -0.43
# pct diff: -0.0
# next iteration: 337
#
#
# current iteration: 337
# diff: 0.78
# pct diff: 0.01
# next iteration: 338
#
#
# current iteration: 338
# diff: -0.54
# pct diff: -0.01
# next iteration: 339
#
#
# current iteration: 339
# diff: 0.62
# pct diff: 0.01
# next iteration: 340
#
#
# current iteration: 340
# diff: -2.31
# pct diff: -0.02
# next iteration: 341
#
#
# current iteration: 341
# diff: -0.07
# pct diff: -0.0
# next iteration: 342
#
#
# current iteration: 342
# diff: 0.1
# pct diff: 0.0
# next iteration: 343
#
#
# current iteration: 343
# diff: -0.53
# pct diff: -0.01
# next iteration: 344
#
#
# current iteration: 344
# diff: -1.11
# pct diff: -0.01
# next iteration: 345
#
#
# current iteration: 345
# diff: -1.6
# pct diff: -0.02
# next iteration: 346
#
#
# current iteration: 346
# diff: 0.36
# pct diff: 0.0
# next iteration: 347
#
#
# current iteration: 347
# diff: 0.8
# pct diff: 0.01
# next iteration: 348
#
#
# current iteration: 348
# diff: 0.11
# pct diff: 0.0
# next iteration: 349
#
#
# current iteration: 349
# diff: -0.59
# pct diff: -0.01
# next iteration: 350
#
#
# current iteration: 350
# diff: 0.67
# pct diff: 0.01
# next iteration: 351
#
#
# current iteration: 351
# diff: -0.43
# pct diff: -0.0
# next iteration: 352
#
#
# current iteration: 352
# diff: 1.1
# pct diff: 0.01
# next iteration: 353
#
#
# current iteration: 353
# diff: -0.07
# pct diff: -0.0
# next iteration: 354
#
#
# current iteration: 354
# diff: -0.38
# pct diff: -0.0
# next iteration: 355
#
#
# current iteration: 355
# diff: 0.25
# pct diff: 0.0
# next iteration: 356
#
#
# current iteration: 356
# diff: -0.98
# pct diff: -0.01
# next iteration: 357
#
#
# current iteration: 357
# diff: -0.63
# pct diff: -0.01
# next iteration: 358
#
#
# current iteration: 358
# diff: -0.98
# pct diff: -0.01
# next iteration: 359
#
#
# current iteration: 359
# diff: 0.4
# pct diff: 0.0
# next iteration: 360
#
#
# current iteration: 360
# diff: -1.53
# pct diff: -0.02
# next iteration: 361
#
#
# current iteration: 361
# diff: 1.24
# pct diff: 0.01
# next iteration: 362
#
#
# current iteration: 362
# diff: 1.36
# pct diff: 0.01
# next iteration: 363
#
#
# current iteration: 363
# diff: -0.46
# pct diff: -0.0
# next iteration: 364
#
#
# current iteration: 364
# diff: -0.4
# pct diff: -0.0
# next iteration: 365
#
#
# current iteration: 365
# diff: -0.15
# pct diff: -0.0
# next iteration: 366
#
#
# current iteration: 366
# diff: -0.45
# pct diff: -0.0
# next iteration: 367
#
#
# current iteration: 367
# diff: -0.14
# pct diff: -0.0
# next iteration: 368
#
#
# current iteration: 368
# diff: -1.36
# pct diff: -0.01
# next iteration: 369
#
#
# current iteration: 369
# diff: 0.82
# pct diff: 0.01
# next iteration: 370
#
#
# current iteration: 370
# diff: -0.56
# pct diff: -0.01
# next iteration: 371
#
#
# current iteration: 371
# diff: 0.14
# pct diff: 0.0
# next iteration: 372
#
#
# current iteration: 372
# diff: 1.16
# pct diff: 0.01
# next iteration: 373
#
#
# current iteration: 373
# diff: -0.16
# pct diff: -0.0
# next iteration: 374
#
#
# current iteration: 374
# diff: 1.39
# pct diff: 0.01
# next iteration: 375
#
#
# current iteration: 375
# diff: -1.1
# pct diff: -0.01
# next iteration: 376
#
#
# current iteration: 376
# diff: 0.52
# pct diff: 0.01
# next iteration: 377
#
#
# current iteration: 377
# diff: 1.16
# pct diff: 0.01
# next iteration: 378
#
#
# current iteration: 378
# diff: -1.76
# pct diff: -0.02
# next iteration: 379
#
#
# current iteration: 379
# diff: -1.44
# pct diff: -0.01
# next iteration: 380
#
#
# current iteration: 380
# diff: -0.03
# pct diff: -0.0
# next iteration: 381
#
#
# current iteration: 381
# diff: 0.26
# pct diff: 0.0
# next iteration: 382
#
#
# current iteration: 382
# diff: 0.24
# pct diff: 0.0
# next iteration: 383
#
#
# current iteration: 383
# diff: 0.52
# pct diff: 0.01
# next iteration: 384
#
#
# current iteration: 384
# diff: -0.09
# pct diff: -0.0
# next iteration: 385
#
#
# current iteration: 385
# diff: 0.77
# pct diff: 0.01
# next iteration: 386
#
#
# current iteration: 386
# diff: -0.28
# pct diff: -0.0
# next iteration: 387
#
#
# current iteration: 387
# diff: 0.92
# pct diff: 0.01
# next iteration: 388
#
#
# current iteration: 388
# diff: 1.03
# pct diff: 0.01
# next iteration: 389
#
#
# current iteration: 389
# diff: 0.52
# pct diff: 0.01
# next iteration: 390
#
#
# current iteration: 390
# diff: -0.26
# pct diff: -0.0
# next iteration: 391
#
#
# current iteration: 391
# diff: -0.08
# pct diff: -0.0
# next iteration: 392
#
#
# current iteration: 392
# diff: -0.56
# pct diff: -0.01
# next iteration: 393
#
#
# current iteration: 393
# diff: 0.5
# pct diff: 0.0
# next iteration: 394
#
#
# current iteration: 394
# diff: 2.95
# pct diff: 0.03
# next iteration: 395
#
#
# current iteration: 395
# diff: -0.04
# pct diff: -0.0
# next iteration: 396
#
#
# current iteration: 396
# diff: -0.03
# pct diff: -0.0
# next iteration: 397
#
#
# current iteration: 397
# diff: 0.66
# pct diff: 0.01
# next iteration: 398
#
#
# current iteration: 398
# diff: -1.87
# pct diff: -0.02
# next iteration: 399
#
#
# current iteration: 399
# diff: 0.43
# pct diff: 0.0
# next iteration: 400
#
#
# current iteration: 400
# diff: -1.38
# pct diff: -0.01
# next iteration: 401
#
#
# current iteration: 401
# diff: -1.29
# pct diff: -0.01
# next iteration: 402
#
#
# current iteration: 402
# diff: 0.61
# pct diff: 0.01
# next iteration: 403
#
#
# current iteration: 403
# diff: -4.01
# pct diff: -0.04
# next iteration: 404
#
#
# current iteration: 404
# diff: -1.42
# pct diff: -0.01
# next iteration: 405
#
#
# current iteration: 405
# diff: 0.61
# pct diff: 0.01
# next iteration: 406
#
#
# current iteration: 406
# diff: -0.56
# pct diff: -0.01
# next iteration: 407
#
#
# current iteration: 407
# diff: 0.1
# pct diff: 0.0
# next iteration: 408
#
#
# current iteration: 408
# diff: 0.67
# pct diff: 0.01
# next iteration: 409
#
#
# current iteration: 409
# diff: -0.79
# pct diff: -0.01
# next iteration: 410
#
#
# current iteration: 410
# diff: -0.66
# pct diff: -0.01
# next iteration: 411
#
#
# current iteration: 411
# diff: 0.45
# pct diff: 0.0
# next iteration: 412
#
#
# current iteration: 412
# diff: 1.55
# pct diff: 0.02
# next iteration: 413
#
#
# current iteration: 413
# diff: -1.23
# pct diff: -0.01
# next iteration: 414
#
#
# current iteration: 414
# diff: 0.02
# pct diff: 0.0
# next iteration: 415
#
#
# current iteration: 415
# diff: 0.86
# pct diff: 0.01
# next iteration: 416
#
#
# current iteration: 416
# diff: 0.14
# pct diff: 0.0
# next iteration: 417
#
#
# current iteration: 417
# diff: 0.01
# pct diff: 0.0
# next iteration: 418
#
#
# current iteration: 418
# diff: 0.29
# pct diff: 0.0
# next iteration: 419
#
#
# current iteration: 419
# diff: -1.61
# pct diff: -0.02
# next iteration: 420
#
#
# current iteration: 420
# diff: 0.29
# pct diff: 0.0
# next iteration: 421
#
#
# current iteration: 421
# diff: 0.1
# pct diff: 0.0
# next iteration: 422
#
#
# current iteration: 422
# diff: -0.1
# pct diff: -0.0
# next iteration: 423
#
#
# current iteration: 423
# diff: -4.28
# pct diff: -0.05
# next iteration: 424
#
#
# current iteration: 424
# diff: 0.01
# pct diff: 0.0
# next iteration: 425
#
#
# current iteration: 425
# diff: 0.02
# pct diff: 0.0
# next iteration: 426
#
#
# current iteration: 426
# diff: 0.77
# pct diff: 0.01
# next iteration: 427
#
#
# current iteration: 427
# diff: 0.9
# pct diff: 0.01
# next iteration: 428
#
#
# current iteration: 428
# diff: -0.89
# pct diff: -0.01
# next iteration: 429
#
#
# current iteration: 429
# diff: 0.6
# pct diff: 0.01
# next iteration: 430
#
#
# current iteration: 430
# diff: -0.41
# pct diff: -0.0
# next iteration: 431
#
#
# current iteration: 431
# diff: 0.32
# pct diff: 0.0
# next iteration: 432
#
#
# current iteration: 432
# diff: 0.75
# pct diff: 0.01
# next iteration: 433
#
#
# current iteration: 433
# diff: -0.31
# pct diff: -0.0
# next iteration: 434
#
#
# current iteration: 434
# diff: -0.28
# pct diff: -0.0
# next iteration: 435
#
#
# current iteration: 435
# diff: 0.94
# pct diff: 0.01
# next iteration: 436
#
#
# current iteration: 436
# diff: -0.91
# pct diff: -0.01
# next iteration: 437
#
#
# current iteration: 437
# diff: 0.59
# pct diff: 0.01
# next iteration: 438
#
#
# current iteration: 438
# diff: -1.15
# pct diff: -0.01
# next iteration: 439
#
#
# current iteration: 439
# diff: 0.5
# pct diff: 0.01
# next iteration: 440
#
#
# current iteration: 440
# diff: 1.25
# pct diff: 0.01
# next iteration: 441
#
#
# current iteration: 441
# diff: 0.9
# pct diff: 0.01
# next iteration: 442
#
#
# current iteration: 442
# diff: -0.23
# pct diff: -0.0
# next iteration: 443
#
#
# current iteration: 443
# diff: -0.43
# pct diff: -0.0
# next iteration: 444
#
#
# current iteration: 444
# diff: -0.04
# pct diff: -0.0
# next iteration: 445
#
#
# current iteration: 445
# diff: -0.48
# pct diff: -0.0
# next iteration: 446
#
#
# current iteration: 446
# diff: 0.01
# pct diff: 0.0
# next iteration: 447
#
#
# current iteration: 447
# diff: -0.99
# pct diff: -0.01
# next iteration: 448
#
#
# current iteration: 448
# diff: -1.57
# pct diff: -0.02
# next iteration: 449
#
#
# current iteration: 449
# diff: 0.44
# pct diff: 0.0
# next iteration: 450
#
#
# current iteration: 450
# diff: 0.72
# pct diff: 0.01
# next iteration: 451
#
#
# current iteration: 451
# diff: 0.22
# pct diff: 0.0
# next iteration: 452
#
#
# current iteration: 452
# diff: -0.1
# pct diff: -0.0
# next iteration: 453
#
#
# current iteration: 453
# diff: 0.73
# pct diff: 0.01
# next iteration: 454
#
#
# current iteration: 454
# diff: 0.38
# pct diff: 0.0
# next iteration: 455
#
#
# current iteration: 455
# diff: -0.68
# pct diff: -0.01
# next iteration: 456
#
#
# current iteration: 456
# diff: -0.4
# pct diff: -0.0
# next iteration: 457
#
#
# current iteration: 457
# diff: -0.47
# pct diff: -0.0
# next iteration: 458
#
#
# current iteration: 458
# diff: 0.74
# pct diff: 0.01
# next iteration: 459
#
#
# current iteration: 459
# diff: -0.25
# pct diff: -0.0
# next iteration: 460
#
#
# current iteration: 460
# diff: -0.26
# pct diff: -0.0
# next iteration: 461
#
#
# current iteration: 461
# diff: -0.22
# pct diff: -0.0
# next iteration: 462
#
#
# current iteration: 462
# diff: 1.18
# pct diff: 0.01
# next iteration: 463
#
#
# current iteration: 463
# diff: -0.66
# pct diff: -0.01
# next iteration: 464
#
#
# current iteration: 464
# diff: 0.28
# pct diff: 0.0
# next iteration: 465
#
#
# current iteration: 465
# diff: 1.93
# pct diff: 0.02
# next iteration: 466
#
#
# current iteration: 466
# diff: 0.94
# pct diff: 0.01
# next iteration: 467
#
#
# current iteration: 467
# diff: -0.42
# pct diff: -0.0
# next iteration: 468
#
#
# current iteration: 468
# diff: 1.45
# pct diff: 0.01
# next iteration: 469
#
#
# current iteration: 469
# diff: 2.03
# pct diff: 0.02
# next iteration: 470
#
#
# current iteration: 470
# diff: -0.04
# pct diff: -0.0
# next iteration: 471
#
#
# current iteration: 471
# diff: -1.52
# pct diff: -0.02
# next iteration: 472
#
#
# current iteration: 472
# diff: 0.5
# pct diff: 0.0
# next iteration: 473
#
#
# current iteration: 473
# diff: -0.08
# pct diff: -0.0
# next iteration: 474
#
#
# current iteration: 474
# diff: -0.16
# pct diff: -0.0
# next iteration: 475
#
#
# current iteration: 475
# diff: -0.66
# pct diff: -0.01
# next iteration: 476
#
#
# current iteration: 476
# diff: 0.24
# pct diff: 0.0
# next iteration: 477
#
#
# current iteration: 477
# diff: -0.25
# pct diff: -0.0
# next iteration: 478
#
#
# current iteration: 478
# diff: -0.1
# pct diff: -0.0
# next iteration: 479
#
#
# current iteration: 479
# diff: 0.15
# pct diff: 0.0
# next iteration: 480
#
#
# current iteration: 480
# diff: 0.59
# pct diff: 0.01
# next iteration: 481
#
#
# current iteration: 481
# diff: 1.77
# pct diff: 0.02
# next iteration: 482
#
#
# current iteration: 482
# diff: -0.41
# pct diff: -0.0
# next iteration: 483
#
#
# current iteration: 483
# diff: 0.42
# pct diff: 0.0
# next iteration: 484
#
#
# current iteration: 484
# diff: 4.79
# pct diff: 0.05
# next iteration: 485
#
#
# current iteration: 485
# diff: -2.89
# pct diff: -0.03
# next iteration: 486
#
#
# current iteration: 486
# diff: -1.7
# pct diff: -0.02
# next iteration: 487
#
#
# current iteration: 487
# diff: -0.19
# pct diff: -0.0
# next iteration: 488
#
#
# current iteration: 488
# diff: -0.19
# pct diff: -0.0
# next iteration: 489
#
#
# current iteration: 489
# diff: 2.53
# pct diff: 0.02
# next iteration: 490
#
#
# current iteration: 490
# diff: 0.59
# pct diff: 0.01
# next iteration: 491
#
#
# current iteration: 491
# diff: 0.17
# pct diff: 0.0
# next iteration: 492
#
#
# current iteration: 492
# diff: 2.88
# pct diff: 0.03
# next iteration: 493
#
#
# current iteration: 493
# diff: 0.68
# pct diff: 0.01
# next iteration: 494
#
#
# current iteration: 494
# diff: -0.23
# pct diff: -0.0
# next iteration: 495
#
#
# current iteration: 495
# diff: 0.76
# pct diff: 0.01
# next iteration: 496
#
#
# current iteration: 496
# diff: -2.07
# pct diff: -0.02
# next iteration: 497
#
#
# current iteration: 497
# diff: -0.11
# pct diff: -0.0
# next iteration: 498
#
#
# current iteration: 498
# diff: -0.88
# pct diff: -0.01
# next iteration: 499
#
#
# current iteration: 499
# diff: -0.53
# pct diff: -0.01
# next iteration: 500
#
#
# current iteration: 500
# diff: -0.47
# pct diff: -0.0
# next iteration: 501
#
#
# current iteration: 501
# diff: 0.13
# pct diff: 0.0
# next iteration: 502
#
#
# current iteration: 502
# diff: -0.26
# pct diff: -0.0
# next iteration: 503
#
#
# current iteration: 503
# diff: 4.18
# pct diff: 0.04
# next iteration: 504
#
#
# current iteration: 504
# diff: 0.46
# pct diff: 0.0
# next iteration: 505
#
#
# current iteration: 505
# diff: -0.05
# pct diff: -0.0
# next iteration: 506
#
#
# current iteration: 506
# diff: -0.59
# pct diff: -0.01
# next iteration: 507
#
#
# current iteration: 507
# diff: -1.56
# pct diff: -0.01
# next iteration: 508
#
#
# current iteration: 508
# diff: -0.07
# pct diff: -0.0
# next iteration: 509
#
#
# current iteration: 509
# diff: -0.46
# pct diff: -0.0
# next iteration: 510
#
#
# current iteration: 510
# diff: 1.48
# pct diff: 0.01
# next iteration: 511
#
#
# current iteration: 511
# diff: 1.44
# pct diff: 0.01
# next iteration: 512
#
#
# current iteration: 512
# diff: -1.73
# pct diff: -0.02
# next iteration: 513
#
#
# current iteration: 513
# diff: 1.24
# pct diff: 0.01
# next iteration: 514
#
#
# current iteration: 514
# diff: -1.51
# pct diff: -0.01
# next iteration: 515
#
#
# current iteration: 515
# diff: 0.17
# pct diff: 0.0
# next iteration: 516
#
#
# current iteration: 516
# diff: 0.5
# pct diff: 0.0
# next iteration: 517
#
#
# current iteration: 517
# diff: -0.68
# pct diff: -0.01
# next iteration: 518
#
#
# current iteration: 518
# diff: 0.09
# pct diff: 0.0
# next iteration: 519
#
#
# current iteration: 519
# diff: 0.05
# pct diff: 0.0
# next iteration: 520
#
#
# current iteration: 520
# diff: 1.6
# pct diff: 0.01
# next iteration: 521
#
#
# current iteration: 521
# diff: -0.64
# pct diff: -0.01
# next iteration: 522
#
#
# current iteration: 522
# diff: -1.39
# pct diff: -0.01
# next iteration: 523
#
#
# current iteration: 523
# diff: -1.4
# pct diff: -0.01
# next iteration: 524
#
#
# current iteration: 524
# diff: 1.77
# pct diff: 0.02
# next iteration: 525
#
#
# current iteration: 525
# diff: -1.74
# pct diff: -0.02
# next iteration: 526
#
#
# current iteration: 526
# diff: -3.89
# pct diff: -0.04
# next iteration: 527
#
#
# current iteration: 527
# diff: 1.43
# pct diff: 0.01
# next iteration: 528
#
#
# current iteration: 528
# diff: -1.37
# pct diff: -0.01
# next iteration: 529
#
#
# current iteration: 529
# diff: -3.32
# pct diff: -0.03
# next iteration: 530
#
#
# current iteration: 530
# diff: 1.7
# pct diff: 0.02
# next iteration: 531
#
#
# current iteration: 531
# diff: 0.29
# pct diff: 0.0
# next iteration: 532
#
#
# current iteration: 532
# diff: 0.71
# pct diff: 0.01
# next iteration: 533
#
#
# current iteration: 533
# diff: 0.46
# pct diff: 0.0
# next iteration: 534
#
#
# current iteration: 534
# diff: 0.57
# pct diff: 0.01
# next iteration: 535
#
#
# current iteration: 535
# diff: 1.31
# pct diff: 0.01
# next iteration: 536
#
#
# current iteration: 536
# diff: -0.53
# pct diff: -0.01
# next iteration: 537
#
#
# current iteration: 537
# diff: -0.91
# pct diff: -0.01
# next iteration: 538
#
#
# current iteration: 538
# diff: 0.19
# pct diff: 0.0
# next iteration: 539
#
#
# current iteration: 539
# diff: 1.95
# pct diff: 0.02
# next iteration: 540
#
#
# current iteration: 540
# diff: 2.49
# pct diff: 0.02
# next iteration: 541
#
#
# current iteration: 541
# diff: -4.8
# pct diff: -0.05
# next iteration: 542
#
#
# current iteration: 542
# diff: -1.67
# pct diff: -0.02
# next iteration: 543
#
#
# current iteration: 543
# diff: -0.57
# pct diff: -0.01
# next iteration: 544
#
#
# current iteration: 544
# diff: 0.41
# pct diff: 0.0
# next iteration: 545
#
#
# current iteration: 545
# diff: 0.41
# pct diff: 0.0
# next iteration: 546
#
#
# current iteration: 546
# diff: 1.48
# pct diff: 0.01
# next iteration: 547
#
#
# current iteration: 547
# diff: -1.31
# pct diff: -0.01
# next iteration: 548
#
#
# current iteration: 548
# diff: 0.43
# pct diff: 0.0
# next iteration: 549
#
#
# current iteration: 549
# diff: 0.68
# pct diff: 0.01
# next iteration: 550
#
#
# current iteration: 550
# diff: 0.43
# pct diff: 0.0
# next iteration: 551
#
#
# current iteration: 551
# diff: -1.4
# pct diff: -0.01
# next iteration: 552
#
#
# current iteration: 552
# diff: 0.16
# pct diff: 0.0
# next iteration: 553
#
#
# current iteration: 553
# diff: -0.64
# pct diff: -0.01
# next iteration: 554
#
#
# current iteration: 554
# diff: -0.36
# pct diff: -0.0
# next iteration: 555
#
#
# current iteration: 555
# diff: -1.35
# pct diff: -0.01
# next iteration: 556
#
#
# current iteration: 556
# diff: -0.13
# pct diff: -0.0
# next iteration: 557
#
#
# current iteration: 557
# diff: 0.46
# pct diff: 0.0
# next iteration: 558
#
#
# current iteration: 558
# diff: -1.19
# pct diff: -0.01
# next iteration: 559
#
#
# current iteration: 559
# diff: -2.0
# pct diff: -0.02
# next iteration: 560
#
#
# current iteration: 560
# diff: 2.05
# pct diff: 0.02
# next iteration: 561
#
#
# current iteration: 561
# diff: -1.25
# pct diff: -0.01
# next iteration: 562
#
#
# current iteration: 562
# diff: -0.8
# pct diff: -0.01
# next iteration: 563
#
#
# current iteration: 563
# diff: 1.85
# pct diff: 0.02
# next iteration: 564
#
#
# current iteration: 564
# diff: -1.73
# pct diff: -0.02
# next iteration: 565
#
#
# current iteration: 565
# diff: 0.74
# pct diff: 0.01
# next iteration: 566
#
#
# current iteration: 566
# diff: 1.48
# pct diff: 0.02
# next iteration: 567
#
#
# current iteration: 567
# diff: 1.13
# pct diff: 0.01
# next iteration: 568
#
#
# current iteration: 568
# diff: -1.71
# pct diff: -0.02
# next iteration: 569
#
#
# current iteration: 569
# diff: -0.63
# pct diff: -0.01
# next iteration: 570
#
#
# current iteration: 570
# diff: 1.62
# pct diff: 0.02
# next iteration: 571
#
#
# current iteration: 571
# diff: -0.55
# pct diff: -0.01
# next iteration: 572
#
#
# current iteration: 572
# diff: -0.4
# pct diff: -0.0
# next iteration: 573
#
#
# current iteration: 573
# diff: -0.04
# pct diff: -0.0
# next iteration: 574
#
#
# current iteration: 574
# diff: -0.11
# pct diff: -0.0
# next iteration: 575
#
#
# current iteration: 575
# diff: 1.88
# pct diff: 0.02
# next iteration: 576
#
#
# current iteration: 576
# diff: -0.93
# pct diff: -0.01
# next iteration: 577
#
#
# current iteration: 577
# diff: -0.31
# pct diff: -0.0
# next iteration: 578
#
#
# current iteration: 578
# diff: -0.64
# pct diff: -0.01
# next iteration: 579
#
#
# current iteration: 579
# diff: -0.08
# pct diff: -0.0
# next iteration: 580
#
#
# current iteration: 580
# diff: -0.67
# pct diff: -0.01
# next iteration: 581
#
#
# current iteration: 581
# diff: 1.64
# pct diff: 0.02
# next iteration: 582
#
#
# current iteration: 582
# diff: -1.28
# pct diff: -0.01
# next iteration: 583
#
#
# current iteration: 583
# diff: -0.59
# pct diff: -0.01
# next iteration: 584
#
#
# current iteration: 584
# diff: 1.07
# pct diff: 0.01
# next iteration: 585
#
#
# current iteration: 585
# diff: -0.26
# pct diff: -0.0
# next iteration: 586
#
#
# current iteration: 586
# diff: -0.43
# pct diff: -0.0
# next iteration: 587
#
#
# current iteration: 587
# diff: -0.84
# pct diff: -0.01
# next iteration: 588
#
#
# current iteration: 588
# diff: 2.33
# pct diff: 0.02
# next iteration: 589
#
#
# current iteration: 589
# diff: 1.29
# pct diff: 0.01
# next iteration: 590
#
#
# current iteration: 590
# diff: -0.67
# pct diff: -0.01
# next iteration: 591
#
#
# current iteration: 591
# diff: -1.77
# pct diff: -0.02
# next iteration: 592
#
#
# current iteration: 592
# diff: 1.66
# pct diff: 0.02
# next iteration: 593
#
#
# current iteration: 593
# diff: 0.38
# pct diff: 0.0
# next iteration: 594
#
#
# current iteration: 594
# diff: 0.36
# pct diff: 0.0
# next iteration: 595
#
#
# current iteration: 595
# diff: 0.47
# pct diff: 0.0
# next iteration: 596
#
#
# current iteration: 596
# diff: 2.06
# pct diff: 0.02
# next iteration: 597
#
#
# current iteration: 597
# diff: -0.68
# pct diff: -0.01
# next iteration: 598
#
#
# current iteration: 598
# diff: -0.4
# pct diff: -0.0
# next iteration: 599
#
#
# current iteration: 599
# diff: 0.13
# pct diff: 0.0
# next iteration: 600
#
#
# current iteration: 600
# diff: 0.01
# pct diff: 0.0
# next iteration: 601
#
#
# current iteration: 601
# diff: -1.15
# pct diff: -0.01
# next iteration: 602
#
#
# current iteration: 602
# diff: -0.76
# pct diff: -0.01
# next iteration: 603
#
#
# current iteration: 603
# diff: 0.09
# pct diff: 0.0
# next iteration: 604
#
#
# current iteration: 604
# diff: -2.44
# pct diff: -0.03
# next iteration: 605
#
#
# current iteration: 605
# diff: 0.28
# pct diff: 0.0
# next iteration: 606
#
#
# current iteration: 606
# diff: -0.49
# pct diff: -0.01
# next iteration: 607
#
#
# current iteration: 607
# diff: -0.11
# pct diff: -0.0
# next iteration: 608
#
#
# current iteration: 608
# diff: 0.85
# pct diff: 0.01
# next iteration: 609
#
#
# current iteration: 609
# diff: -0.29
# pct diff: -0.0
# next iteration: 610
#
#
# current iteration: 610
# diff: 1.92
# pct diff: 0.02
# next iteration: 611
#
#
# current iteration: 611
# diff: 0.54
# pct diff: 0.01
# next iteration: 612
#
#
# current iteration: 612
# diff: 1.47
# pct diff: 0.01
# next iteration: 613
#
#
# current iteration: 613
# diff: 0.36
# pct diff: 0.0
# next iteration: 614
#
#
# current iteration: 614
# diff: -0.02
# pct diff: -0.0
# next iteration: 615
#
#
# current iteration: 615
# diff: 1.93
# pct diff: 0.02
# next iteration: 616
#
#
# current iteration: 616
# diff: 2.37
# pct diff: 0.02
# next iteration: 617
#
#
# current iteration: 617
# diff: 0.1
# pct diff: 0.0
# next iteration: 618
#
#
# current iteration: 618
# diff: -1.74
# pct diff: -0.02
# next iteration: 619
#
#
# current iteration: 619
# diff: -0.94
# pct diff: -0.01
# next iteration: 620
#
#
# current iteration: 620
# diff: 1.02
# pct diff: 0.01
# next iteration: 621
#
#
# current iteration: 621
# diff: -1.22
# pct diff: -0.01
# next iteration: 622
#
#
# current iteration: 622
# diff: 0.44
# pct diff: 0.0
# next iteration: 623
#
#
# current iteration: 623
# diff: -1.84
# pct diff: -0.02
# next iteration: 624
#
#
# current iteration: 624
# diff: -0.19
# pct diff: -0.0
# next iteration: 625
#
#
# current iteration: 625
# diff: -0.29
# pct diff: -0.0
# next iteration: 626
#
#
# current iteration: 626
# diff: 0.79
# pct diff: 0.01
# next iteration: 627
#
#
# current iteration: 627
# diff: 0.04
# pct diff: 0.0
# next iteration: 628
#
#
# current iteration: 628
# diff: 0.5
# pct diff: 0.0
# next iteration: 629
#
#
# current iteration: 629
# diff: -1.25
# pct diff: -0.01
# next iteration: 630
#
#
# current iteration: 630
# diff: 1.26
# pct diff: 0.01
# next iteration: 631
#
#
# current iteration: 631
# diff: 0.28
# pct diff: 0.0
# next iteration: 632
#
#
# current iteration: 632
# diff: 1.21
# pct diff: 0.01
# next iteration: 633
#
#
# current iteration: 633
# diff: 0.01
# pct diff: 0.0
# next iteration: 634
#
#
# current iteration: 634
# diff: 1.97
# pct diff: 0.02
# next iteration: 635
#
#
# current iteration: 635
# diff: 0.21
# pct diff: 0.0
# next iteration: 636
#
#
# current iteration: 636
# diff: 1.72
# pct diff: 0.02
# next iteration: 637
#
#
# current iteration: 637
# diff: 0.19
# pct diff: 0.0
# next iteration: 638
#
#
# current iteration: 638
# diff: 0.1
# pct diff: 0.0
# next iteration: 639
#
#
# current iteration: 639
# diff: 0.38
# pct diff: 0.0
# next iteration: 640
#
#
# current iteration: 640
# diff: 1.41
# pct diff: 0.01
# next iteration: 641
#
#
# current iteration: 641
# diff: -0.63
# pct diff: -0.01
# next iteration: 642
#
#
# current iteration: 642
# diff: -0.39
# pct diff: -0.0
# next iteration: 643
#
#
# current iteration: 643
# diff: -0.38
# pct diff: -0.0
# next iteration: 644
#
#
# current iteration: 644
# diff: 0.47
# pct diff: 0.0
# next iteration: 645
#
#
# current iteration: 645
# diff: 2.29
# pct diff: 0.02
# next iteration: 646
#
#
# current iteration: 646
# diff: -0.88
# pct diff: -0.01
# next iteration: 647
#
#
# current iteration: 647
# diff: 0.01
# pct diff: 0.0
# next iteration: 648
#
#
# current iteration: 648
# diff: 0.92
# pct diff: 0.01
# next iteration: 649
#
#
# current iteration: 649
# diff: -0.58
# pct diff: -0.01
# next iteration: 650
#
#
# current iteration: 650
# diff: -0.22
# pct diff: -0.0
# next iteration: 651
#
#
# current iteration: 651
# diff: 1.31
# pct diff: 0.01
# next iteration: 652
#
#
# current iteration: 652
# diff: 1.82
# pct diff: 0.02
# next iteration: 653
#
#
# current iteration: 653
# diff: 0.61
# pct diff: 0.01
# next iteration: 654
#
#
# current iteration: 654
# diff: -2.53
# pct diff: -0.02
# next iteration: 655
#
#
# current iteration: 655
# diff: 0.17
# pct diff: 0.0
# next iteration: 656
#
#
# current iteration: 656
# diff: -1.45
# pct diff: -0.01
# next iteration: 657
#
#
# current iteration: 657
# diff: -0.55
# pct diff: -0.01
# next iteration: 658
#
#
# current iteration: 658
# diff: 0.62
# pct diff: 0.01
# next iteration: 659
#
#
# current iteration: 659
# diff: 0.1
# pct diff: 0.0
# next iteration: 660
#
#
# current iteration: 660
# diff: -0.36
# pct diff: -0.0
# next iteration: 661
#
#
# current iteration: 661
# diff: 0.0
# pct diff: 0.0
# next iteration: 662
#
#
# current iteration: 662
# diff: -0.48
# pct diff: -0.0
# next iteration: 663
#
#
# current iteration: 663
# diff: 0.39
# pct diff: 0.0
# next iteration: 664
#
#
# current iteration: 664
# diff: -0.44
# pct diff: -0.0
# next iteration: 665
#
#
# current iteration: 665
# diff: 0.06
# pct diff: 0.0
# next iteration: 666
#
#
# current iteration: 666
# diff: -0.07
# pct diff: -0.0
# next iteration: 667
#
#
# current iteration: 667
# diff: 0.39
# pct diff: 0.0
# next iteration: 668
#
#
# current iteration: 668
# diff: 0.24
# pct diff: 0.0
# next iteration: 669
#
#
# current iteration: 669
# diff: -0.12
# pct diff: -0.0
# next iteration: 670
#
#
# current iteration: 670
# diff: -0.52
# pct diff: -0.0
# next iteration: 671
#
#
# current iteration: 671
# diff: 0.1
# pct diff: 0.0
# next iteration: 672
#
#
# current iteration: 672
# diff: -1.15
# pct diff: -0.01
# next iteration: 673
#
#
# current iteration: 673
# diff: -0.96
# pct diff: -0.01
# next iteration: 674
#
#
# current iteration: 674
# diff: 0.38
# pct diff: 0.0
# next iteration: 675
#
#
# ...
#
#
# current iteration: 1041
# diff: -5.96
# pct diff: -0.04
# next iteration: 1042
#
#
# current iteration: 1042
# diff: -4.82
# pct diff: -0.04
# next iteration: 1043
#
#
# current iteration: 1043
# diff: -4.83
# pct diff: -0.04
# next iteration: 1044
#
#
# current iteration: 1044
# diff: -5.32
# pct diff: -0.05
# next iteration: 1045
#
#
# current iteration: 1045
# diff: -0.39
# pct diff: -0.0
# next iteration: 1046
#
#
# current iteration: 1046
# diff: 2.33
# pct diff: 0.02
# next iteration: 1047
#
#
# current iteration: 1047
# diff: -3.53
# pct diff: -0.03
# next iteration: 1048
#
#
# current iteration: 1048
# diff: 2.73
# pct diff: 0.02
# next iteration: 1049
#
#
# current iteration: 1049
# diff: -5.2
# pct diff: -0.05
# next iteration: 1050
#
#
# current iteration: 1050
# diff: 1.29
# pct diff: 0.01
# next iteration: 1051
#
#
# current iteration: 1051
# diff: -10.92
# pct diff: -0.1
# next iteration: 1052
#
#
# current iteration: 1052
# diff: 7.11
# pct diff: 0.06
# next iteration: 1053
#
#
# current iteration: 1053
# diff: -5.95
# pct diff: -0.06
# next iteration: 1054
#
#
# current iteration: 1054
# diff: -13.7
# pct diff: -0.15
# next iteration: 1055
#
#
# current iteration: 1055
# diff: 10.71
# pct diff: 0.1
# next iteration: 1056
#
#
# current iteration: 1056
# diff: -7.51
# pct diff: -0.08
# next iteration: 1057
#
#
# current iteration: 1057
# diff: -1.48
# pct diff: -0.02
# next iteration: 1058
#
#
# current iteration: 1058
# diff: -4.73
# pct diff: -0.05
# next iteration: 1059
#
#
# current iteration: 1059
# diff: 6.13
# pct diff: 0.06
# next iteration: 1060
#
#
# current iteration: 1060
# diff: -8.95
# pct diff: -0.1
# next iteration: 1061
#
#
# current iteration: 1061
# diff: -0.22
# pct diff: -0.0
# next iteration: 1062
#
#
# current iteration: 1062
# diff: 12.36
# pct diff: 0.13
# next iteration: 1063
#
#
# current iteration: 1063
# diff: 2.61
# pct diff: 0.03
# next iteration: 1064
#
#
# current iteration: 1064
# diff: 4.63
# pct diff: 0.04
# next iteration: 1065
#
#
# current iteration: 1065
# diff: -8.96
# pct diff: -0.09
# next iteration: 1066
#
#
# current iteration: 1066
# diff: 3.4
# pct diff: 0.03
# next iteration: 1067
#
#
# current iteration: 1067
# diff: -3.2
# pct diff: -0.03
# next iteration: 1068
#
#
# current iteration: 1068
# diff: -1.68
# pct diff: -0.02
# next iteration: 1069
#
#
# current iteration: 1069
# diff: 2.05
# pct diff: 0.02
# next iteration: 1070
#
#
# current iteration: 1070
# diff: -3.09
# pct diff: -0.03
# next iteration: 1071
#
#
# current iteration: 1071
# diff: 5.7
# pct diff: 0.06
# next iteration: 1072
#
#
# current iteration: 1072
# diff: 1.66
# pct diff: 0.02
# next iteration: 1073
#
#
# current iteration: 1073
# diff: -0.17
# pct diff: -0.0
# next iteration: 1074
#
#
# current iteration: 1074
# diff: 3.43
# pct diff: 0.03
# next iteration: 1075
#
#
# current iteration: 1075
# diff: -1.0
# pct diff: -0.01
# next iteration: 1076
#
#
# current iteration: 1076
# diff: 2.53
# pct diff: 0.02
# next iteration: 1077
#
#
# current iteration: 1077
# diff: -2.66
# pct diff: -0.03
# next iteration: 1078
#
#
# current iteration: 1078
# diff: -1.35
# pct diff: -0.01
# next iteration: 1079
#
#
# current iteration: 1079
# diff: 4.61
# pct diff: 0.04
# next iteration: 1080
#
#
# current iteration: 1080
# diff: -4.37
# pct diff: -0.04
# next iteration: 1081
#
#
# current iteration: 1081
# diff: -1.72
# pct diff: -0.02
# next iteration: 1082
#
#
# current iteration: 1082
# diff: 0.45
# pct diff: 0.0
# next iteration: 1083
#
#
# current iteration: 1083
# diff: 0.01
# pct diff: 0.0
# next iteration: 1084
#
#
# current iteration: 1084
# diff: 0.19
# pct diff: 0.0
# next iteration: 1085
#
#
# current iteration: 1085
# diff: 4.87
# pct diff: 0.05
# next iteration: 1086
#
#
# current iteration: 1086
# diff: 0.15
# pct diff: 0.0
# next iteration: 1087
#
#
# current iteration: 1087
# diff: 6.04
# pct diff: 0.05
# next iteration: 1088
#
#
# current iteration: 1088
# diff: -4.1
# pct diff: -0.04
# next iteration: 1089
#
#
# current iteration: 1089
# diff: -2.65
# pct diff: -0.03
# next iteration: 1090
#
#
# current iteration: 1090
# diff: -2.32
# pct diff: -0.02
# next iteration: 1091
#
#
# current iteration: 1091
# diff: -2.12
# pct diff: -0.02
# next iteration: 1092
#
#
# current iteration: 1092
# diff: -0.18
# pct diff: -0.0
# next iteration: 1093
#
#
# current iteration: 1093
# diff: 4.69
# pct diff: 0.04
# next iteration: 1094
#
#
# current iteration: 1094
# diff: 3.59
# pct diff: 0.03
# next iteration: 1095
#
#
# current iteration: 1095
# diff: -1.39
# pct diff: -0.01
# next iteration: 1096
#
#
# current iteration: 1096
# diff: -3.21
# pct diff: -0.03
# next iteration: 1097
#
#
# current iteration: 1097
# diff: -1.64
# pct diff: -0.02
# next iteration: 1098
#
#
# current iteration: 1098
# diff: 2.99
# pct diff: 0.03
# next iteration: 1099
#
#
# current iteration: 1099
# diff: 3.14
# pct diff: 0.03
# next iteration: 1100
#
#
# current iteration: 1100
# diff: 7.8
# pct diff: 0.07
# next iteration: 1101
#
#
# current iteration: 1101
# diff: -2.48
# pct diff: -0.02
# next iteration: 1102
#
#
# current iteration: 1102
# diff: 5.55
# pct diff: 0.05
# next iteration: 1103
#
#
# current iteration: 1103
# diff: -2.09
# pct diff: -0.02
# next iteration: 1104
#
#
# current iteration: 1104
# diff: 0.19
# pct diff: 0.0
# next iteration: 1105
#
#
# current iteration: 1105
# diff: 2.93
# pct diff: 0.02
# next iteration: 1106
#
#
# current iteration: 1106
# diff: 0.58
# pct diff: 0.0
# next iteration: 1107
#
#
# current iteration: 1107
# diff: -4.78
# pct diff: -0.04
# next iteration: 1108
#
#
# current iteration: 1108
# diff: 0.55
# pct diff: 0.0
# next iteration: 1109
#
#
# current iteration: 1109
# diff: 1.47
# pct diff: 0.01
# next iteration: 1110
#
#
# current iteration: 1110
# diff: -0.02
# pct diff: -0.0
# next iteration: 1111
#
#
# current iteration: 1111
# diff: 3.43
# pct diff: 0.03
# next iteration: 1112
#
#
# current iteration: 1112
# diff: 1.51
# pct diff: 0.01
# next iteration: 1113
#
#
# current iteration: 1113
# diff: 1.13
# pct diff: 0.01
# next iteration: 1114
#
#
# current iteration: 1114
# diff: 2.46
# pct diff: 0.02
# next iteration: 1115
#
#
# current iteration: 1115
# diff: -3.39
# pct diff: -0.03
# next iteration: 1116
#
#
# current iteration: 1116
# diff: -1.71
# pct diff: -0.01
# next iteration: 1117
#
#
# current iteration: 1117
# diff: -9.54
# pct diff: -0.08
# next iteration: 1118
#
#
# current iteration: 1118
# diff: 2.85
# pct diff: 0.02
# next iteration: 1119
#
#
# current iteration: 1119
# diff: 1.59
# pct diff: 0.01
# next iteration: 1120
#
#
# current iteration: 1120
# diff: 1.36
# pct diff: 0.01
# next iteration: 1121
#
#
# current iteration: 1121
# diff: -0.79
# pct diff: -0.01
# next iteration: 1122
#
#
# current iteration: 1122
# diff: 0.72
# pct diff: 0.01
# next iteration: 1123
#
#
# current iteration: 1123
# diff: -4.02
# pct diff: -0.04
# next iteration: 1124
#
#
# current iteration: 1124
# diff: 1.57
# pct diff: 0.01
# next iteration: 1125
#
#
# current iteration: 1125
# diff: 0.67
# pct diff: 0.01
# next iteration: 1126
#
#
# current iteration: 1126
# diff: -4.52
# pct diff: -0.04
# next iteration: 1127
#
#
# current iteration: 1127
# diff: -0.71
# pct diff: -0.01
# next iteration: 1128
#
#
# current iteration: 1128
# diff: -2.26
# pct diff: -0.02
# next iteration: 1129
#
#
# current iteration: 1129
# diff: 2.42
# pct diff: 0.02
# next iteration: 1130
#
#
# current iteration: 1130
# diff: -0.01
# pct diff: -0.0
# next iteration: 1131
#
#
# current iteration: 1131
# diff: 1.5
# pct diff: 0.01
# next iteration: 1132
#
#
# current iteration: 1132
# diff: -0.83
# pct diff: -0.01
# next iteration: 1133
#
#
# current iteration: 1133
# diff: 2.25
# pct diff: 0.02
# next iteration: 1134
#
#
# current iteration: 1134
# diff: -0.8
# pct diff: -0.01
# next iteration: 1135
#
#
# current iteration: 1135
# diff: 3.03
# pct diff: 0.03
# next iteration: 1136
#
#
# current iteration: 1136
# diff: 0.15
# pct diff: 0.0
# next iteration: 1137
#
#
# current iteration: 1137
# diff: 2.53
# pct diff: 0.02
# next iteration: 1138
#
#
# current iteration: 1138
# diff: -3.12
# pct diff: -0.03
# next iteration: 1139
#
#
# current iteration: 1139
# diff: 2.44
# pct diff: 0.02
# next iteration: 1140
#
#
# current iteration: 1140
# diff: 2.24
# pct diff: 0.02
# next iteration: 1141
#
#
# current iteration: 1141
# diff: -1.47
# pct diff: -0.01
# next iteration: 1142
#
#
# current iteration: 1142
# diff: -0.78
# pct diff: -0.01
# next iteration: 1143
#
#
# current iteration: 1143
# diff: -0.86
# pct diff: -0.01
# next iteration: 1144
#
#
# current iteration: 1144
# diff: 0.83
# pct diff: 0.01
# next iteration: 1145
#
#
# current iteration: 1145
# diff: 0.41
# pct diff: 0.0
# next iteration: 1146
#
#
# current iteration: 1146
# diff: -0.91
# pct diff: -0.01
# next iteration: 1147
#
#
# current iteration: 1147
# diff: -0.51
# pct diff: -0.0
# next iteration: 1148
#
#
# current iteration: 1148
# diff: -1.3
# pct diff: -0.01
# next iteration: 1149
#
#
# current iteration: 1149
# diff: -0.13
# pct diff: -0.0
# next iteration: 1150
#
#
# current iteration: 1150
# diff: -0.57
# pct diff: -0.0
# next iteration: 1151
#
#
# current iteration: 1151
# diff: 0.05
# pct diff: 0.0
# next iteration: 1152
#
#
# current iteration: 1152
# diff: 1.28
# pct diff: 0.01
# next iteration: 1153
#
#
# current iteration: 1153
# diff: -0.59
# pct diff: -0.01
# next iteration: 1154
#
#
# current iteration: 1154
# diff: 0.94
# pct diff: 0.01
# next iteration: 1155
#
#
# current iteration: 1155
# diff: 10.32
# pct diff: 0.08
# next iteration: 1156
#
#
# current iteration: 1156
# diff: 3.21
# pct diff: 0.02
# next iteration: 1157
#
#
# current iteration: 1157
# diff: -0.89
# pct diff: -0.01
# next iteration: 1158
#
#
# current iteration: 1158
# diff: -1.14
# pct diff: -0.01
# next iteration: 1159
#
#
# current iteration: 1159
# diff: 1.7
# pct diff: 0.01
# next iteration: 1160
#
#
# current iteration: 1160
# diff: 1.3
# pct diff: 0.01
# next iteration: 1161
#
#
# current iteration: 1161
# diff: -0.83
# pct diff: -0.01
# next iteration: 1162
#
#
# current iteration: 1162
# diff: -0.43
# pct diff: -0.0
# next iteration: 1163
#
#
# current iteration: 1163
# diff: -1.16
# pct diff: -0.01
# next iteration: 1164
#
#
# current iteration: 1164
# diff: -0.45
# pct diff: -0.0
# next iteration: 1165
#
#
# current iteration: 1165
# diff: -1.15
# pct diff: -0.01
# next iteration: 1166
#
#
# current iteration: 1166
# diff: 0.35
# pct diff: 0.0
# next iteration: 1167
#
#
# current iteration: 1167
# diff: -0.68
# pct diff: -0.01
# next iteration: 1168
#
#
# current iteration: 1168
# diff: 3.25
# pct diff: 0.02
# next iteration: 1169
#
#
# current iteration: 1169
# diff: -0.9
# pct diff: -0.01
# next iteration: 1170
#
#
# current iteration: 1170
# diff: 2.39
# pct diff: 0.02
# next iteration: 1171
#
#
# current iteration: 1171
# diff: 1.55
# pct diff: 0.01
# next iteration: 1172
#
#
# current iteration: 1172
# diff: 1.81
# pct diff: 0.01
# next iteration: 1173
#
#
# current iteration: 1173
# diff: -3.67
# pct diff: -0.03
# next iteration: 1174
#
#
# current iteration: 1174
# diff: 1.68
# pct diff: 0.01
# next iteration: 1175
#
#
# current iteration: 1175
# diff: 1.84
# pct diff: 0.01
# next iteration: 1176
#
#
# current iteration: 1176
# diff: -2.15
# pct diff: -0.02
# next iteration: 1177
#
#
# current iteration: 1177
# diff: -1.25
# pct diff: -0.01
# next iteration: 1178
#
#
# current iteration: 1178
# diff: 2.21
# pct diff: 0.02
# next iteration: 1179
#
#
# current iteration: 1179
# diff: -0.84
# pct diff: -0.01
# next iteration: 1180
#
#
# current iteration: 1180
# diff: -0.14
# pct diff: -0.0
# next iteration: 1181
#
#
# current iteration: 1181
# diff: -1.47
# pct diff: -0.01
# next iteration: 1182
#
#
# current iteration: 1182
# diff: -0.5
# pct diff: -0.0
# next iteration: 1183
#
#
# current iteration: 1183
# diff: -0.01
# pct diff: -0.0
# next iteration: 1184
#
#
# current iteration: 1184
# diff: 0.85
# pct diff: 0.01
# next iteration: 1185
#
#
# current iteration: 1185
# diff: -1.87
# pct diff: -0.01
# next iteration: 1186
#
#
# current iteration: 1186
# diff: -1.59
# pct diff: -0.01
# next iteration: 1187
#
#
# current iteration: 1187
# diff: -3.22
# pct diff: -0.03
# next iteration: 1188
#
#
# current iteration: 1188
# diff: 1.8
# pct diff: 0.01
# next iteration: 1189
#
#
# current iteration: 1189
# diff: -3.93
# pct diff: -0.03
# next iteration: 1190
#
#
# current iteration: 1190
# diff: -0.79
# pct diff: -0.01
# next iteration: 1191
#
#
# current iteration: 1191
# diff: 1.51
# pct diff: 0.01
# next iteration: 1192
#
#
# current iteration: 1192
# diff: 1.99
# pct diff: 0.02
# next iteration: 1193
#
#
# current iteration: 1193
# diff: -0.59
# pct diff: -0.0
# next iteration: 1194
#
#
# current iteration: 1194
# diff: -1.32
# pct diff: -0.01
# next iteration: 1195
#
#
# current iteration: 1195
# diff: -0.77
# pct diff: -0.01
# next iteration: 1196
#
#
# current iteration: 1196
# diff: -0.76
# pct diff: -0.01
# next iteration: 1197
#
#
# current iteration: 1197
# diff: 0.82
# pct diff: 0.01
# next iteration: 1198
#
#
# current iteration: 1198
# diff: -2.44
# pct diff: -0.02
# next iteration: 1199
#
#
# current iteration: 1199
# diff: 1.98
# pct diff: 0.02
# next iteration: 1200
#
#
# current iteration: 1200
# diff: 0.18
# pct diff: 0.0
# next iteration: 1201
#
#
# current iteration: 1201
# diff: 1.89
# pct diff: 0.02
# next iteration: 1202
#
#
# current iteration: 1202
# diff: -0.01
# pct diff: -0.0
# next iteration: 1203
#
#
# current iteration: 1203
# diff: 3.99
# pct diff: 0.03
# next iteration: 1204
#
#
# current iteration: 1204
# diff: -2.37
# pct diff: -0.02
# next iteration: 1205
#
#
# current iteration: 1205
# diff: 0.77
# pct diff: 0.01
# next iteration: 1206
#
#
# current iteration: 1206
# diff: -0.55
# pct diff: -0.0
# next iteration: 1207
#
#
# current iteration: 1207
# diff: -2.58
# pct diff: -0.02
# next iteration: 1208
#
#
# current iteration: 1208
# diff: 0.72
# pct diff: 0.01
# next iteration: 1209
#
#
# current iteration: 1209
# diff: 1.68
# pct diff: 0.01
# next iteration: 1210
#
#
# current iteration: 1210
# diff: 0.93
# pct diff: 0.01
# next iteration: 1211
#
#
# current iteration: 1211
# diff: 0.79
# pct diff: 0.01
# next iteration: 1212
#
#
# current iteration: 1212
# diff: -4.29
# pct diff: -0.03
# next iteration: 1213
#
#
# current iteration: 1213
# diff: -0.75
# pct diff: -0.01
# next iteration: 1214
#
#
# current iteration: 1214
# diff: -4.84
# pct diff: -0.04
# next iteration: 1215
#
#
# current iteration: 1215
# diff: 3.07
# pct diff: 0.03
# next iteration: 1216
#
#
# current iteration: 1216
# diff: -0.29
# pct diff: -0.0
# next iteration: 1217
#
#
# current iteration: 1217
# diff: -1.12
# pct diff: -0.01
# next iteration: 1218
#
#
# current iteration: 1218
# diff: 3.89
# pct diff: 0.03
# next iteration: 1219
#
#
# current iteration: 1219
# diff: 1.05
# pct diff: 0.01
# next iteration: 1220
#
#
# current iteration: 1220
# diff: 1.89
# pct diff: 0.01
# next iteration: 1221
#
#
# current iteration: 1221
# diff: 0.5
# pct diff: 0.0
# next iteration: 1222
#
#
# current iteration: 1222
# diff: 15.13
# pct diff: 0.11
# next iteration: 1223
#
#
# current iteration: 1223
# diff: -0.48
# pct diff: -0.0
# next iteration: 1224
#
#
# current iteration: 1224
# diff: -4.29
# pct diff: -0.03
# next iteration: 1225
#
#
# current iteration: 1225
# diff: -2.3
# pct diff: -0.02
# next iteration: 1226
#
#
# current iteration: 1226
# diff: 2.84
# pct diff: 0.02
# next iteration: 1227
#
#
# current iteration: 1227
# diff: 6.31
# pct diff: 0.04
# next iteration: 1228
#
#
# current iteration: 1228
# diff: -0.17
# pct diff: -0.0
# next iteration: 1229
#
#
# current iteration: 1229
# diff: -0.6
# pct diff: -0.0
# next iteration: 1230
#
#
# current iteration: 1230
# diff: -2.18
# pct diff: -0.02
# next iteration: 1231
#
#
# current iteration: 1231
# diff: -0.65
# pct diff: -0.0
# next iteration: 1232
#
#
# current iteration: 1232
# diff: 4.91
# pct diff: 0.03
# next iteration: 1233
#
#
# current iteration: 1233
# diff: 5.51
# pct diff: 0.04
# next iteration: 1234
#
#
# current iteration: 1234
# diff: -2.4
# pct diff: -0.02
# next iteration: 1235
#
#
# current iteration: 1235
# diff: -1.96
# pct diff: -0.01
# next iteration: 1236
#
#
# current iteration: 1236
# diff: 0.88
# pct diff: 0.01
# next iteration: 1237
#
#
# current iteration: 1237
# diff: 1.43
# pct diff: 0.01
# next iteration: 1238
#
#
# current iteration: 1238
# diff: 4.17
# pct diff: 0.03
# next iteration: 1239
#
#
# current iteration: 1239
# diff: -0.37
# pct diff: -0.0
# next iteration: 1240
#
#
# current iteration: 1240
# diff: 0.9
# pct diff: 0.01
# next iteration: 1241
#
#
# current iteration: 1241
# diff: -0.46
# pct diff: -0.0
# next iteration: 1242
#
#
# current iteration: 1242
# diff: 0.04
# pct diff: 0.0
# next iteration: 1243
#
#
# current iteration: 1243
# diff: 0.71
# pct diff: 0.0
# next iteration: 1244
#
#
# current iteration: 1244
# diff: 0.26
# pct diff: 0.0
# next iteration: 1245
#
#
# current iteration: 1245
# diff: 21.03
# pct diff: 0.12
# next iteration: 1246
#
#
# current iteration: 1246
# diff: -6.42
# pct diff: -0.04
# next iteration: 1247
#
#
# current iteration: 1247
# diff: 4.64
# pct diff: 0.03
# next iteration: 1248
#
#
# current iteration: 1248
# diff: -0.82
# pct diff: -0.0
# next iteration: 1249
#
#
# current iteration: 1249
# diff: 0.43
# pct diff: 0.0
# next iteration: 1250
#
#
# current iteration: 1250
# diff: -0.66
# pct diff: -0.0
# next iteration: 1251
#
#
# current iteration: 1251
# diff: -2.2
# pct diff: -0.01
# next iteration: 1252
#
#
# current iteration: 1252
# diff: -0.24
# pct diff: -0.0
# next iteration: 1253
#
#
# current iteration: 1253
# diff: 3.1
# pct diff: 0.02
# next iteration: 1254
#
#
# current iteration: 1254
# diff: 0.18
# pct diff: 0.0
# next iteration: 1255
#
#
# current iteration: 1255
# diff: 5.13
# pct diff: 0.03
# next iteration: 1256
#
#
# current iteration: 1256
# diff: -1.56
# pct diff: -0.01
# next iteration: 1257
#
#
# current iteration: 1257
# diff: 3.87
# pct diff: 0.02
# next iteration: 1258

# %%
# containers for returns by day of the week and year
mon_2016 = []
tue_2016 = []
wed_2016 = []
thu_2016 = []
fri_2016 = []

mon_2017 = []
tue_2017 = []
wed_2017 = []
thu_2017 = []
fri_2017 = []

mon_2018 = []
tue_2018 = []
wed_2018 = []
thu_2018 = []
fri_2018 = []

mon_2019 = []
tue_2019 = []
wed_2019 = []
thu_2019 = []
fri_2019 = []

mon_2020 = []
tue_2020 = []
wed_2020 = []
thu_2020 = []
fri_2020 = []

# %%
for i in range(len(ac_l)):
    
    year = year_l[i]
    weekday = weekday_l[i]
    ret = pct_diff_l[i]
    
    # 2016
    if year == '2016' and weekday == 'Monday':
        mon_2016.append(ret)
    if year == '2016' and weekday == 'Tuesday':
        tue_2016.append(ret)
    if year == '2016' and weekday == 'Wednesday':
        wed_2016.append(ret)
    if year == '2016' and weekday == 'Thursday':
        thu_2016.append(ret)
    if year == '2016' and weekday == 'Friday':
        fri_2016.append(ret)
    
    # 2017       
    if year == '2017' and weekday == 'Monday':
        mon_2017.append(ret)
    if year == '2017' and weekday == 'Tuesday':
        tue_2017.append(ret)
    if year == '2017' and weekday == 'Wednesday':
        wed_2017.append(ret)       
    if year == '2017' and weekday == 'Thursday':
        thu_2017.append(ret)
    if year == '2017' and weekday == 'Friday':
        fri_2017.append(ret)
        
     # 2018       
    if year == '2018' and weekday == 'Monday':
        mon_2018.append(ret)
    if year == '2018' and weekday == 'Tuesday':
        tue_2018.append(ret)
    if year == '2018' and weekday == 'Wednesday':
        wed_2018.append(ret)
    if year == '2018' and weekday == 'Thursday':
        thu_2018.append(ret)
    if year == '2018' and weekday == 'Friday':
        fri_2018.append(ret)
        
    # 2019       
    if year == '2019' and weekday == 'Monday':
        mon_2019.append(ret)
    if year == '2019' and weekday == 'Tuesday':
        tue_2019.append(ret)
    if year == '2019' and weekday == 'Wednesday':
        wed_2019.append(ret)
    if year == '2019' and weekday == 'Thursday':
        thu_2019.append(ret)
    if year == '2019' and weekday == 'Friday':
        fri_2019.append(ret)
        
    # 2020       
    if year == '2020' and weekday == 'Monday':
        mon_2020.append(ret)
    if year == '2020' and weekday == 'Tuesday':
        tue_2020.append(ret)
    if year == '2020' and weekday == 'Wednesday':
        wed_2020.append(ret)
    if year == '2020' and weekday == 'Thursday':
        thu_2020.append(ret)
    if year == '2020' and weekday == 'Friday':
        fri_2020.append(ret)

# %%
# containers for returns by day of the week, year, and sign of the return

# 2016
mon_2016_pos = [x for x in mon_2016 if x > 0]
tue_2016_pos = [x for x in tue_2016 if x > 0]
wed_2016_pos = [x for x in wed_2016 if x > 0]
thu_2016_pos = [x for x in thu_2016 if x > 0]
fri_2016_pos = [x for x in fri_2016 if x > 0]

mon_2016_neg = [x for x in mon_2016 if x < 0]
tue_2016_neg = [x for x in tue_2016 if x < 0]
wed_2016_neg = [x for x in wed_2016 if x < 0]
thu_2016_neg = [x for x in thu_2016 if x < 0]
fri_2016_neg = [x for x in fri_2016 if x < 0] 

# 2017
mon_2017_pos = [x for x in mon_2017 if x > 0]
tue_2017_pos = [x for x in tue_2017 if x > 0]
wed_2017_pos = [x for x in wed_2017 if x > 0]
thu_2017_pos = [x for x in thu_2017 if x > 0]
fri_2017_pos = [x for x in fri_2017 if x > 0]

mon_2017_neg = [x for x in mon_2017 if x < 0]
tue_2017_neg = [x for x in tue_2017 if x < 0]
wed_2017_neg = [x for x in wed_2017 if x < 0]
thu_2017_neg = [x for x in thu_2017 if x < 0]
fri_2017_neg = [x for x in fri_2017 if x < 0] 

# 2018
mon_2018_pos = [x for x in mon_2018 if x > 0]
tue_2018_pos = [x for x in tue_2018 if x > 0]
wed_2018_pos = [x for x in wed_2018 if x > 0]
thu_2018_pos = [x for x in thu_2018 if x > 0]
fri_2018_pos = [x for x in fri_2018 if x > 0]

mon_2018_neg = [x for x in mon_2018 if x < 0]
tue_2018_neg = [x for x in tue_2018 if x < 0]
wed_2018_neg = [x for x in wed_2018 if x < 0]
thu_2018_neg = [x for x in thu_2018 if x < 0]
fri_2018_neg = [x for x in fri_2018 if x < 0] 

# 2019
mon_2019_pos = [x for x in mon_2019 if x > 0]
tue_2019_pos = [x for x in tue_2019 if x > 0]
wed_2019_pos = [x for x in wed_2019 if x > 0]
thu_2019_pos = [x for x in thu_2019 if x > 0]
fri_2019_pos = [x for x in fri_2019 if x > 0]

mon_2019_neg = [x for x in mon_2019 if x < 0]
tue_2019_neg = [x for x in tue_2019 if x < 0]
wed_2019_neg = [x for x in wed_2019 if x < 0]
thu_2019_neg = [x for x in thu_2019 if x < 0]
fri_2019_neg = [x for x in fri_2019 if x < 0]

# 2020
mon_2020_pos = [x for x in mon_2020 if x > 0]
tue_2020_pos = [x for x in tue_2020 if x > 0]
wed_2020_pos = [x for x in wed_2020 if x > 0]
thu_2020_pos = [x for x in thu_2020 if x > 0]
fri_2020_pos = [x for x in fri_2020 if x > 0]

mon_2020_neg = [x for x in mon_2020 if x < 0]
tue_2020_neg = [x for x in tue_2020 if x < 0]
wed_2020_neg = [x for x in wed_2020 if x < 0]
thu_2020_neg = [x for x in thu_2020 if x < 0]
fri_2020_neg = [x for x in fri_2020 if x < 0]

# %%
# calculate mean and standard deviation of returns by day of the week and by year

# 2016 
avg_mon_2016 = stats.mean(mon_2016)
stdev_mon_2016 = stats.stdev(mon_2016)

avg_tue_2016 = stats.mean(tue_2016)
stdev_tue_2016 = stats.stdev(tue_2016)

avg_wed_2016 = stats.mean(wed_2016)
stdev_wed_2016 = stats.stdev(wed_2016)

avg_thu_2016 = stats.mean(thu_2016)
stdev_thu_2016 = stats.stdev(thu_2016)

avg_fri_2016 = stats.mean(fri_2016)
stdev_fri_2016 = stats.stdev(fri_2016)

# 2017 
avg_mon_2017 = stats.mean(mon_2017)
stdev_mon_2017 = stats.stdev(mon_2017)

avg_tue_2017 = stats.mean(tue_2017)
stdev_tue_2017 = stats.stdev(tue_2017)

avg_wed_2017 = stats.mean(wed_2017)
stdev_wed_2017 = stats.stdev(wed_2017)

avg_thu_2017 = stats.mean(thu_2017)
stdev_thu_2017 = stats.stdev(thu_2017)

avg_fri_2017 = stats.mean(fri_2017)
stdev_fri_2017 = stats.stdev(fri_2017)

# 2018 
avg_mon_2018 = stats.mean(mon_2018)
stdev_mon_2018 = stats.stdev(mon_2018)

avg_tue_2018 = stats.mean(tue_2018)
stdev_tue_2018 = stats.stdev(tue_2018)

avg_wed_2018 = stats.mean(wed_2018)
stdev_wed_2018 = stats.stdev(wed_2018)

avg_thu_2018 = stats.mean(thu_2018)
stdev_thu_2018 = stats.stdev(thu_2018)

avg_fri_2018 = stats.mean(fri_2018)
stdev_fri_2018 = stats.stdev(fri_2018)

# 2019 
avg_mon_2019 = stats.mean(mon_2019)
stdev_mon_2019 = stats.stdev(mon_2019)

avg_tue_2019 = stats.mean(tue_2019)
stdev_tue_2019 = stats.stdev(tue_2019)

avg_wed_2019 = stats.mean(wed_2019)
stdev_wed_2019 = stats.stdev(wed_2019)

avg_thu_2019 = stats.mean(thu_2019)
stdev_thu_2019 = stats.stdev(thu_2019)

avg_fri_2019 = stats.mean(fri_2019)
stdev_fri_2019 = stats.stdev(fri_2019)

# 2020
avg_mon_2020 = stats.mean(mon_2020)
stdev_mon_2020 = stats.stdev(mon_2020)

avg_tue_2020 = stats.mean(tue_2020)
stdev_tue_2020 = stats.stdev(tue_2020)

avg_wed_2020 = stats.mean(wed_2020)
stdev_wed_2020 = stats.stdev(wed_2020)

avg_thu_2020 = stats.mean(thu_2020)
stdev_thu_2020 = stats.stdev(thu_2020)

avg_fri_2020 = stats.mean(fri_2020)
stdev_fri_2020 = stats.stdev(fri_2020)

# %%
# calculate average returns and length

# 2016 - positive returns
avg_mon_2016_pos = stats.mean(mon_2016_pos)
num_mon_2016_pos = len(mon_2016_pos)
stdev_mon_2016_pos = stats.stdev(mon_2016_pos)

avg_tue_2016_pos = stats.mean(tue_2016_pos)
num_tue_2016_pos = len(tue_2016_pos)
stdev_tue_2016_pos = stats.stdev(tue_2016_pos)

avg_wed_2016_pos = stats.mean(wed_2016_pos)
num_wed_2016_pos = len(wed_2016_pos)
stdev_wed_2016_pos = stats.stdev(wed_2016_pos)

avg_thu_2016_pos = stats.mean(thu_2016_pos)
num_thu_2016_pos = len(thu_2016_pos)
stdev_thu_2016_pos = stats.stdev(thu_2016_pos)

avg_fri_2016_pos = stats.mean(fri_2016_pos)
num_fri_2016_pos = len(fri_2016_pos)
stdev_fri_2016_pos = stats.stdev(fri_2016_pos)

#2016 - negative returns
avg_mon_2016_neg = stats.mean(mon_2016_neg)
num_mon_2016_neg = len(mon_2016_neg)
stdev_mon_2016_neg = stats.stdev(mon_2016_neg)

avg_tue_2016_neg = stats.mean(tue_2016_neg)
num_tue_2016_neg = len(tue_2016_neg)
stdev_tue_2016_neg = stats.stdev(tue_2016_neg)

avg_wed_2016_neg = stats.mean(wed_2016_neg)
num_wed_2016_neg = len(wed_2016_neg)
stdev_wed_2016_neg = stats.stdev(wed_2016_neg)

avg_thu_2016_neg = stats.mean(thu_2016_neg)
num_thu_2016_neg = len(thu_2016_neg)
stdev_thu_2016_neg = stats.stdev(thu_2016_neg)

avg_fri_2016_neg = stats.mean(fri_2016_neg)
num_fri_2016_neg = len(fri_2016_neg)
stdev_fri_2016_neg = stats.stdev(fri_2016_neg)

# %%
# calculate average returns and length

# 2017 - positive returns
avg_mon_2017_pos = stats.mean(mon_2017_pos)
num_mon_2017_pos = len(mon_2017_pos)
stdev_mon_2017_pos = stats.stdev(mon_2017_pos)

avg_tue_2017_pos = stats.mean(tue_2017_pos)
num_tue_2017_pos = len(tue_2017_pos)
stdev_tue_2017_pos = stats.stdev(tue_2017_pos)

avg_wed_2017_pos = stats.mean(wed_2017_pos)
num_wed_2017_pos = len(wed_2017_pos)
stdev_wed_2017_pos = stats.stdev(wed_2017_pos)

avg_thu_2017_pos = stats.mean(thu_2017_pos)
num_thu_2017_pos = len(thu_2017_pos)
stdev_thu_2017_pos = stats.stdev(thu_2017_pos)

avg_fri_2017_pos = stats.mean(fri_2017_pos)
num_fri_2017_pos = len(fri_2017_pos)
stdev_fri_2017_pos = stats.stdev(fri_2017_pos)

#2017 - negative returns
avg_mon_2017_neg = stats.mean(mon_2017_neg)
num_mon_2017_neg = len(mon_2017_neg)
stdev_mon_2017_neg = stats.stdev(mon_2017_neg)

avg_tue_2017_neg = stats.mean(tue_2017_neg)
num_tue_2017_neg = len(tue_2017_neg)
stdev_tue_2017_neg = stats.stdev(tue_2017_neg)

avg_wed_2017_neg = stats.mean(wed_2017_neg)
num_wed_2017_neg = len(wed_2017_neg)
stdev_wed_2017_neg = stats.stdev(wed_2017_neg)

avg_thu_2017_neg = stats.mean(thu_2017_neg)
num_thu_2017_neg = len(thu_2017_neg)
stdev_thu_2017_neg = stats.stdev(thu_2017_neg)

avg_fri_2017_neg = stats.mean(fri_2017_neg)
num_fri_2017_neg = len(fri_2017_neg)
stdev_fri_2017_neg = stats.stdev(fri_2017_neg)

# %%
# calculate average returns and length

# 2018 - positive returns
avg_mon_2018_pos = stats.mean(mon_2018_pos)
num_mon_2018_pos = len(mon_2018_pos)
stdev_mon_2018_pos = stats.stdev(mon_2018_pos)

avg_tue_2018_pos = stats.mean(tue_2018_pos)
num_tue_2018_pos = len(tue_2018_pos)
stdev_tue_2018_pos = stats.stdev(tue_2018_pos)

avg_wed_2018_pos = stats.mean(wed_2018_pos)
num_wed_2018_pos = len(wed_2018_pos)
stdev_wed_2018_pos = stats.stdev(wed_2018_pos)

avg_thu_2018_pos = stats.mean(thu_2018_pos)
num_thu_2018_pos = len(thu_2018_pos)
stdev_thu_2018_pos = stats.stdev(thu_2018_pos)

avg_fri_2018_pos = stats.mean(fri_2018_pos)
num_fri_2018_pos = len(fri_2018_pos)
stdev_fri_2018_pos = stats.stdev(fri_2018_pos)

#2018 - negative returns
avg_mon_2018_neg = stats.mean(mon_2018_neg)
num_mon_2018_neg = len(mon_2018_neg)
stdev_mon_2018_neg = stats.stdev(mon_2018_neg)

avg_tue_2018_neg = stats.mean(tue_2018_neg)
num_tue_2018_neg = len(tue_2018_neg)
stdev_tue_2018_neg = stats.stdev(tue_2018_neg)

avg_wed_2018_neg = stats.mean(wed_2018_neg)
num_wed_2018_neg = len(wed_2018_neg)
stdev_wed_2018_neg = stats.stdev(wed_2018_neg)

avg_thu_2018_neg = stats.mean(thu_2018_neg)
num_thu_2018_neg = len(thu_2018_neg)
stdev_thu_2018_neg = stats.stdev(thu_2018_neg)

avg_fri_2018_neg = stats.mean(fri_2018_neg)
num_fri_2018_neg = len(fri_2018_neg)
stdev_fri_2018_neg = stats.stdev(fri_2018_neg)

# %%
# calculate average returns and length

# 2019 - positive returns
avg_mon_2019_pos = stats.mean(mon_2019_pos)
num_mon_2019_pos = len(mon_2019_pos)
stdev_mon_2019_pos = stats.stdev(mon_2019_pos)

avg_tue_2019_pos = stats.mean(tue_2019_pos)
num_tue_2019_pos = len(tue_2019_pos)
stdev_tue_2019_pos = stats.stdev(tue_2019_pos)

avg_wed_2019_pos = stats.mean(wed_2019_pos)
num_wed_2019_pos = len(wed_2019_pos)
stdev_wed_2019_pos = stats.stdev(wed_2019_pos)

avg_thu_2019_pos = stats.mean(thu_2019_pos)
num_thu_2019_pos = len(thu_2019_pos)
stdev_thu_2019_pos = stats.stdev(thu_2019_pos)

avg_fri_2019_pos = stats.mean(fri_2019_pos)
num_fri_2019_pos = len(fri_2019_pos)
stdev_fri_2019_pos = stats.stdev(fri_2019_pos)

#2019 - negative returns
avg_mon_2019_neg = stats.mean(mon_2019_neg)
num_mon_2019_neg = len(mon_2019_neg)
stdev_mon_2019_neg = stats.stdev(mon_2019_neg)

avg_tue_2019_neg = stats.mean(tue_2019_neg)
num_tue_2019_neg = len(tue_2019_neg)
stdev_tue_2019_neg = stats.stdev(tue_2019_neg)

avg_wed_2019_neg = stats.mean(wed_2019_neg)
num_wed_2019_neg = len(wed_2019_neg)
stdev_wed_2019_neg = stats.stdev(wed_2019_neg)

avg_thu_2019_neg = stats.mean(thu_2019_neg)
num_thu_2019_neg = len(thu_2019_neg)
stdev_thu_2019_neg = stats.stdev(thu_2019_neg)

avg_fri_2019_neg = stats.mean(fri_2019_neg)
num_fri_2019_neg = len(fri_2019_neg)
stdev_fri_2019_neg = stats.stdev(fri_2019_neg)

# %%
# calculate average returns and length

# 2020 - positive returns
avg_mon_2020_pos = stats.mean(mon_2020_pos)
num_mon_2020_pos = len(mon_2020_pos)
stdev_mon_2020_pos = stats.stdev(mon_2020_pos)

avg_tue_2020_pos = stats.mean(tue_2020_pos)
num_tue_2020_pos = len(tue_2020_pos)
stdev_tue_2020_pos = stats.stdev(tue_2020_pos)

avg_wed_2020_pos = stats.mean(wed_2020_pos)
num_wed_2020_pos = len(wed_2020_pos)
stdev_wed_2020_pos = stats.stdev(wed_2020_pos)

avg_thu_2020_pos = stats.mean(thu_2020_pos)
num_thu_2020_pos = len(thu_2020_pos)
stdev_thu_2020_pos = stats.stdev(thu_2020_pos)

avg_fri_2020_pos = stats.mean(fri_2020_pos)
num_fri_2020_pos = len(fri_2020_pos)
stdev_fri_2020_pos = stats.stdev(fri_2020_pos)

#2020 - negative returns
avg_mon_2020_neg = stats.mean(mon_2020_neg)
num_mon_2020_neg = len(mon_2020_neg)
stdev_mon_2020_neg = stats.stdev(mon_2020_neg)

avg_tue_2020_neg = stats.mean(tue_2020_neg)
num_tue_2020_neg = len(tue_2020_neg)
stdev_tue_2020_neg = stats.stdev(tue_2020_neg)

avg_wed_2020_neg = stats.mean(wed_2020_neg)
num_wed_2020_neg = len(wed_2020_neg)
stdev_wed_2020_neg = stats.stdev(wed_2020_neg)

avg_thu_2020_neg = stats.mean(thu_2020_neg)
num_thu_2020_neg = len(thu_2020_neg)
stdev_thu_2020_neg = stats.stdev(thu_2020_neg)

avg_fri_2020_neg = stats.mean(fri_2020_neg)
num_fri_2020_neg = len(fri_2020_neg)
stdev_fri_2020_neg = stats.stdev(fri_2020_neg)

# %% [markdown]
# #### Create a summary table

# %%
# create a dataframe with all the results per year
cols = ['day','avg_return','stdev_return','num_neg','avg_neg','stdev_neg','num_pos','avg_pos','stdev_pos']

# 2016
res_2016 = pd.DataFrame(columns=cols)
res_2016['day'] = ['Mon','Tue','Wed','Thu','Fri']

res_2016['avg_return'] = [avg_mon_2016, avg_tue_2016, avg_wed_2016, avg_thu_2016, avg_fri_2016]

res_2016['stdev_return'] = [stdev_mon_2016, stdev_tue_2016, stdev_wed_2016, stdev_thu_2016, stdev_fri_2016]

res_2016['num_neg'] = [num_mon_2016_neg,
                       num_tue_2016_neg,
                       num_wed_2016_neg,
                       num_thu_2016_neg,
                       num_fri_2016_neg]

res_2016['avg_neg'] = [avg_mon_2016_neg,
                       avg_tue_2016_neg,
                       avg_wed_2016_neg,
                       avg_thu_2016_neg,
                       avg_fri_2016_neg]

res_2016['stdev_neg'] = [stdev_mon_2016_neg,
                       stdev_tue_2016_neg,
                       stdev_wed_2016_neg,
                       stdev_thu_2016_neg,
                       stdev_fri_2016_neg]

res_2016['num_pos'] = [num_mon_2016_pos,
                       num_tue_2016_pos,
                       num_wed_2016_pos,
                       num_thu_2016_pos,
                       num_fri_2016_pos]

res_2016['avg_pos'] = [avg_mon_2016_pos,
                       avg_tue_2016_pos,
                       avg_wed_2016_pos,
                       avg_thu_2016_pos,
                       avg_fri_2016_pos]

res_2016['stdev_pos'] = [stdev_mon_2016_pos,
                       stdev_tue_2016_pos,
                       stdev_wed_2016_pos,
                       stdev_thu_2016_pos,
                       stdev_fri_2016_pos]

# %%
res_2016.head()
# Out:
#    day  avg_return  stdev_return  num_neg   avg_neg  stdev_neg  num_pos  \
# 0  Mon    0.000435      0.009651       12 -0.011667   0.003892       13
# 1  Tue   -0.000962      0.010148       17 -0.012353   0.004372       12
# 2  Wed   -0.000962      0.013174       15 -0.016667   0.011127       16
# 3  Thu    0.001569      0.008336        9 -0.010000   0.000000       12
# 4  Fri    0.000196      0.013637       10 -0.019000   0.015951       15
#
#     avg_pos  stdev_pos
# 0  0.012308   0.005991
# 1  0.013333   0.004924
# 2  0.012500   0.005774
# 3  0.014167   0.005149
# 4  0.013333   0.007237

# %%
# create a dataframe with all the results per year
cols = ['day','avg_return','stdev_return','num_neg','avg_neg','stdev_neg','num_pos','avg_pos','stdev_pos']

# 2017
res_2017 = pd.DataFrame(columns=cols)
res_2017['day'] = ['Mon','Tue','Wed','Thu','Fri']

res_2017['avg_return'] = [avg_mon_2017, avg_tue_2017, avg_wed_2017, avg_thu_2017, avg_fri_2017]

res_2017['stdev_return'] = [stdev_mon_2017, stdev_tue_2017, stdev_wed_2017, stdev_thu_2017, stdev_fri_2017]

res_2017['num_neg'] = [num_mon_2017_neg,
                       num_tue_2017_neg,
                       num_wed_2017_neg,
                       num_thu_2017_neg,
                       num_fri_2017_neg]

res_2017['avg_neg'] = [avg_mon_2017_neg,
                       avg_tue_2017_neg,
                       avg_wed_2017_neg,
                       avg_thu_2017_neg,
                       avg_fri_2017_neg]

res_2017['stdev_neg'] = [stdev_mon_2017_neg,
                       stdev_tue_2017_neg,
                       stdev_wed_2017_neg,
                       stdev_thu_2017_neg,
                       stdev_fri_2017_neg]

res_2017['num_pos'] = [num_mon_2017_pos,
                       num_tue_2017_pos,
                       num_wed_2017_pos,
                       num_thu_2017_pos,
                       num_fri_2017_pos]

res_2017['avg_pos'] = [avg_mon_2017_pos,
                       avg_tue_2017_pos,
                       avg_wed_2017_pos,
                       avg_thu_2017_pos,
                       avg_fri_2017_pos]

res_2017['stdev_pos'] = [stdev_mon_2017_pos,
                       stdev_tue_2017_pos,
                       stdev_wed_2017_pos,
                       stdev_thu_2017_pos,
                       stdev_fri_2017_pos]

# %%
res_2017.head()
# Out:
#    day  avg_return  stdev_return  num_neg   avg_neg  stdev_neg  num_pos  \
# 0  Mon    0.001304      0.011077       13 -0.010000   0.000000       13
# 1  Tue    0.001176      0.009518       11 -0.012727   0.006467       18
# 2  Wed   -0.000769      0.011175       10 -0.020000   0.008165       15
# 3  Thu   -0.002157      0.012052       15 -0.015333   0.010601        8
# 4  Fri    0.002353      0.006508        5 -0.010000   0.000000       16
#
#     avg_pos  stdev_pos
# 0  0.014615   0.011266
# 1  0.011111   0.003234
# 2  0.010667   0.002582
# 3  0.015000   0.009258
# 4  0.010625   0.002500

# %%
# create a dataframe with all the results per year
cols = ['day','avg_return','stdev_return','num_neg','avg_neg','stdev_neg','num_pos','avg_pos','stdev_pos']

# 2018
res_2018 = pd.DataFrame(columns=cols)
res_2018['day'] = ['Mon','Tue','Wed','Thu','Fri']

res_2018['avg_return'] = [avg_mon_2018, avg_tue_2018, avg_wed_2018, avg_thu_2018, avg_fri_2018]

res_2018['stdev_return'] = [stdev_mon_2018, stdev_tue_2018, stdev_wed_2018, stdev_thu_2018, stdev_fri_2018]

res_2018['num_neg'] = [num_mon_2018_neg,
                       num_tue_2018_neg,
                       num_wed_2018_neg,
                       num_thu_2018_neg,
                       num_fri_2018_neg]

res_2018['avg_neg'] = [avg_mon_2018_neg,
                       avg_tue_2018_neg,
                       avg_wed_2018_neg,
                       avg_thu_2018_neg,
                       avg_fri_2018_neg]

res_2018['stdev_neg'] = [stdev_mon_2018_neg,
                       stdev_tue_2018_neg,
                       stdev_wed_2018_neg,
                       stdev_thu_2018_neg,
                       stdev_fri_2018_neg]

res_2018['num_pos'] = [num_mon_2018_pos,
                       num_tue_2018_pos,
                       num_wed_2018_pos,
                       num_thu_2018_pos,
                       num_fri_2018_pos]

res_2018['avg_pos'] = [avg_mon_2018_pos,
                       avg_tue_2018_pos,
                       avg_wed_2018_pos,
                       avg_thu_2018_pos,
                       avg_fri_2018_pos]

res_2018['stdev_pos'] = [stdev_mon_2018_pos,
                       stdev_tue_2018_pos,
                       stdev_wed_2018_pos,
                       stdev_thu_2018_pos,
                       stdev_fri_2018_pos]

# %%
res_2018.head()
# Out:
#    day  avg_return  stdev_return  num_neg   avg_neg  stdev_neg  num_pos  \
# 0  Mon   -0.001667      0.012937       15 -0.016000   0.010556       11
# 1  Tue   -0.000980      0.014732       17 -0.016471   0.011695       17
# 2  Wed   -0.000600      0.016464       16 -0.016875   0.014009       13
# 3  Thu    0.001373      0.011835       16 -0.012500   0.005774       20
# 4  Fri   -0.000588      0.011902       20 -0.012500   0.005501       16
#
#     avg_pos  stdev_pos
# 0  0.014545   0.005222
# 1  0.013529   0.007859
# 2  0.018462   0.010682
# 3  0.013500   0.004894
# 4  0.013750   0.005000

# %%
# create a dataframe with all the results per year
cols = ['day','avg_return','stdev_return','num_neg','avg_neg','stdev_neg','num_pos','avg_pos','stdev_pos']

# 2019
res_2019 = pd.DataFrame(columns=cols)
res_2019['day'] = ['Mon','Tue','Wed','Thu','Fri']

res_2019['avg_return'] = [avg_mon_2019, avg_tue_2019, avg_wed_2019, avg_thu_2019, avg_fri_2019]

res_2019['stdev_return'] = [stdev_mon_2019, stdev_tue_2019, stdev_wed_2019, stdev_thu_2019, stdev_fri_2019]

res_2019['num_neg'] = [num_mon_2019_neg,
                       num_tue_2019_neg,
                       num_wed_2019_neg,
                       num_thu_2019_neg,
                       num_fri_2019_neg]

res_2019['avg_neg'] = [avg_mon_2019_neg,
                       avg_tue_2019_neg,
                       avg_wed_2019_neg,
                       avg_thu_2019_neg,
                       avg_fri_2019_neg]

res_2019['stdev_neg'] = [stdev_mon_2019_neg,
                       stdev_tue_2019_neg,
                       stdev_wed_2019_neg,
                       stdev_thu_2019_neg,
                       stdev_fri_2019_neg]

res_2019['num_pos'] = [num_mon_2019_pos,
                       num_tue_2019_pos,
                       num_wed_2019_pos,
                       num_thu_2019_pos,
                       num_fri_2019_pos]

res_2019['avg_pos'] = [avg_mon_2019_pos,
                       avg_tue_2019_pos,
                       avg_wed_2019_pos,
                       avg_thu_2019_pos,
                       avg_fri_2019_pos]

res_2019['stdev_pos'] = [stdev_mon_2019_pos,
                       stdev_tue_2019_pos,
                       stdev_wed_2019_pos,
                       stdev_thu_2019_pos,
                       stdev_fri_2019_pos]

# %%
res_2019.head()
# Out:
#    day  avg_return  stdev_return  num_neg   avg_neg  stdev_neg  num_pos  \
# 0  Mon   -0.002292      0.010962       18 -0.013889   0.005016       11
# 1  Tue    0.000000      0.011882       16 -0.013750   0.006191       16
# 2  Wed    0.000784      0.015079       14 -0.014286   0.011579       17
# 3  Thu    0.000400      0.011945       16 -0.012500   0.005774       16
# 4  Fri    0.004706      0.017703        7 -0.014286   0.007868       16
#
#     avg_pos  stdev_pos
# 0  0.012727   0.004671
# 1  0.013750   0.006191
# 2  0.014118   0.014603
# 3  0.013750   0.008062
# 4  0.021250   0.022767

# %%
# create a dataframe with all the results per year
cols = ['day','avg_return','stdev_return','num_neg','avg_neg','stdev_neg','num_pos','avg_pos','stdev_pos']

# 2020
res_2020 = pd.DataFrame(columns=cols)
res_2020['day'] = ['Mon','Tue','Wed','Thu','Fri']

res_2020['avg_return'] = [avg_mon_2020, avg_tue_2020, avg_wed_2020, avg_thu_2020, avg_fri_2020]

res_2020['stdev_return'] = [stdev_mon_2020, stdev_tue_2020, stdev_wed_2020, stdev_thu_2020, stdev_fri_2020]

res_2020['num_neg'] = [num_mon_2020_neg,
                       num_tue_2020_neg,
                       num_wed_2020_neg,
                       num_thu_2020_neg,
                       num_fri_2020_neg]

res_2020['avg_neg'] = [avg_mon_2020_neg,
                       avg_tue_2020_neg,
                       avg_wed_2020_neg,
                       avg_thu_2020_neg,
                       avg_fri_2020_neg]

res_2020['stdev_neg'] = [stdev_mon_2020_neg,
                       stdev_tue_2020_neg,
                       stdev_wed_2020_neg,
                       stdev_thu_2020_neg,
                       stdev_fri_2020_neg]

res_2020['num_pos'] = [num_mon_2020_pos,
                       num_tue_2020_pos,
                       num_wed_2020_pos,
                       num_thu_2020_pos,
                       num_fri_2020_pos]

res_2020['avg_pos'] = [avg_mon_2020_pos,
                       avg_tue_2020_pos,
                       avg_wed_2020_pos,
                       avg_thu_2020_pos,
                       avg_fri_2020_pos]

res_2020['stdev_pos'] = [stdev_mon_2020_pos,
                       stdev_tue_2020_pos,
                       stdev_wed_2020_pos,
                       stdev_thu_2020_pos,
                       stdev_fri_2020_pos]

# %%
res_2020.head()
# Out:
#    day  avg_return  stdev_return  num_neg   avg_neg  stdev_neg  num_pos  \
# 0  Mon    0.000417      0.035247       23 -0.026087   0.023304       21
# 1  Tue    0.004615      0.026306       16 -0.020000   0.009661       23
# 2  Wed    0.000192      0.026234       20 -0.025000   0.014690       21
# 3  Thu   -0.004510      0.031769       22 -0.027727   0.033085       18
# 4  Fri    0.000204      0.033447       20 -0.023000   0.026178       16
#
#     avg_pos  stdev_pos
# 0  0.029524   0.024995
# 1  0.024348   0.026081
# 2  0.024286   0.017485
# 3  0.021111   0.014507
# 4  0.029375   0.032958

# %%
sum_tbls = [res_2016,res_2017,res_2018,res_2019,res_2020]

# %%
res_2016['year'] = 2016
res_2017['year'] = 2017
res_2018['year'] = 2018
res_2019['year'] = 2019
res_2020['year'] = 2020

summary_df = pd.concat(sum_tbls, axis=0).reset_index(drop=True)

# %%
summary_df.head(10)
# Out:
#    day  avg_return  stdev_return  num_neg   avg_neg  stdev_neg  num_pos  \
# 0  Mon    0.000435      0.009651       12 -0.011667   0.003892       13
# 1  Tue   -0.000962      0.010148       17 -0.012353   0.004372       12
# 2  Wed   -0.000962      0.013174       15 -0.016667   0.011127       16
# 3  Thu    0.001569      0.008336        9 -0.010000   0.000000       12
# 4  Fri    0.000196      0.013637       10 -0.019000   0.015951       15
# 5  Mon    0.001304      0.011077       13 -0.010000   0.000000       13
# 6  Tue    0.001176      0.009518       11 -0.012727   0.006467       18
# 7  Wed   -0.000769      0.011175       10 -0.020000   0.008165       15
# 8  Thu   -0.002157      0.012052       15 -0.015333   0.010601        8
# 9  Fri    0.002353      0.006508        5 -0.010000   0.000000       16
#
#     avg_pos  stdev_pos  year
# 0  0.012308   0.005991  2016
# 1  0.013333   0.004924  2016
# 2  0.012500   0.005774  2016
# 3  0.014167   0.005149  2016
# 4  0.013333   0.007237  2016
# 5  0.014615   0.011266  2017
# 6  0.011111   0.003234  2017
# 7  0.010667   0.002582  2017
# 8  0.015000   0.009258  2017
# 9  0.010625   0.002500  2017

# %% [markdown]
# #### 1.3 Are there more days with negative or non-negative returns?

# %%
# total number of days with a return, by year
tot_2016 = len(mon_2016)+len(tue_2016)+len(wed_2016)+len(thu_2016)+len(fri_2016)
tot_2017 = len(mon_2017)+len(tue_2017)+len(wed_2017)+len(thu_2017)+len(fri_2017)
tot_2018 = len(mon_2018)+len(tue_2018)+len(wed_2018)+len(thu_2018)+len(fri_2018)
tot_2019 = len(mon_2019)+len(tue_2019)+len(wed_2019)+len(thu_2019)+len(fri_2019)
tot_2020 = len(mon_2020)+len(tue_2020)+len(wed_2020)+len(thu_2020)+len(fri_2020)

# %%
tot_neg_days = 0
for tbl in sum_tbls:
    tot_neg_days = tot_neg_days + tbl['num_neg'].sum()

tot_nonneg_days = (tot_2016+tot_2017+tot_2018+tot_2019+tot_2020) - tot_neg_days

print("Days with non-negative returns: ", tot_nonneg_days)
print("Days with negative returns: ", tot_neg_days)

if tot_nonneg_days > tot_neg_days:
    print("There are more days with non-negative returns than negative returns.")
else:
    print("There are more days with negative returns than non-negative returns.")
# Out:
# Days with non-negative returns:  885
# Days with negative returns:  373
# There are more days with non-negative returns than negative returns.

# %% [markdown]
# #### 1.4 Does your stock lose more on a "down" day than it gains on an "up" day?

# %%
# take the average of averages of positive and negative returns
avg_pos_days = abs(stats.mean(summary_df['avg_pos']))
avg_neg_days = abs(stats.mean(summary_df['avg_neg']))

print("Average of positive returns: ", avg_pos_days)
print("Average of negative returns: ", avg_neg_days)

if avg_pos_days > avg_neg_days:
    print("Average positive returns are greater than average negative returns.")
else:
    print("Average negative returns are greater than average positive returns.")
# Out:
# Average of positive returns:  0.016227358943982986
# Average of negative returns:  0.016104680620601337
# Average positive returns are greater than average negative returns.

# %% [markdown]
# #### 1.5 Are these results the same across days of the week?

# %%
# average postive returns by day
summary_df.groupby('day')['avg_pos'].mean().sort_values()
# Out:
# day
# Tue    0.015214
# Thu    0.015506
# Wed    0.016006
# Mon    0.016744
# Fri    0.017667
# Name: avg_pos, dtype: float64

# %%
# average negative returns by day
summary_df.groupby('day')['avg_neg'].mean().sort_values()
# Out:
# day
# Wed   -0.018565
# Fri   -0.015757
# Thu   -0.015612
# Mon   -0.015529
# Tue   -0.015060
# Name: avg_neg, dtype: float64

# %% [markdown]
# The stock fluctuates the most on Friday (largest average positive return and second largest negative average return) and fluctuates the least on Tuesdays (smallest average positive and negative return).

# %% [markdown]
# #### 2.1 Are there any patterns across days of the week?

# %%
# average returns by day
summary_df.groupby('day')['avg_return'].mean()
# Out:
# day
# Fri    0.001374
# Mon   -0.000361
# Thu   -0.000665
# Tue    0.000770
# Wed   -0.000271
# Name: avg_return, dtype: float64

# %% [markdown]
# The changes fluctuate slightly between positive and negative but these are extremely small differences. Friday seems to be the outlier yielding the highest average return

# %% [markdown]
# #### 2.2 Are there any patterns across different years for the same day of the week?

# %%
# average returns by day and by year
summary_df.groupby(['day','year'])['avg_return'].mean()
# Out:
# day  year
# Fri  2016    0.000196
#      2017    0.002353
#      2018   -0.000588
#      2019    0.004706
#      2020    0.000204
# Mon  2016    0.000435
#      2017    0.001304
#      2018   -0.001667
#      2019   -0.002292
#      2020    0.000417
# Thu  2016    0.001569
#      2017   -0.002157
#      2018    0.001373
#      2019    0.000400
#      2020   -0.004510
# Tue  2016   -0.000962
#      2017    0.001176
#      2018   -0.000980
#      2019    0.000000
#      2020    0.004615
# Wed  2016   -0.000962
#      2017   -0.000769
#      2018   -0.000600
#      2019    0.000784
#      2020    0.000192
# Name: avg_return, dtype: float64

# %% [markdown]
# There does not seem to be a discernable pattern across different years for the same day of the week.

# %% [markdown]
# #### 2.3 What are the best and worst days of the week to be invested for each year.

# %%
# average returns by year and by day
summary_df.groupby(['year','day'])['avg_return'].mean()
# Out:
# year  day
# 2016  Fri    0.000196
#       Mon    0.000435
#       Thu    0.001569
#       Tue   -0.000962
#       Wed   -0.000962
# 2017  Fri    0.002353
#       Mon    0.001304
#       Thu   -0.002157
#       Tue    0.001176
#       Wed   -0.000769
# 2018  Fri   -0.000588
#       Mon   -0.001667
#       Thu    0.001373
#       Tue   -0.000980
#       Wed   -0.000600
# 2019  Fri    0.004706
#       Mon   -0.002292
#       Thu    0.000400
#       Tue    0.000000
#       Wed    0.000784
# 2020  Fri    0.000204
#       Mon    0.000417
#       Thu   -0.004510
#       Tue    0.004615
#       Wed    0.000192
# Name: avg_return, dtype: float64

# %% [markdown]
# 2016
# - Best Day: Thursday
# - Worst Day: Tuesday or Wednesday
#
# 2017
# - Best Day: Friday
# - Worst Day: Thursday
#
# 2018
# - Best Day: Thursday
# - Worst Day: Tuesday
#
# 2019
# - Best Day: Friday
# - Worst Day: Monday
#
# 2020
# - Best Day: Tuesday
# - Worst Day: Thursday

# %% [markdown]
# #### 2.4 Do these days change from year to year for your stock?
# - Yes, for the most part, the best days occur towards the end of the week (Thursdays and Fridays) while the worst days tend to fluctuate across all five days in the week.

# %% [markdown]
# #### 3. Compute the aggregate table across all 5 years, one table for both your stock and one table for S&P-500 (using data for "spy").

# %%
# import the spy data
input_dir = os.path.abspath('')
ticker = 'SPY'
ticker_file = os.path.join(input_dir, ticker + '.csv')

# %%
try:
    with open(ticker_file) as f:
        lines = f.read().splitlines()
    print('opened file for ticker: ', ticker)
    print(lines[0])
except Exception as e:
    print(e)
    print('failed to read stock data for ticker: ', ticker)
# Out:
# opened file for ticker:  SPY
# Date,Year,Month,Day,Weekday,Week_Number,Year_Week,Open,High,Low,Close,Volume,Adj Close,Return,Short_MA,Long_MA

# %%
# each line represents a row of data
# the first line represents the columns
cols = lines[0].split(',')

# %%
cols
# Out:
# ['Date',
#  'Year',
#  'Month',
#  'Day',
#  'Weekday',
#  'Week_Number',
#  'Year_Week',
#  'Open',
#  'High',
#  'Low',
#  'Close',
#  'Volume',
#  'Adj Close',
#  'Return',
#  'Short_MA',
#  'Long_MA']

# %%
spy_date_l = []
spy_year_l = []
spy_weekday_l = []
spy_ac_l = []

for row in lines[1:]:
    date = row.split(',')[0]
    spy_date_l.append(date)
    
    year = row.split(',')[1]
    spy_year_l.append(year)
    
    weekday = row.split(',')[4]
    spy_weekday_l.append(weekday)
    
    ac = float(row.split(',')[12])
    spy_ac_l.append(ac)

# %%
spy_ac_l[:5]
# Out:
# [160.93, 160.9, 160.43, 161.42, 161.45]

# %%
diff_l, pct_diff_l = daily_ret_pct_diff(spy_ac_l)
# Out:
# current iteration: 0
# diff: 0
# pct diff: 0
# next iteration: 1
#
#
# current iteration: 1
# diff: -0.030000000000001137
# pct diff: -0.00018641645435904514
# next iteration: 2
#
#
# current iteration: 2
# diff: -0.46999999999999886
# pct diff: -0.002929626628436071
# next iteration: 3
#
#
# current iteration: 3
# diff: 0.9899999999999807
# pct diff: 0.0061330690125138195
# next iteration: 4
#
#
# current iteration: 4
# diff: 0.030000000000001137
# pct diff: 0.00018581604211830992
# next iteration: 5
#
#
# current iteration: 5
# diff: 0.11000000000001364
# pct diff: 0.000680861599405878
# next iteration: 6
#
#
# current iteration: 6
# diff: 0.4399999999999977
# pct diff: 0.0027160493827160354
# next iteration: 7
#
#
# current iteration: 7
# diff: -2.1599999999999966
# pct diff: -0.013513513513513492
# next iteration: 8
#
#
# current iteration: 8
# diff: 1.75
# pct diff: 0.010829878086515254
# next iteration: 9
#
#
# current iteration: 9
# diff: 0.8700000000000045
# pct diff: 0.0053551643481472636
# next iteration: 10
#
#
# current iteration: 10
# diff: -0.21000000000000796
# pct diff: -0.0012942989214176144
# next iteration: 11
#
#
# current iteration: 11
# diff: -0.6899999999999977
# pct diff: -0.004270859123545418
# next iteration: 12
#
#
# current iteration: 12
# diff: 0.46999999999999886
# pct diff: 0.0029006974017157247
# next iteration: 13
#
#
# current iteration: 13
# diff: 0.10999999999998522
# pct diff: 0.0006784260515602888
# next iteration: 14
#
#
# current iteration: 14
# diff: -1.329999999999984
# pct diff: -0.008270629935949158
# next iteration: 15
#
#
# current iteration: 15
# diff: -3.430000000000007
# pct diff: -0.02179438302198505
# next iteration: 16
#
#
# current iteration: 16
# diff: -0.7699999999999818
# pct diff: -0.00491667198774013
# next iteration: 17
#
#
# current iteration: 17
# diff: 0.9299999999999784
# pct diff: 0.0059032626634504155
# next iteration: 18
#
#
# current iteration: 18
# diff: -1.509999999999991
# pct diff: -0.009677626097545286
# next iteration: 19
#
#
# current iteration: 19
# diff: 1.6500000000000057
# pct diff: 0.01046423135464235
# next iteration: 20
#
#
# current iteration: 20
# diff: -0.9200000000000159
# pct diff: -0.005868844092880939
# next iteration: 21
#
#
# current iteration: 21
# diff: -3.530000000000001
# pct diff: -0.023037264243294404
# next iteration: 22
#
#
# current iteration: 22
# diff: 1.0700000000000216
# pct diff: 0.006934543097861449
# next iteration: 23
#
#
# current iteration: 23
# diff: -0.18999999999999773
# pct diff: -0.0012328856011939375
# next iteration: 24
#
#
# current iteration: 24
# diff: 2.0299999999999727
# pct diff: 0.013001152811579179
# next iteration: 25
#
#
# current iteration: 25
# diff: 1.9300000000000068
# pct diff: 0.012209780477003903
# next iteration: 26
#
#
# current iteration: 26
# diff: 0.30000000000001137
# pct diff: 0.001894298162530854
# next iteration: 27
#
#
# current iteration: 27
# diff: 1.7299999999999898
# pct diff: 0.010805746408494627
# next iteration: 28
#
#
# current iteration: 28
# diff: 0.0800000000000125
# pct diff: 0.000499438132101464
# next iteration: 29
#
#
# current iteration: 29
# diff: 0.8199999999999932
# pct diff: 0.005093167701863311
# next iteration: 30
#
#
# current iteration: 30
# diff: 0.8899999999999864
# pct diff: 0.005497560071653508
# next iteration: 31
#
#
# current iteration: 31
# diff: 0.20000000000001705
# pct diff: 0.0012338824110063363
# next iteration: 32
#
#
# current iteration: 32
# diff: -1.0800000000000125
# pct diff: -0.0067076579094466965
# next iteration: 33
#
#
# current iteration: 33
# diff: 0.950000000000017
# pct diff: 0.005865645838478741
# next iteration: 34
#
#
# current iteration: 34
# diff: -0.18000000000000682
# pct diff: -0.0011126220793670838
# next iteration: 35
#
#
# current iteration: 35
# diff: 0.9000000000000057
# pct diff: 0.005532333415293863
# next iteration: 36
#
#
# current iteration: 36
# diff: -0.06999999999999318
# pct diff: -0.0004304778303916928
# next iteration: 37
#
#
# current iteration: 37
# diff: 0.009999999999990905
# pct diff: 6.149305128514885e-05
# next iteration: 38
#
#
# current iteration: 38
# diff: 0.8599999999999852
# pct diff: 0.005260582334230397
# next iteration: 39
#
#
# current iteration: 39
# diff: 0.4099999999999966
# pct diff: 0.0025016779547257103
# next iteration: 40
#
#
# current iteration: 40
# diff: -1.1499999999999773
# pct diff: -0.007066486420056392
# next iteration: 41
#
#
# current iteration: 41
# diff: 2.289999999999992
# pct diff: 0.013876264921529371
# next iteration: 42
#
#
# current iteration: 42
# diff: 0.13999999999998636
# pct diff: 0.000847611551734494
# next iteration: 43
#
#
# current iteration: 43
# diff: 0.3800000000000239
# pct diff: 0.00229537903956523
# next iteration: 44
#
#
# current iteration: 44
# diff: 0.06999999999999318
# pct diff: 0.0004226542688080738
# next iteration: 45
#
#
# current iteration: 45
# diff: -0.0800000000000125
# pct diff: -0.0004832668841368401
# next iteration: 46
#
#
# current iteration: 46
# diff: -0.8199999999999932
# pct diff: -0.004978144730451634
# next iteration: 47
#
#
# current iteration: 47
# diff: 0.03999999999999204
# pct diff: 0.00024277737314877423
# next iteration: 48
#
#
# current iteration: 48
# diff: -1.8499999999999943
# pct diff: -0.011355963415382692
# next iteration: 49
#
#
# current iteration: 49
# diff: -0.44999999999998863
# pct diff: -0.00276991259386919
# next iteration: 50
#
#
# current iteration: 50
# diff: 1.4699999999999989
# pct diff: 0.008967242115537111
# next iteration: 51
#
#
# current iteration: 51
# diff: 1.1699999999999875
# pct diff: 0.007086614173228271
# next iteration: 52
#
#
# current iteration: 52
# diff: -0.8799999999999955
# pct diff: -0.005358665205212492
# next iteration: 53
#
#
# current iteration: 53
# diff: 0.9499999999999886
# pct diff: 0.005751649815341701
# next iteration: 54
#
#
# current iteration: 54
# diff: -0.6399999999999864
# pct diff: -0.0038898681091593407
# next iteration: 55
#
#
# current iteration: 55
# diff: -0.6800000000000068
# pct diff: -0.0041501373207202125
# next iteration: 56
#
#
# current iteration: 56
# diff: 0.7800000000000011
# pct diff: 0.004737897102593702
# next iteration: 57
#
#
# current iteration: 57
# diff: -1.1800000000000068
# pct diff: -0.007219333129397412
# next iteration: 58
#
#
# current iteration: 58
# diff: -0.3499999999999943
# pct diff: -0.002145922746781081
# next iteration: 59
#
#
# current iteration: 59
# diff: 0.8100000000000023
# pct diff: 0.004941736318711502
# next iteration: 60
#
#
# current iteration: 60
# diff: 1.3400000000000034
# pct diff: 0.00810892586989412
# next iteration: 61
#
#
# current iteration: 61
# diff: 1.0999999999999943
# pct diff: 0.006612563871355542
# next iteration: 62
#
#
# current iteration: 62
# diff: 0.5500000000000114
# pct diff: 0.0032953864589575278
# next iteration: 63
#
#
# current iteration: 63
# diff: -0.21999999999999886
# pct diff: -0.0013198944084473173
# next iteration: 64
#
#
# current iteration: 64
# diff: -1.9699999999999989
# pct diff: -0.011960415275332394
# next iteration: 65
#
#
# current iteration: 65
# diff: -1.8200000000000216
# pct diff: -0.011173184357542033
# next iteration: 66
#
#
# current iteration: 66
# diff: 0.6700000000000159
# pct diff: 0.004096356077280606
# next iteration: 67
#
#
# current iteration: 67
# diff: 1.759999999999991
# pct diff: 0.010646019840309648
# next iteration: 68
#
#
# current iteration: 68
# diff: -3.469999999999999
# pct diff: -0.021439604572134688
# next iteration: 69
#
#
# current iteration: 69
# diff: -1.460000000000008
# pct diff: -0.009102811896003541
# next iteration: 70
#
#
# current iteration: 70
# diff: 1.2600000000000193
# pct diff: 0.00779461800185598
# next iteration: 71
#
#
# current iteration: 71
# diff: 1.1200000000000045
# pct diff: 0.006880874854088619
# next iteration: 72
#
#
# current iteration: 72
# diff: 1.6999999999999886
# pct diff: 0.010336231531586238
# next iteration: 73
#
#
# current iteration: 73
# diff: 0.22999999999998977
# pct diff: 0.0013964784456587116
# next iteration: 74
#
#
# current iteration: 74
# diff: 0.5800000000000125
# pct diff: 0.003509196515004916
# next iteration: 75
#
#
# current iteration: 75
# diff: 0.75
# pct diff: 0.004517255917605252
# next iteration: 76
#
#
# current iteration: 76
# diff: -0.3900000000000148
# pct diff: -0.002354503743057322
# next iteration: 77
#
#
# current iteration: 77
# diff: 0.3300000000000125
# pct diff: 0.001988311140567648
# next iteration: 78
#
#
# current iteration: 78
# diff: -1.3599999999999852
# pct diff: -0.00826195249377307
# next iteration: 79
#
#
# current iteration: 79
# diff: 0.5199999999999818
# pct diff: 0.003149034094349796
# next iteration: 80
#
#
# current iteration: 80
# diff: 0.7700000000000102
# pct diff: 0.004641350210970526
# next iteration: 81
#
#
# current iteration: 81
# diff: 0.5
# pct diff: 0.003004807692307692
# next iteration: 82
#
#
# current iteration: 82
# diff: 0.01999999999998181
# pct diff: 0.00012017786323748235
# next iteration: 83
#
#
# current iteration: 83
# diff: -0.23999999999998067
# pct diff: -0.0014442171139726842
# next iteration: 84
#
#
# current iteration: 84
# diff: 0.3199999999999932
# pct diff: 0.001921921921921881
# next iteration: 85
#
#
# current iteration: 85
# diff: -1.4499999999999886
# pct diff: -0.008785216601029922
# next iteration: 86
#
#
# current iteration: 86
# diff: 0.9699999999999989
# pct diff: 0.005842669557884585
# next iteration: 87
#
#
# current iteration: 87
# diff: -0.18000000000000682
# pct diff: -0.001085383502170808
# next iteration: 88
#
#
# current iteration: 88
# diff: 0.25
# pct diff: 0.0015052080197483291
# next iteration: 89
#
#
# current iteration: 89
# diff: 1.6200000000000045
# pct diff: 0.009659531333850125
# next iteration: 90
#
#
# current iteration: 90
# diff: 0.15000000000000568
# pct diff: 0.0008936018110330374
# next iteration: 91
#
#
# current iteration: 91
# diff: -0.8000000000000114
# pct diff: -0.004788698671136187
# next iteration: 92
#
#
# current iteration: 92
# diff: -1.4699999999999989
# pct diff: -0.008877347665921848
# next iteration: 93
#
#
# current iteration: 93
# diff: 0.5799999999999841
# pct diff: 0.003490401396160463
# next iteration: 94
#
#
# current iteration: 94
# diff: 0.6100000000000136
# pct diff: 0.0036575128912340426
# next iteration: 95
#
#
# current iteration: 95
# diff: -1.0500000000000114
# pct diff: -0.006335606106317573
# next iteration: 96
#
#
# current iteration: 96
# diff: 1.3900000000000148
# pct diff: 0.008317376735280126
# next iteration: 97
#
#
# current iteration: 97
# diff: 0.4099999999999966
# pct diff: 0.0024473228675460906
# next iteration: 98
#
#
# current iteration: 98
# diff: 0.6699999999999875
# pct diff: 0.003983353151010628
# next iteration: 99
#
#
# current iteration: 99
# diff: 1.0300000000000011
# pct diff: 0.006086391301778652
# next iteration: 100
#
#
# current iteration: 100
# diff: -0.11999999999997613
# pct diff: -0.0007095973035301053
# next iteration: 101
#
#
# current iteration: 101
# diff: 0.8799999999999955
# pct diff: 0.0051767751044178795
# next iteration: 102
#
#
# current iteration: 102
# diff: 0.2699999999999818
# pct diff: 0.0015858099377421698
# next iteration: 103
#
#
# current iteration: 103
# diff: 0.18999999999999773
# pct diff: 0.0011146963919037708
# next iteration: 104
#
#
# current iteration: 104
# diff: -0.07999999999998408
# pct diff: -0.0004695662381873809
# next iteration: 105
#
#
# current iteration: 105
# diff: 0.3400000000000034
# pct diff: 0.001991681799543105
# next iteration: 106
#
#
# current iteration: 106
# diff: 1.1099999999999852
# pct diff: 0.006460249097893059
# next iteration: 107
#
#
# current iteration: 107
# diff: 0.8300000000000125
# pct diff: 0.004807413843035114
# next iteration: 108
#
#
# current iteration: 108
# diff: 0.1699999999999875
# pct diff: 0.000983682444161483
# next iteration: 109
#
#
# current iteration: 109
# diff: 0.020000000000010232
# pct diff: 0.00011571395510304462
# next iteration: 110
#
#
# current iteration: 110
# diff: -0.5999999999999943
# pct diff: -0.003483511379470473
# next iteration: 111
#
#
# current iteration: 111
# diff: -1.2199999999999989
# pct diff: -0.0071336685767746395
# next iteration: 112
#
#
# current iteration: 112
# diff: 0.5199999999999818
# pct diff: 0.003031362947417406
# next iteration: 113
#
#
# current iteration: 113
# diff: 0.14000000000001478
# pct diff: 0.000815470643056936
# next iteration: 114
#
#
# current iteration: 114
# diff: 0.47999999999998977
# pct diff: 0.0027881040892192713
# next iteration: 115
#
#
# current iteration: 115
# diff: 1.259999999999991
# pct diff: 0.007265597970245594
# next iteration: 116
#
#
# current iteration: 116
# diff: 0.20000000000001705
# pct diff: 0.0011519410206198425
# next iteration: 117
#
#
# current iteration: 117
# diff: 0.3499999999999943
# pct diff: 0.0020118411220325016
# next iteration: 118
#
#
# current iteration: 118
# diff: -0.05000000000001137
# pct diff: -0.00028748850046004696
# next iteration: 119
#
#
# current iteration: 119
# diff: -1.049999999999983
# pct diff: -0.006073928385491889
# next iteration: 120
#
#
# current iteration: 120
# diff: 0.7800000000000011
# pct diff: 0.004491793838180254
# next iteration: 121
#
#
# current iteration: 121
# diff: -0.12000000000000455
# pct diff: -0.0006915230795828072
# next iteration: 122
#
#
# current iteration: 122
# diff: 0.3300000000000125
# pct diff: 0.0018980789140688628
# next iteration: 123
#
#
# current iteration: 123
# diff: -0.09000000000000341
# pct diff: -0.0005179259941301917
# next iteration: 124
#
#
# current iteration: 124
# diff: 1.1699999999999875
# pct diff: 0.0066880073167942585
# next iteration: 125
#
#
# current iteration: 125
# diff: 0.18000000000000682
# pct diff: 0.0010278666057560919
# next iteration: 126
#
#
# current iteration: 126
# diff: 0.8599999999999852
# pct diff: 0.004886918968064469
# next iteration: 127
#
#
# current iteration: 127
# diff: -0.6199999999999761
# pct diff: -0.003535583941605703
# next iteration: 128
#
#
# current iteration: 128
# diff: -1.1200000000000045
# pct diff: -0.006427915518824635
# next iteration: 129
#
#
# current iteration: 129
# diff: 0.7800000000000011
# pct diff: 0.004456633527596852
# next iteration: 130
#
#
# current iteration: 130
# diff: -0.6899999999999977
# pct diff: -0.003958010669420052
# next iteration: 131
#
#
# current iteration: 131
# diff: 0.23999999999998067
# pct diff: 0.0013748066678122282
# next iteration: 132
#
#
# current iteration: 132
# diff: 0.8700000000000045
# pct diff: 0.004958960328317399
# next iteration: 133
#
#
# current iteration: 133
# diff: -0.3199999999999932
# pct diff: -0.001827318410232944
# next iteration: 134
#
#
# current iteration: 134
# diff: 0.6399999999999864
# pct diff: 0.00364132908511599
# next iteration: 135
#
#
# current iteration: 135
# diff: -1.9899999999999807
# pct diff: -0.011451919203544804
# next iteration: 136
#
#
# current iteration: 136
# diff: 1.7699999999999818
# pct diff: 0.010083171926626307
# next iteration: 137
#
#
# current iteration: 137
# diff: -0.3299999999999841
# pct diff: -0.0018834541407453003
# next iteration: 138
#
#
# current iteration: 138
# diff: 0.7699999999999818
# pct diff: 0.0043754972155925775
# next iteration: 139
#
#
# current iteration: 139
# diff: 0.3900000000000148
# pct diff: 0.0022112604184385937
# next iteration: 140
#
#
# current iteration: 140
# diff: 0.009999999999990905
# pct diff: 5.6695770495469474e-05
# next iteration: 141
#
#
# current iteration: 141
# diff: -0.8299999999999841
# pct diff: -0.004727997721446791
# next iteration: 142
#
#
# current iteration: 142
# diff: 0.06999999999999318
# pct diff: 0.0003985878601525634
# next iteration: 143
#
#
# current iteration: 143
# diff: -0.75
# pct diff: -0.004288900325956425
# next iteration: 144
#
#
# current iteration: 144
# diff: 0.01999999999998181
# pct diff: 0.00011435759620322381
# next iteration: 145
#
#
# current iteration: 145
# diff: -3.4499999999999886
# pct diff: -0.02012365842277175
# next iteration: 146
#
#
# current iteration: 146
# diff: -0.5200000000000102
# pct diff: -0.003042358998361867
# next iteration: 147
#
#
# current iteration: 147
# diff: 1.2300000000000182
# pct diff: 0.007144931745570828
# next iteration: 148
#
#
# current iteration: 148
# diff: -1.670000000000016
# pct diff: -0.009795870483341249
# next iteration: 149
#
#
# current iteration: 149
# diff: 0.05000000000001137
# pct diff: 0.0002932035418988528
# next iteration: 150
#
#
# current iteration: 150
# diff: -0.9199999999999875
# pct diff: -0.005424208478273612
# next iteration: 151
#
#
# current iteration: 151
# diff: 1.9599999999999795
# pct diff: 0.011423908608731012
# next iteration: 152
#
#
# current iteration: 152
# diff: 0.5
# pct diff: 0.002905794153542163
# next iteration: 153
#
#
# current iteration: 153
# diff: -0.23999999999998067
# pct diff: -0.0013967293254960173
# next iteration: 154
#
#
# current iteration: 154
# diff: 1.1599999999999966
# pct diff: 0.006705589918492378
# next iteration: 155
#
#
# current iteration: 155
# diff: 0.8199999999999932
# pct diff: 0.004717795293711485
# next iteration: 156
#
#
# current iteration: 156
# diff: -0.03999999999999204
# pct diff: -0.0002301893307244751
# next iteration: 157
#
#
# current iteration: 157
# diff: 1.4599999999999795
# pct diff: 0.008331906636991267
# next iteration: 158
#
#
# current iteration: 158
# diff: 0.9200000000000159
# pct diff: 0.005222821458983911
# next iteration: 159
#
#
# current iteration: 159
# diff: 0.46999999999999886
# pct diff: 0.0026610802853583903
# next iteration: 160
#
#
# current iteration: 160
# diff: 0.5099999999999909
# pct diff: 0.0028792412352508946
# next iteration: 161
#
#
# current iteration: 161
# diff: -0.2699999999999818
# pct diff: -0.0015266312337441014
# next iteration: 162
#
#
# current iteration: 162
# diff: 0.8899999999999864
# pct diff: 0.005007032348804424
# next iteration: 163
#
#
# current iteration: 163
# diff: 0.12000000000000455
# pct diff: 0.0006746500252994015
# next iteration: 164
#
#
# current iteration: 164
# diff: -0.06999999999999318
# pct diff: -0.0003937007874015364
# next iteration: 165
#
#
# current iteration: 165
# diff: -0.10000000000002274
# pct diff: -0.0005627462014632681
# next iteration: 166
#
#
# current iteration: 166
# diff: 0.5100000000000193
# pct diff: 0.0028617922675496284
# next iteration: 167
#
#
# current iteration: 167
# diff: -0.09000000000000341
# pct diff: -0.0005052773411183663
# next iteration: 168
#
#
# current iteration: 168
# diff: -0.09999999999999432
# pct diff: -0.0005617346365576582
# next iteration: 169
#
#
# current iteration: 169
# diff: -0.2600000000000193
# pct diff: -0.0014626462646265715
# next iteration: 170
#
#
# current iteration: 170
# diff: 0.8000000000000114
# pct diff: 0.0044802867383513184
# next iteration: 171
#
#
# current iteration: 171
# diff: -0.46000000000000796
# pct diff: -0.0025828186412128465
# next iteration: 172
#
#
# current iteration: 172
# diff: -1.1299999999999955
# pct diff: -0.006385263038933127
# next iteration: 173
#
#
# current iteration: 173
# diff: 0.6699999999999875
# pct diff: 0.0037716730466110537
# next iteration: 174
#
#
# current iteration: 174
# diff: 0.20000000000001705
# pct diff: 0.0011246063877643783
# next iteration: 175
#
#
# current iteration: 175
# diff: -1.039999999999992
# pct diff: -0.005882352941176425
# next iteration: 176
#
#
# current iteration: 176
# diff: -0.13000000000002387
# pct diff: -0.0007358351729214008
# next iteration: 177
#
#
# current iteration: 177
# diff: 1.3300000000000125
# pct diff: 0.007471910112359621
# next iteration: 178
#
#
# current iteration: 178
# diff: 0.2400000000000091
# pct diff: 0.0013464991023339828
# next iteration: 179
#
#
# current iteration: 179
# diff: 0.9499999999999886
# pct diff: 0.005301635135889216
# next iteration: 180
#
#
# current iteration: 180
# diff: -0.1599999999999966
# pct diff: -0.0008937049656481963
# next iteration: 181
#
#
# current iteration: 181
# diff: -1.3799999999999955
# pct diff: -0.00776808330987895
# next iteration: 182
#
#
# current iteration: 182
# diff: -1.0200000000000102
# pct diff: -0.005774783445620847
# next iteration: 183
#
#
# current iteration: 183
# diff: 1.3799999999999955
# pct diff: 0.0077523734621650214
# next iteration: 184
#
#
# current iteration: 184
# diff: -2.8700000000000045
# pct diff: -0.01638689048760994
# next iteration: 185
#
#
# current iteration: 185
# diff: 1.3900000000000148
# pct diff: 0.00787401574803158
# next iteration: 186
#
#
# current iteration: 186
# diff: -0.3199999999999932
# pct diff: -0.0018160149821235638
# next iteration: 187
#
#
# current iteration: 187
# diff: -0.46000000000000796
# pct diff: -0.00261735419630161
# next iteration: 188
#
#
# current iteration: 188
# diff: -2.3799999999999955
# pct diff: -0.01372786525927205
# next iteration: 189
#
#
# current iteration: 189
# diff: 0.01999999999998181
# pct diff: 0.0001153469058191465
# next iteration: 190
#
#
# current iteration: 190
# diff: 1.910000000000025
# pct diff: 0.010895607529948802
# next iteration: 191
#
#
# current iteration: 191
# diff: -0.20000000000001705
# pct diff: -0.0011422044545974703
# next iteration: 192
#
#
# current iteration: 192
# diff: -2.710000000000008
# pct diff: -0.015720169383374952
# next iteration: 193
#
#
# current iteration: 193
# diff: 3.0200000000000102
# pct diff: 0.017216806339433385
# next iteration: 194
#
#
# current iteration: 194
# diff: -3.4799999999999898
# pct diff: -0.02024079567265742
# next iteration: 195
#
#
# current iteration: 195
# diff: -1.960000000000008
# pct diff: -0.011531446725892852
# next iteration: 196
#
#
# current iteration: 196
# diff: -2.8000000000000114
# pct diff: -0.0167494167613807
# next iteration: 197
#
#
# current iteration: 197
# diff: 0.2600000000000193
# pct diff: 0.0015528877739952177
# next iteration: 198
#
#
# current iteration: 198
# diff: -1.1299999999999955
# pct diff: -0.006794948887552588
# next iteration: 199
#
#
# current iteration: 199
# diff: -0.14000000000001478
# pct diff: -0.0008425613866153996
# next iteration: 200
#
#
# current iteration: 200
# diff: 1.960000000000008
# pct diff: 0.011658339281465667
# next iteration: 201
#
#
# current iteration: 201
# diff: 1.6299999999999955
# pct diff: 0.00960235640648009
# next iteration: 202
#
#
# current iteration: 202
# diff: 3.3700000000000045
# pct diff: 0.019466266173752335
# next iteration: 203
#
#
# current iteration: 203
# diff: -1.240000000000009
# pct diff: -0.007214335582964912
# next iteration: 204
#
#
# current iteration: 204
# diff: 2.0
# pct diff: 0.011502185415228895
# next iteration: 205
#
#
# current iteration: 205
# diff: 1.3400000000000034
# pct diff: 0.007647528820910875
# next iteration: 206
#
#
# current iteration: 206
# diff: -0.2400000000000091
# pct diff: -0.001371585324037085
# next iteration: 207
#
#
# current iteration: 207
# diff: 2.0100000000000193
# pct diff: 0.011356573817729924
# next iteration: 208
#
#
# current iteration: 208
# diff: -0.27000000000001023
# pct diff: -0.001527840651878736
# next iteration: 209
#
#
# current iteration: 209
# diff: 1.1299999999999955
# pct diff: 0.00635366882204102
# next iteration: 210
#
#
# current iteration: 210
# diff: 2.039999999999992
# pct diff: 0.011340263494357619
# next iteration: 211
#
#
# current iteration: 211
# diff: 0.09000000000000341
# pct diff: 0.0005000555617291
# next iteration: 212
#
#
# current iteration: 212
# diff: -0.6199999999999761
# pct diff: -0.0034567350579838094
# next iteration: 213
#
#
# current iteration: 213
# diff: 1.1299999999999955
# pct diff: 0.006260734666740514
# next iteration: 214
#
#
# current iteration: 214
# diff: 0.7299999999999898
# pct diff: 0.004028252952212724
# next iteration: 215
#
#
# current iteration: 215
# diff: 0.1599999999999966
# pct diff: 0.0008821259234755574
# next iteration: 216
#
#
# current iteration: 216
# diff: 0.5800000000000125
# pct diff: 0.0031875137392834278
# next iteration: 217
#
#
# current iteration: 217
# diff: 0.1699999999999875
# pct diff: 0.0009333992203370532
# next iteration: 218
#
#
# current iteration: 218
# diff: -0.18999999999999773
# pct diff: -0.0010443003187864007
# next iteration: 219
#
#
# current iteration: 219
# diff: 0.19999999999998863
# pct diff: 0.001098056440100959
# next iteration: 220
#
#
# current iteration: 220
# diff: 0.05000000000001137
# pct diff: 0.00027443877270987086
# next iteration: 221
#
#
# current iteration: 221
# diff: 0.11000000000001364
# pct diff: 0.0006034009873835086
# next iteration: 222
#
#
# current iteration: 222
# diff: 1.0600000000000023
# pct diff: 0.0057809773123909365
# next iteration: 223
#
#
# current iteration: 223
# diff: -0.30000000000001137
# pct diff: -0.001638806948541524
# next iteration: 224
#
#
# current iteration: 224
# diff: 0.3199999999999932
# pct diff: 0.0017450103609989813
# next iteration: 225
#
#
# current iteration: 225
# diff: 0.9800000000000182
# pct diff: 0.005315686699935008
# next iteration: 226
#
#
# current iteration: 226
# diff: 0.5199999999999818
# pct diff: 0.002812635222847154
# next iteration: 227
#
#
# current iteration: 227
# diff: -0.12999999999999545
# pct diff: -0.0007036535859269036
# next iteration: 228
#
#
# current iteration: 228
# diff: 0.46999999999999886
# pct diff: 0.002537522945686205
# next iteration: 229
#
#
# current iteration: 229
# diff: -0.38999999999998636
# pct diff: -0.0021100470702807247
# next iteration: 230
#
#
# current iteration: 230
# diff: -1.2900000000000205
# pct diff: -0.0070284406668847145
# next iteration: 231
#
#
# current iteration: 231
# diff: 1.1899999999999977
# pct diff: 0.006441834028040913
# next iteration: 232
#
#
# current iteration: 232
# diff: 0.710000000000008
# pct diff: 0.0038287316652286883
# next iteration: 233
#
#
# current iteration: 233
# diff: -0.19999999999998863
# pct diff: -0.0010796804145972178
# next iteration: 234
#
#
# current iteration: 234
# diff: 0.29999999999998295
# pct diff: 0.0016169020157377543
# next iteration: 235
#
#
# current iteration: 235
# diff: -1.2399999999999807
# pct diff: -0.006728160607704724
# next iteration: 236
#
#
# current iteration: 236
# diff: -0.12000000000000455
# pct diff: -0.0006515365403409954
# next iteration: 237
#
#
# current iteration: 237
# diff: -2.960000000000008
# pct diff: -0.01633373799801351
# next iteration: 238
#
#
# current iteration: 238
# diff: 0.9199999999999875
# pct diff: 0.005051059624464629
# next iteration: 239
#
#
# current iteration: 239
# diff: -2.9399999999999977
# pct diff: -0.016406249999999987
# next iteration: 240
#
#
# current iteration: 240
# diff: -1.2299999999999898
# pct diff: -0.006911277181547395
# next iteration: 241
#
#
# current iteration: 241
# diff: -1.4300000000000068
# pct diff: -0.008100147275405046
# next iteration: 242
#
#
# current iteration: 242
# diff: 3.460000000000008
# pct diff: 0.019222222222222266
# next iteration: 243
#
#
# current iteration: 243
# diff: 4.449999999999989
# pct diff: 0.024125779343995603
# next iteration: 244
#
#
# current iteration: 244
# diff: 0.7900000000000205
# pct diff: 0.004264737637659363
# next iteration: 245
#
#
# current iteration: 245
# diff: 0.8499999999999943
# pct diff: 0.004567682304261348
# next iteration: 246
#
#
# current iteration: 246
# diff: 0.25
# pct diff: 0.0013416335730385316
# next iteration: 247
#
#
# current iteration: 247
# diff: 0.020000000000010232
# pct diff: 0.0001073191672033174
# next iteration: 248
#
#
# current iteration: 248
# diff: 0.5999999999999943
# pct diff: 0.0032092426187419463
# next iteration: 249
#
#
# current iteration: 249
# diff: 0.25
# pct diff: 0.0013353987500667698
# next iteration: 250
#
#
# current iteration: 250
# diff: -1.0
# pct diff: -0.005370280865689275
# next iteration: 251
#
#
# current iteration: 251
# diff: -1.8499999999999943
# pct diff: -0.010034714688652604
# next iteration: 252
#
#
# current iteration: 252
# diff: -0.10000000000002274
# pct diff: -0.0005427113860850035
# next iteration: 253
#
#
# current iteration: 253
# diff: -3.329999999999984
# pct diff: -0.018404907975460034
# next iteration: 254
#
#
# current iteration: 254
# diff: -1.700000000000017
# pct diff: -0.009485019249009748
# next iteration: 255
#
#
# current iteration: 255
# diff: 2.230000000000018
# pct diff: 0.012289209743194193
# next iteration: 256
#
#
# current iteration: 256
# diff: 3.219999999999999
# pct diff: 0.017435564219189945
# next iteration: 257
#
#
# current iteration: 257
# diff: -1.4800000000000182
# pct diff: -0.008078602620087435
# next iteration: 258
#
#
# current iteration: 258
# diff: -1.4299999999999784
# pct diff: -0.00786708477746591
# next iteration: 259
#
#
# current iteration: 259
# diff: -0.5100000000000193
# pct diff: -0.0028136378682556513
# next iteration: 260
#
#
# current iteration: 260
# diff: -1.0999999999999943
# pct diff: -0.006105683836589666
# next iteration: 261
#
#
# current iteration: 261
# diff: -1.6500000000000057
# pct diff: -0.00924317965380094
# next iteration: 262
#
#
# current iteration: 262
# diff: 2.3400000000000034
# pct diff: 0.01293889964058614
# next iteration: 263
#
#
# current iteration: 263
# diff: 0.3900000000000148
# pct diff: 0.0021518428602958217
# next iteration: 264
#
#
# current iteration: 264
# diff: 0.9099999999999966
# pct diff: 0.00499588251441118
# next iteration: 265
#
#
# current iteration: 265
# diff: 2.710000000000008
# pct diff: 0.014659742507843816
# next iteration: 266
#
#
# current iteration: 266
# diff: -1.0100000000000193
# pct diff: -0.0054936089203155795
# next iteration: 267
#
#
# current iteration: 267
# diff: 0.4300000000000068
# pct diff: 0.0023334056869980836
# next iteration: 268
#
#
# current iteration: 268
# diff: -2.430000000000007
# pct diff: -0.013362661534231548
# next iteration: 269
#
#
# current iteration: 269
# diff: -2.329999999999984
# pct diff: -0.012979055258466933
# next iteration: 270
#
#
# current iteration: 270
# diff: 1.6499999999999773
# pct diff: 0.009107468123861442
# next iteration: 271
#
#
# current iteration: 271
# diff: -2.269999999999982
# pct diff: -0.012688652878703084
# next iteration: 272
#
#
# current iteration: 272
# diff: 2.210000000000008
# pct diff: 0.012202528849870288
# next iteration: 273
#
#
# current iteration: 273
# diff: 2.619999999999976
# pct diff: 0.014260055516246537
# next iteration: 274
#
#
# current iteration: 274
# diff: -0.6999999999999886
# pct diff: -0.003824509643227824
# next iteration: 275
#
#
# current iteration: 275
# diff: 1.8499999999999943
# pct diff: 0.010006490696668079
# next iteration: 276
#
#
# current iteration: 276
# diff: -0.5099999999999909
# pct diff: -0.0027661767098768287
# next iteration: 277
#
#
# current iteration: 277
# diff: -0.8300000000000125
# pct diff: -0.00452217500272427
# next iteration: 278
#
#
# current iteration: 278
# diff: 1.960000000000008
# pct diff: 0.010566037735849099
# next iteration: 279
#
#
# current iteration: 279
# diff: 0.11000000000001364
# pct diff: 0.0005926404827326848
# next iteration: 280
#
#
# current iteration: 280
# diff: 1.7799999999999727
# pct diff: 0.009498906024867778
# next iteration: 281
#
#
# current iteration: 281
# diff: 0.7700000000000102
# pct diff: 0.00409226190476196
# next iteration: 282
#
#
# current iteration: 282
# diff: 0.30000000000001137
# pct diff: 0.0015918497293856062
# next iteration: 283
#
#
# current iteration: 283
# diff: 0.01999999999998181
# pct diff: 0.00010611205432927531
# next iteration: 284
#
#
# current iteration: 284
# diff: -0.13999999999998636
# pct diff: -0.0007433365190611998
# next iteration: 285
#
#
# current iteration: 285
# diff: 1.1299999999999955
# pct diff: 0.005964004855649947
# next iteration: 286
#
#
# current iteration: 286
# diff: -0.030000000000001137
# pct diff: -0.00015836148648649249
# next iteration: 287
#
#
# current iteration: 287
# diff: 0.539999999999992
# pct diff: 0.0028424044636277085
# next iteration: 288
#
#
# current iteration: 288
# diff: -0.1599999999999966
# pct diff: -0.0008429038036033958
# next iteration: 289
#
#
# current iteration: 289
# diff: -0.21999999999999886
# pct diff: -0.0011603375527426101
# next iteration: 290
#
#
# current iteration: 290
# diff: -0.6500000000000057
# pct diff: -0.0034400635088648094
# next iteration: 291
#
#
# current iteration: 291
# diff: 1.1899999999999977
# pct diff: 0.006258546334279993
# next iteration: 292
#
#
# current iteration: 292
# diff: -0.7799999999999727
# pct diff: -0.004119138149556256
# next iteration: 293
#
#
# current iteration: 293
# diff: -0.7900000000000205
# pct diff: -0.004189425677467362
# next iteration: 294
#
#
# current iteration: 294
# diff: 0.20000000000001705
# pct diff: 0.0010594903851248454
# next iteration: 295
#
#
# current iteration: 295
# diff: -2.6500000000000057
# pct diff: -0.01423812594025363
# next iteration: 296
#
#
# current iteration: 296
# diff: 0.7699999999999818
# pct diff: 0.0041200706297821275
# next iteration: 297
#
#
# current iteration: 297
# diff: -3.0299999999999727
# pct diff: -0.0164799303818121
# next iteration: 298
#
#
# current iteration: 298
# diff: -0.4300000000000068
# pct diff: -0.0023442185029711976
# next iteration: 299
#
#
# current iteration: 299
# diff: 2.329999999999984
# pct diff: 0.012543066322136004
# next iteration: 300
#
#
# current iteration: 300
# diff: -1.1399999999999864
# pct diff: -0.006174845628859204
# next iteration: 301
#
#
# current iteration: 301
# diff: 2.469999999999999
# pct diff: 0.01320220214869848
# next iteration: 302
#
#
# current iteration: 302
# diff: -0.5600000000000023
# pct diff: -0.0030021980378491515
# next iteration: 303
#
#
# current iteration: 303
# diff: 2.240000000000009
# pct diff: 0.011866292313397303
# next iteration: 304
#
#
# current iteration: 304
# diff: -0.8600000000000136
# pct diff: -0.004576659038901675
# next iteration: 305
#
#
# current iteration: 305
# diff: 1.6599999999999966
# pct diff: 0.008756659809041497
# next iteration: 306
#
#
# current iteration: 306
# diff: -0.37000000000000455
# pct diff: -0.00195560253699791
# next iteration: 307
#
#
# current iteration: 307
# diff: -1.0600000000000023
# pct diff: -0.0056341022642712995
# next iteration: 308
#
#
# current iteration: 308
# diff: -2.759999999999991
# pct diff: -0.014888337468982582
# next iteration: 309
#
#
# current iteration: 309
# diff: -0.4399999999999977
# pct diff: -0.0023791499945928288
# next iteration: 310
#
#
# current iteration: 310
# diff: 0.4200000000000159
# pct diff: 0.002265861027190418
# next iteration: 311
#
#
# current iteration: 311
# diff: 2.259999999999991
# pct diff: 0.012045624133887597
# next iteration: 312
#
#
# current iteration: 312
# diff: -1.6400000000000148
# pct diff: -0.008818152489515082
# next iteration: 313
#
#
# current iteration: 313
# diff: -0.6499999999999773
# pct diff: -0.0035072573247719053
# next iteration: 314
#
#
# current iteration: 314
# diff: 0.6599999999999966
# pct diff: 0.003548577880531193
# next iteration: 315
#
#
# current iteration: 315
# diff: 1.259999999999991
# pct diff: 0.006728971962616774
# next iteration: 316
#
#
# current iteration: 316
# diff: -0.5
# pct diff: -0.002677376171352075
# next iteration: 317
#
#
# current iteration: 317
# diff: 0.6299999999999955
# pct diff: 0.003362151777137344
# next iteration: 318
#
#
# current iteration: 318
# diff: 0.8300000000000125
# pct diff: 0.004409967589394891
# next iteration: 319
#
#
# current iteration: 319
# diff: 1.0300000000000011
# pct diff: 0.005442823927288105
# next iteration: 320
#
#
# current iteration: 320
# diff: -0.8600000000000136
# pct diff: -0.0045652404713876936
# next iteration: 321
#
#
# current iteration: 321
# diff: 0.36000000000001364
# pct diff: 0.0019073858217654638
# next iteration: 322
#
#
# current iteration: 322
# diff: 0.8499999999999943
# pct diff: 0.004483358826942319
# next iteration: 323
#
#
# current iteration: 323
# diff: -0.060000000000002274
# pct diff: -0.0003165725742626617
# next iteration: 324
#
#
# current iteration: 324
# diff: -2.180000000000007
# pct diff: -0.011635975447024324
# next iteration: 325
#
#
# current iteration: 325
# diff: 1.710000000000008
# pct diff: 0.009044747699143171
# next iteration: 326
#
#
# current iteration: 326
# diff: -0.21999999999999886
# pct diff: -0.0011650074136835356
# next iteration: 327
#
#
# current iteration: 327
# diff: 0.9300000000000068
# pct diff: 0.004900669231174616
# next iteration: 328
#
#
# current iteration: 328
# diff: 0.47999999999998977
# pct diff: 0.002522996057818606
# next iteration: 329
#
#
# current iteration: 329
# diff: 0.4399999999999977
# pct diff: 0.002307409932350924
# next iteration: 330
#
#
# current iteration: 330
# diff: -0.8000000000000114
# pct diff: -0.0042129654010217045
# next iteration: 331
#
#
# current iteration: 331
# diff: 0.6100000000000136
# pct diff: 0.00320209973753288
# next iteration: 332
#
#
# current iteration: 332
# diff: -0.789999999999992
# pct diff: -0.0041642506984344105
# next iteration: 333
#
#
# current iteration: 333
# diff: -1.9000000000000057
# pct diff: -0.0101166072094138
# next iteration: 334
#
#
# current iteration: 334
# diff: 2.039999999999992
# pct diff: 0.010745325256781629
# next iteration: 335
#
#
# current iteration: 335
# diff: 0.539999999999992
# pct diff: 0.0028362834182467152
# next iteration: 336
#
#
# current iteration: 336
# diff: -2.1799999999999784
# pct diff: -0.011582806439615208
# next iteration: 337
#
#
# current iteration: 337
# diff: -0.7800000000000011
# pct diff: -0.004161553646694772
# next iteration: 338
#
#
# current iteration: 338
# diff: 0.75
# pct diff: 0.0039855457540652565
# next iteration: 339
#
#
# current iteration: 339
# diff: 2.4799999999999898
# pct diff: 0.013007447812860536
# next iteration: 340
#
#
# current iteration: 340
# diff: -0.9099999999999966
# pct diff: -0.004795783926218691
# next iteration: 341
#
#
# current iteration: 341
# diff: -0.5699999999999932
# pct diff: -0.0030130034887408457
# next iteration: 342
#
#
# current iteration: 342
# diff: 0.03999999999999204
# pct diff: 0.00021139414438215855
# next iteration: 343
#
#
# current iteration: 343
# diff: 1.9699999999999989
# pct diff: 0.010303886186516025
# next iteration: 344
#
#
# current iteration: 344
# diff: 0.21000000000000796
# pct diff: 0.0010971786833856214
# next iteration: 345
#
#
# current iteration: 345
# diff: 0.5900000000000034
# pct diff: 0.003073076722745994
# next iteration: 346
#
#
# current iteration: 346
# diff: -0.060000000000002274
# pct diff: -0.0003126139738446427
# next iteration: 347
#
#
# current iteration: 347
# diff: -0.14000000000001478
# pct diff: -0.0007299650659576348
# next iteration: 348
#
#
# current iteration: 348
# diff: 0.5600000000000023
# pct diff: 0.0029113595009098115
# next iteration: 349
#
#
# current iteration: 349
# diff: -0.46000000000000796
# pct diff: -0.0023972067330241703
# next iteration: 350
#
#
# current iteration: 350
# diff: -2.059999999999974
# pct diff: -0.010851814781646598
# next iteration: 351
#
#
# current iteration: 351
# diff: 1.799999999999983
# pct diff: 0.009393101288942144
# next iteration: 352
#
#
# current iteration: 352
# diff: -0.21000000000000796
# pct diff: -0.001097064047643966
# next iteration: 353
#
#
# current iteration: 353
# diff: -1.1899999999999977
# pct diff: -0.006255585344057182
# next iteration: 354
#
#
# current iteration: 354
# diff: 0.3800000000000239
# pct diff: 0.0019935994963539367
# next iteration: 355
#
#
# current iteration: 355
# diff: -0.18000000000000682
# pct diff: -0.0009452292180854215
# next iteration: 356
#
#
# current iteration: 356
# diff: 0.5
# pct diff: 0.00261876080238831
# next iteration: 357
#
#
# current iteration: 357
# diff: -1.6100000000000136
# pct diff: -0.008504120008451372
# next iteration: 358
#
#
# current iteration: 358
# diff: -0.3299999999999841
# pct diff: -0.0017461241335519555
# next iteration: 359
#
#
# current iteration: 359
# diff: -1.1599999999999966
# pct diff: -0.006175797263482918
# next iteration: 360
#
#
# current iteration: 360
# diff: -0.030000000000001137
# pct diff: -0.00015974440894569295
# next iteration: 361
#
#
# current iteration: 361
# diff: 2.259999999999991
# pct diff: 0.011890981795222513
# next iteration: 362
#
#
# current iteration: 362
# diff: 0.6099999999999852
# pct diff: 0.003199244768448027
# next iteration: 363
#
#
# current iteration: 363
# diff: -1.4599999999999795
# pct diff: -0.007716294064795621
# next iteration: 364
#
#
# current iteration: 364
# diff: -0.8100000000000023
# pct diff: -0.004299363057324853
# next iteration: 365
#
#
# current iteration: 365
# diff: 1.0300000000000011
# pct diff: 0.005437364725756222
# next iteration: 366
#
#
# current iteration: 366
# diff: 0.29999999999998295
# pct diff: 0.0015811943287829177
# next iteration: 367
#
#
# current iteration: 367
# diff: 1.9699999999999989
# pct diff: 0.010276473656755342
# next iteration: 368
#
#
# current iteration: 368
# diff: -0.8499999999999943
# pct diff: -0.004453759496987133
# next iteration: 369
#
#
# current iteration: 369
# diff: 0.9800000000000182
# pct diff: 0.005108689985925132
# next iteration: 370
#
#
# current iteration: 370
# diff: 0.13999999999998636
# pct diff: 0.0007292806167629648
# next iteration: 371
#
#
# current iteration: 371
# diff: -1.4000000000000057
# pct diff: -0.007346381906910876
# next iteration: 372
#
#
# current iteration: 372
# diff: -0.5799999999999841
# pct diff: -0.0030527922522237175
# next iteration: 373
#
#
# current iteration: 373
# diff: -0.030000000000001137
# pct diff: -0.00015792798483891943
# next iteration: 374
#
#
# current iteration: 374
# diff: -3.990000000000009
# pct diff: -0.021455073398935362
# next iteration: 375
#
#
# current iteration: 375
# diff: 0.3900000000000148
# pct diff: 0.002092723760463698
# next iteration: 376
#
#
# current iteration: 376
# diff: 1.5
# pct diff: 0.007984669434685404
# next iteration: 377
#
#
# current iteration: 377
# diff: -0.17000000000001592
# pct diff: -0.0009057488411743616
# next iteration: 378
#
#
# current iteration: 378
# diff: -0.539999999999992
# pct diff: -0.0028853860539673633
# next iteration: 379
#
#
# current iteration: 379
# diff: 1.1800000000000068
# pct diff: 0.006265597621196871
# next iteration: 380
#
#
# current iteration: 380
# diff: -3.160000000000025
# pct diff: -0.017065399362747882
# next iteration: 381
#
#
# current iteration: 381
# diff: 0.3300000000000125
# pct diff: 0.0017789757412399595
# next iteration: 382
#
#
# current iteration: 382
# diff: 2.3400000000000034
# pct diff: 0.012457410562180598
# next iteration: 383
#
#
# current iteration: 383
# diff: 2.069999999999993
# pct diff: 0.010899899952609095
# next iteration: 384
#
#
# current iteration: 384
# diff: 0.8300000000000125
# pct diff: 0.004351473209604763
# next iteration: 385
#
#
# current iteration: 385
# diff: -0.0700000000000216
# pct diff: -0.0003671264488384203
# next iteration: 386
#
#
# current iteration: 386
# diff: 1.5300000000000011
# pct diff: 0.00796045785639959
# next iteration: 387
#
#
# current iteration: 387
# diff: 0.17000000000001592
# pct diff: 0.0008837136767688097
# next iteration: 388
#
#
# current iteration: 388
# diff: 0.09999999999999432
# pct diff: 0.000519561490102324
# next iteration: 389
#
#
# current iteration: 389
# diff: -0.7700000000000102
# pct diff: -0.004016692749087169
# next iteration: 390
#
#
# current iteration: 390
# diff: -0.339999999999975
# pct diff: -0.0017767558528426785
# next iteration: 391
#
#
# current iteration: 391
# diff: -1.0800000000000125
# pct diff: -0.005675846121505216
# next iteration: 392
#
#
# current iteration: 392
# diff: -1.9699999999999989
# pct diff: -0.010461473102862296
# next iteration: 393
#
#
# current iteration: 393
# diff: -1.0999999999999943
# pct diff: -0.005875754500293757
# next iteration: 394
#
#
# current iteration: 394
# diff: 2.299999999999983
# pct diff: 0.012136562714368545
# next iteration: 395
#
#
# current iteration: 395
# diff: 1.3100000000000023
# pct diff: 0.006865108479195065
# next iteration: 396
#
#
# current iteration: 396
# diff: 0.040000000000020464
# pct diff: 0.00020957770093272797
# next iteration: 397
#
#
# current iteration: 397
# diff: -0.29000000000002046
# pct diff: -0.0015217505378602113
# next iteration: 398
#
#
# current iteration: 398
# diff: -0.6399999999999864
# pct diff: -0.0033696625072394373
# next iteration: 399
#
#
# current iteration: 399
# diff: -0.37000000000000455
# pct diff: -0.0019518885840894944
# next iteration: 400
#
#
# current iteration: 400
# diff: 0.6200000000000045
# pct diff: 0.003260069407929354
# next iteration: 401
#
#
# current iteration: 401
# diff: -1.5500000000000114
# pct diff: -0.008217144674760172
# next iteration: 402
#
#
# current iteration: 402
# diff: -0.37000000000000455
# pct diff: -0.0019653670455752927
# next iteration: 403
#
#
# current iteration: 403
# diff: 2.3799999999999955
# pct diff: 0.012484263533361286
# next iteration: 404
#
#
# current iteration: 404
# diff: -1.7199999999999989
# pct diff: -0.009104382807537576
# next iteration: 405
#
#
# current iteration: 405
# diff: 0.21999999999999886
# pct diff: 0.0011631595643438663
# next iteration: 406
#
#
# current iteration: 406
# diff: -0.22999999999998977
# pct diff: -0.0012175109840664325
# next iteration: 407
#
#
# current iteration: 407
# diff: 0.6899999999999977
# pct diff: 0.003639240506329102
# next iteration: 408
#
#
# current iteration: 408
# diff: 1.0500000000000114
# pct diff: 0.005507474429583065
# next iteration: 409
#
#
# current iteration: 409
# diff: -0.5500000000000114
# pct diff: -0.0028932140978433
# next iteration: 410
#
#
# current iteration: 410
# diff: -1.5
# pct diff: -0.007953340402969248
# next iteration: 411
#
#
# current iteration: 411
# diff: -3.9399999999999977
# pct diff: -0.021336510343333684
# next iteration: 412
#
#
# current iteration: 412
# diff: -5.560000000000002
# pct diff: -0.03104410943606925
# next iteration: 413
#
#
# current iteration: 413
# diff: -7.539999999999992
# pct diff: -0.04394963861039865
# next iteration: 414
#
#
# current iteration: 414
# diff: -2.0200000000000102
# pct diff: -0.011914592426566064
# next iteration: 415
#
#
# current iteration: 415
# diff: 6.510000000000019
# pct diff: 0.03697813121272377
# next iteration: 416
#
#
# current iteration: 416
# diff: 4.359999999999985
# pct diff: 0.024167174768582593
# next iteration: 417
#
#
# current iteration: 417
# diff: 0.009999999999990905
# pct diff: 5.542622769089295e-05
# next iteration: 418
#
#
# current iteration: 418
# diff: -1.4599999999999795
# pct diff: -0.008158247653106725
# next iteration: 419
#
#
# current iteration: 419
# diff: -5.340000000000003
# pct diff: -0.030756825250547192
# next iteration: 420
#
#
# current iteration: 420
# diff: 3.289999999999992
# pct diff: 0.01859702673675876
# next iteration: 421
#
#
# current iteration: 421
# diff: 0.12999999999999545
# pct diff: 0.000734297333935808
# next iteration: 422
#
#
# current iteration: 422
# diff: -2.6799999999999784
# pct diff: -0.01537049782060093
# next iteration: 423
#
#
# current iteration: 423
# diff: 4.3799999999999955
# pct diff: 0.024504867405169495
# next iteration: 424
#
#
# current iteration: 424
# diff: -2.390000000000015
# pct diff: -0.013552594272753132
# next iteration: 425
#
#
# current iteration: 425
# diff: 0.960000000000008
# pct diff: 0.005414246235406959
# next iteration: 426
#
#
# current iteration: 426
# diff: 0.8100000000000023
# pct diff: 0.0045474960700651375
# next iteration: 427
#
#
# current iteration: 427
# diff: -0.6700000000000159
# pct diff: -0.0037757114680192503
# next iteration: 428
#
#
# current iteration: 428
# diff: 2.219999999999999
# pct diff: 0.012355985974286186
# next iteration: 429
#
#
# current iteration: 429
# diff: 1.5600000000000023
# pct diff: 0.008607846383049176
# next iteration: 430
#
#
# current iteration: 430
# diff: -0.4099999999999966
# pct diff: -0.0022674482911182203
# next iteration: 431
#
#
# current iteration: 431
# diff: -2.9499999999999886
# pct diff: -0.01658514645527626
# next iteration: 432
#
#
# current iteration: 432
# diff: 0.9199999999999875
# pct diff: 0.005145701661166662
# next iteration: 433
#
#
# current iteration: 433
# diff: -2.319999999999993
# pct diff: -0.013146710489034924
# next iteration: 434
#
#
# current iteration: 434
# diff: -0.28999999999999204
# pct diff: -0.0016460438188216145
# next iteration: 435
#
#
# current iteration: 435
# diff: -0.6299999999999955
# pct diff: -0.0035887211620620643
# next iteration: 436
#
#
# current iteration: 436
# diff: -0.05000000000001137
# pct diff: -0.00028490028490034966
# next iteration: 437
#
#
# current iteration: 437
# diff: -4.400000000000006
# pct diff: -0.0257159555815313
# next iteration: 438
#
#
# current iteration: 438
# diff: 0.09999999999999432
# pct diff: 0.0005841121495326772
# next iteration: 439
#
#
# current iteration: 439
# diff: 3.1899999999999977
# pct diff: 0.018292333275990585
# next iteration: 440
#
#
# current iteration: 440
# diff: 0.46000000000000796
# pct diff: 0.0026308264226480296
# next iteration: 441
#
#
# current iteration: 441
# diff: 2.6100000000000136
# pct diff: 0.014707539727262558
# next iteration: 442
#
#
# current iteration: 442
# diff: 3.1599999999999966
# pct diff: 0.017495293987376793
# next iteration: 443
#
#
# current iteration: 443
# diff: -0.6200000000000045
# pct diff: -0.0034444444444444696
# next iteration: 444
#
#
# current iteration: 444
# diff: 1.4699999999999989
# pct diff: 0.008100512481401879
# next iteration: 445
#
#
# current iteration: 445
# diff: 1.6400000000000148
# pct diff: 0.008956365026486892
# next iteration: 446
#
#
# current iteration: 446
# diff: 0.10999999999998522
# pct diff: 0.0006003711385219148
# next iteration: 447
#
#
# current iteration: 447
# diff: 0.1699999999999875
# pct diff: 0.0009269862042640684
# next iteration: 448
#
#
# current iteration: 448
# diff: -1.1499999999999773
# pct diff: -0.00631035996488135
# next iteration: 449
#
#
# current iteration: 449
# diff: -0.8799999999999955
# pct diff: -0.004852227613586212
# next iteration: 450
#
#
# current iteration: 450
# diff: 2.789999999999992
# pct diff: 0.015150692370350214
# next iteration: 451
#
#
# current iteration: 451
# diff: 0.8299999999999841
# pct diff: 0.004486971564493373
# next iteration: 452
#
#
# current iteration: 452
# diff: 0.10000000000002274
# pct diff: 0.0005403068943160943
# next iteration: 453
#
#
# current iteration: 453
# diff: -0.2400000000000091
# pct diff: -0.0012984202553560328
# next iteration: 454
#
#
# current iteration: 454
# diff: -1.1500000000000057
# pct diff: -0.006260547661821578
# next iteration: 455
#
#
# current iteration: 455
# diff: 3.1100000000000136
# pct diff: 0.016648822269807354
# next iteration: 456
#
#
# current iteration: 456
# diff: 2.039999999999992
# pct diff: 0.010802796017792798
# next iteration: 457
#
#
# current iteration: 457
# diff: -0.46000000000000796
# pct diff: -0.0024418728102771417
# next iteration: 458
#
#
# current iteration: 458
# diff: -0.37000000000000455
# pct diff: -0.0019679804265730788
# next iteration: 459
#
#
# current iteration: 459
# diff: 2.140000000000015
# pct diff: 0.01125427294241396
# next iteration: 460
#
#
# current iteration: 460
# diff: -0.11000000000001364
# pct diff: -0.000578825510418931
# next iteration: 461
#
#
# current iteration: 461
# diff: -0.8199999999999932
# pct diff: -0.004333579959835077
# next iteration: 462
#
#
# current iteration: 462
# diff: 2.240000000000009
# pct diff: 0.011699571712107015
# next iteration: 463
#
#
# current iteration: 463
# diff: 0.5600000000000023
# pct diff: 0.002916362878866796
# next iteration: 464
#
#
# current iteration: 464
# diff: -0.5800000000000125
# pct diff: -0.0030296698704555605
# next iteration: 465
#
#
# current iteration: 465
# diff: -0.18999999999999773
# pct diff: -0.0009934640522875698
# next iteration: 466
#
#
# current iteration: 466
# diff: -0.09999999999999432
# pct diff: -0.0005231493591420053
# next iteration: 467
#
#
# current iteration: 467
# diff: -1.789999999999992
# pct diff: -0.009452893958597337
# next iteration: 468
#
#
# current iteration: 468
# diff: 0.4399999999999977
# pct diff: 0.0023182297154899774
# next iteration: 469
#
#
# current iteration: 469
# diff: -0.75
# pct diff: -0.003967204443268976
# next iteration: 470
#
#
# current iteration: 470
# diff: -2.640000000000015
# pct diff: -0.014162330347084463
# next iteration: 471
#
#
# current iteration: 471
# diff: -2.0900000000000034
# pct diff: -0.011338975694444463
# next iteration: 472
#
#
# current iteration: 472
# diff: 2.8000000000000114
# pct diff: 0.01496365968362554
# next iteration: 473
#
#
# current iteration: 473
# diff: -0.12999999999999545
# pct diff: -0.000695224343547759
# ...
# next iteration: 1356
#
#
# current iteration: 1356
# diff: -3.400000000000034
# pct diff: -0.012351060738157638
# next iteration: 1357
#
#
# current iteration: 1357
# diff: 0.6200000000000045
# pct diff: 0.0022471910112359717
# next iteration: 1358
#
#
# current iteration: 1358
# diff: -2.5600000000000023
# pct diff: -0.009365625228652969
# next iteration: 1359
#
#
# current iteration: 1359
# diff: -1.839999999999975
# pct diff: -0.006777163904235635
# next iteration: 1360
#
#
# current iteration: 1360
# diff: 0.7400000000000091
# pct diff: 0.002718189832500768
# next iteration: 1361
#
#
# current iteration: 1361
# diff: -3.660000000000025
# pct diff: -0.013627224663042763
# next iteration: 1362
#
#
# current iteration: 1362
# diff: -0.6899999999999977
# pct diff: -0.0025756840494232623
# next iteration: 1363
#
#
# current iteration: 1363
# diff: 5.819999999999993
# pct diff: 0.021263380950641165
# next iteration: 1364
#
#
# current iteration: 1364
# diff: 2.3700000000000045
# pct diff: 0.008584468270066665
# next iteration: 1365
#
#
# current iteration: 1365
# diff: 1.7900000000000205
# pct diff: 0.006441861302047794
# next iteration: 1366
#
#
# current iteration: 1366
# diff: 2.7900000000000205
# pct diff: 0.009940853701988243
# next iteration: 1367
#
#
# current iteration: 1367
# diff: 1.2799999999999727
# pct diff: 0.004539973043909955
# next iteration: 1368
#
#
# current iteration: 1368
# diff: -0.06999999999999318
# pct diff: -0.0002483414339943704
# next iteration: 1369
#
#
# current iteration: 1369
# diff: -0.4900000000000091
# pct diff: -0.0017414173004478254
# next iteration: 1370
#
#
# current iteration: 1370
# diff: 1.160000000000025
# pct diff: 0.004105613364479454
# next iteration: 1371
#
#
# current iteration: 1371
# diff: -0.3100000000000023
# pct diff: -0.0010983949261240912
# next iteration: 1372
#
#
# current iteration: 1372
# diff: 0.0999999999999659
# pct diff: 0.0003541954450464559
# next iteration: 1373
#
#
# current iteration: 1373
# diff: 2.9600000000000364
# pct diff: 0.010375407480108087
# next iteration: 1374
#
#
# current iteration: 1374
# diff: 0.6399999999999864
# pct diff: 0.002238310075892653
# next iteration: 1375
#
#
# current iteration: 1375
# diff: 2.740000000000009
# pct diff: 0.009491807253957837
# next iteration: 1376
#
#
# current iteration: 1376
# diff: -0.4200000000000159
# pct diff: -0.0014570685169124577
# next iteration: 1377
#
#
# current iteration: 1377
# diff: -0.36000000000001364
# pct diff: -0.0012504776129772263
# next iteration: 1378
#
#
# current iteration: 1378
# diff: -2.819999999999993
# pct diff: -0.009892307152629155
# next iteration: 1379
#
#
# current iteration: 1379
# diff: -0.2799999999999727
# pct diff: -0.0009831805892059858
# next iteration: 1380
#
#
# current iteration: 1380
# diff: 1.0
# pct diff: 0.0034990727457223834
# next iteration: 1381
#
#
# current iteration: 1381
# diff: 1.4799999999999613
# pct diff: 0.005151947645072446
# next iteration: 1382
#
#
# current iteration: 1382
# diff: 2.6000000000000227
# pct diff: 0.008969538068789536
# next iteration: 1383
#
#
# current iteration: 1383
# diff: 0.7599999999999909
# pct diff: 0.002615008774042566
# next iteration: 1384
#
#
# current iteration: 1384
# diff: 2.319999999999993
# pct diff: 0.00791944017750467
# next iteration: 1385
#
#
# current iteration: 1385
# diff: -0.3299999999999841
# pct diff: -0.001127742464629841
# next iteration: 1386
#
#
# current iteration: 1386
# diff: -1.6100000000000136
# pct diff: -0.005532455929349554
# next iteration: 1387
#
#
# current iteration: 1387
# diff: 0.36000000000001364
# pct diff: 0.001235542437450711
# next iteration: 1388
#
#
# current iteration: 1388
# diff: 1.3999999999999773
# pct diff: 0.0047819107148955745
# next iteration: 1389
#
#
# current iteration: 1389
# diff: 0.6800000000000068
# pct diff: 0.002317260180610008
# next iteration: 1390
#
#
# current iteration: 1390
# diff: 1.3199999999999932
# pct diff: 0.004478067645961235
# next iteration: 1391
#
#
# current iteration: 1391
# diff: 0.09000000000003183
# pct diff: 0.0003052296004884753
# next iteration: 1392
#
#
# current iteration: 1392
# diff: -0.9499999999999886
# pct diff: -0.0032322819910856676
# next iteration: 1393
#
#
# current iteration: 1393
# diff: -2.0
# pct diff: -0.006851426809633105
# next iteration: 1394
#
#
# current iteration: 1394
# diff: 1.0699999999999932
# pct diff: 0.0036521264250119227
# next iteration: 1395
#
#
# current iteration: 1395
# diff: -1.6299999999999955
# pct diff: -0.005594645615239387
# next iteration: 1396
#
#
# current iteration: 1396
# diff: 0.7199999999999704
# pct diff: 0.002465162461053756
# next iteration: 1397
#
#
# current iteration: 1397
# diff: 2.090000000000032
# pct diff: 0.007104976883328908
# next iteration: 1398
#
#
# current iteration: 1398
# diff: 1.3799999999999955
# pct diff: 0.004669418691209296
# next iteration: 1399
#
#
# current iteration: 1399
# diff: -1.410000000000025
# pct diff: -0.004793798660456346
# next iteration: 1400
#
#
# current iteration: 1400
# diff: 1.9700000000000273
# pct diff: 0.006653157716987596
# next iteration: 1401
#
#
# current iteration: 1401
# diff: -0.5400000000000205
# pct diff: -0.0018270401948843567
# next iteration: 1402
#
#
# current iteration: 1402
# diff: -0.7300000000000182
# pct diff: -0.0024760031204423506
# next iteration: 1403
#
#
# current iteration: 1403
# diff: -3.2199999999999704
# pct diff: -0.011042145331092797
# next iteration: 1404
#
#
# current iteration: 1404
# diff: -2.5400000000000205
# pct diff: -0.008786799045214034
# next iteration: 1405
#
#
# current iteration: 1405
# diff: -2.180000000000007
# pct diff: -0.007598731221025504
# next iteration: 1406
#
#
# current iteration: 1406
# diff: -8.620000000000005
# pct diff: -0.030977108563625275
# next iteration: 1407
#
#
# current iteration: 1407
# diff: 3.900000000000034
# pct diff: 0.013821455151150136
# next iteration: 1408
#
#
# current iteration: 1408
# diff: 0.15999999999996817
# pct diff: 0.00056671271207441
# next iteration: 1409
#
#
# current iteration: 1409
# diff: 5.5400000000000205
# pct diff: 0.019244797999096886
# next iteration: 1410
#
#
# current iteration: 1410
# diff: -1.9599999999999795
# pct diff: -0.006855304116680002
# next iteration: 1411
#
#
# current iteration: 1411
# diff: -3.480000000000018
# pct diff: -0.01232163721984215
# next iteration: 1412
#
#
# current iteration: 1412
# diff: 4.389999999999986
# pct diff: 0.015305766682936987
# next iteration: 1413
#
#
# current iteration: 1413
# diff: -8.480000000000018
# pct diff: -0.03046633613566149
# next iteration: 1414
#
#
# current iteration: 1414
# diff: 0.7400000000000091
# pct diff: 0.0026515694424538096
# next iteration: 1415
#
#
# current iteration: 1415
# diff: 4.1200000000000045
# pct diff: 0.014548022598870072
# next iteration: 1416
#
#
# current iteration: 1416
# diff: 3.410000000000025
# pct diff: 0.01189770070827963
# next iteration: 1417
#
#
# current iteration: 1417
# diff: -2.1999999999999886
# pct diff: -0.007735311697900877
# next iteration: 1418
#
#
# current iteration: 1418
# diff: 2.319999999999993
# pct diff: 0.008091235657238493
# next iteration: 1419
#
#
# current iteration: 1419
# diff: -0.09000000000003183
# pct diff: -0.00031398269606486127
# next iteration: 1420
#
#
# current iteration: 1420
# diff: -7.360000000000014
# pct diff: -0.026353480378115204
# next iteration: 1421
#
#
# current iteration: 1421
# diff: 3.080000000000041
# pct diff: 0.010908060631817682
# next iteration: 1422
#
#
# current iteration: 1422
# diff: -1.1000000000000227
# pct diff: -0.003910972054327038
# next iteration: 1423
#
#
# current iteration: 1423
# diff: 1.9800000000000182
# pct diff: 0.006990538059596166
# next iteration: 1424
#
#
# current iteration: 1424
# diff: 3.6100000000000136
# pct diff: 0.012584974725466318
# next iteration: 1425
#
#
# current iteration: 1425
# diff: -0.12000000000000455
# pct diff: -0.00041851218916752535
# next iteration: 1426
#
#
# current iteration: 1426
# diff: -1.6800000000000068
# pct diff: -0.005893702859147542
# next iteration: 1427
#
#
# current iteration: 1427
# diff: 3.240000000000009
# pct diff: 0.011238683270318113
# next iteration: 1428
#
#
# current iteration: 1428
# diff: 3.6999999999999886
# pct diff: 0.012671666837905368
# next iteration: 1429
#
#
# current iteration: 1429
# diff: 0.2300000000000182
# pct diff: 0.0007870782287318397
# next iteration: 1430
#
#
# current iteration: 1430
# diff: 0.13999999999998636
# pct diff: 0.00047886167738400037
# next iteration: 1431
#
#
# current iteration: 1431
# diff: -0.060000000000002274
# pct diff: -0.00020526855969894722
# next iteration: 1432
#
#
# current iteration: 1432
# diff: 2.069999999999993
# pct diff: 0.007031966572680617
# next iteration: 1433
#
#
# current iteration: 1433
# diff: 1.0199999999999818
# pct diff: 0.003453062053556254
# next iteration: 1434
#
#
# current iteration: 1434
# diff: -0.18999999999999773
# pct diff: -0.0006436314363143555
# next iteration: 1435
#
#
# current iteration: 1435
# diff: -0.9099999999999682
# pct diff: -0.0030921879778448747
# next iteration: 1436
#
#
# current iteration: 1436
# diff: 0.7399999999999523
# pct diff: 0.0025082195031012177
# next iteration: 1437
#
#
# current iteration: 1437
# diff: 0.18000000000000682
# pct diff: 0.0006097354425663319
# next iteration: 1438
#
#
# current iteration: 1438
# diff: -0.01999999999998181
# pct diff: -6.775297266161391e-05
# next iteration: 1439
#
#
# current iteration: 1439
# diff: -1.3999999999999773
# pct diff: -0.004765308553728777
# next iteration: 1440
#
#
# current iteration: 1440
# diff: -0.06999999999999318
# pct diff: -0.0002383222116301007
# next iteration: 1441
#
#
# current iteration: 1441
# diff: -2.3000000000000114
# pct diff: -0.007892388991833131
# next iteration: 1442
#
#
# current iteration: 1442
# diff: 1.7199999999999704
# pct diff: 0.005867503581906156
# next iteration: 1443
#
#
# current iteration: 1443
# diff: -0.6100000000000136
# pct diff: -0.0020852562130380258
# next iteration: 1444
#
#
# current iteration: 1444
# diff: -1.5699999999999932
# pct diff: -0.005395930712125355
# next iteration: 1445
#
#
# current iteration: 1445
# diff: 1.3500000000000227
# pct diff: 0.00461838459170067
# next iteration: 1446
#
#
# current iteration: 1446
# diff: -3.480000000000018
# pct diff: -0.01204860990894304
# next iteration: 1447
#
#
# current iteration: 1447
# diff: -5.099999999999966
# pct diff: -0.01797483523067693
# next iteration: 1448
#
#
# current iteration: 1448
# diff: 2.319999999999993
# pct diff: 0.008110470197517892
# next iteration: 1449
#
#
# current iteration: 1449
# diff: 3.8700000000000045
# pct diff: 0.013348509933774849
# next iteration: 1450
#
#
# current iteration: 1450
# diff: -1.25
# pct diff: -0.004330204039214328
# next iteration: 1451
#
#
# current iteration: 1451
# diff: -4.480000000000018
# pct diff: -0.01576410148140335
# next iteration: 1452
#
#
# current iteration: 1452
# diff: 2.6999999999999886
# pct diff: 0.009411272613196657
# next iteration: 1453
#
#
# current iteration: 1453
# diff: 1.9399999999999977
# pct diff: 0.0067167537998130316
# next iteration: 1454
#
#
# current iteration: 1454
# diff: 2.990000000000009
# pct diff: 0.010246042080734732
# next iteration: 1455
#
#
# current iteration: 1455
# diff: -0.3199999999999932
# pct diff: -0.0010977701543739046
# next iteration: 1456
#
#
# current iteration: 1456
# diff: 2.8799999999999955
# pct diff: 0.009783273320198368
# next iteration: 1457
#
#
# current iteration: 1457
# diff: -0.46999999999997044
# pct diff: -0.001599128985063354
# next iteration: 1458
#
#
# current iteration: 1458
# diff: 0.8699999999999477
# pct diff: 0.0029513535518011663
# next iteration: 1459
#
#
# current iteration: 1459
# diff: -1.2899999999999636
# pct diff: -0.004395379740365817
# next iteration: 1460
#
#
# current iteration: 1460
# diff: 1.990000000000009
# pct diff: 0.006734804386083691
# next iteration: 1461
#
#
# current iteration: 1461
# diff: -0.9700000000000273
# pct diff: -0.0032936063291569974
# next iteration: 1462
#
#
# current iteration: 1462
# diff: 0.8600000000000136
# pct diff: 0.0029116023969936473
# next iteration: 1463
#
#
# current iteration: 1463
# diff: 0.4800000000000182
# pct diff: 0.001622443805982823
# next iteration: 1464
#
#
# current iteration: 1464
# diff: 1.2099999999999795
# pct diff: 0.004073251195044703
# next iteration: 1465
#
#
# current iteration: 1465
# diff: 1.6800000000000068
# pct diff: 0.005623619200642722
# next iteration: 1466
#
#
# current iteration: 1466
# diff: -0.09000000000003183
# pct diff: -0.00030135610246118143
# next iteration: 1467
#
#
# current iteration: 1467
# diff: 0.910000000000025
# pct diff: 0.003037788756843454
# next iteration: 1468
#
#
# current iteration: 1468
# diff: -0.7900000000000205
# pct diff: -0.0026441744485725493
# next iteration: 1469
#
#
# current iteration: 1469
# diff: 2.759999999999991
# pct diff: 0.009153318077803174
# next iteration: 1470
#
#
# current iteration: 1470
# diff: 1.2200000000000273
# pct diff: 0.004029727497935681
# next iteration: 1471
#
#
# current iteration: 1471
# diff: -0.339999999999975
# pct diff: -0.001124301445057951
# next iteration: 1472
#
#
# current iteration: 1472
# diff: 0.06999999999999318
# pct diff: 0.00023142025919066774
# next iteration: 1473
#
#
# current iteration: 1473
# diff: 1.0600000000000023
# pct diff: 0.0034921262436581743
# next iteration: 1474
#
#
# current iteration: 1474
# diff: 0.75
# pct diff: 0.0024647540175490486
# next iteration: 1475
#
#
# current iteration: 1475
# diff: -0.5800000000000409
# pct diff: -0.001909716505877452
# next iteration: 1476
#
#
# current iteration: 1476
# diff: 0.6400000000000432
# pct diff: 0.002102842122556409
# next iteration: 1477
#
#
# current iteration: 1477
# diff: 0.0999999999999659
# pct diff: 0.0003284611594677809
# next iteration: 1478
#
#
# current iteration: 1478
# diff: 0.4399999999999977
# pct diff: 0.0014431434287775844
# next iteration: 1479
#
#
# current iteration: 1479
# diff: 2.2100000000000364
# pct diff: 0.007196352979485628
# next iteration: 1480
#
#
# current iteration: 1480
# diff: 0.22999999999996135
# pct diff: 0.0007483812188851116
# next iteration: 1481
#
#
# current iteration: 1481
# diff: -0.08999999999997499
# pct diff: -0.0002929306079936694
# next iteration: 1482
#
#
# current iteration: 1482
# diff: -1.150000000000034
# pct diff: -0.0037570649155478264
# next iteration: 1483
#
#
# current iteration: 1483
# diff: -0.48999999999995225
# pct diff: -0.0016034031413611001
# next iteration: 1484
#
#
# current iteration: 1484
# diff: 0.67999999999995
# pct diff: 0.0022201906751990012
# next iteration: 1485
#
#
# current iteration: 1485
# diff: 2.3800000000000523
# pct diff: 0.007710749692218143
# next iteration: 1486
#
#
# current iteration: 1486
# diff: 0.6899999999999977
# pct diff: 0.0022304832713754574
# next iteration: 1487
#
#
# current iteration: 1487
# diff: 1.3799999999999955
# pct diff: 0.004441154700222043
# next iteration: 1488
#
#
# current iteration: 1488
# diff: -1.150000000000034
# pct diff: -0.0037147102526004076
# next iteration: 1489
#
#
# current iteration: 1489
# diff: -2.6299999999999955
# pct diff: -0.008568170711842306
# next iteration: 1490
#
#
# current iteration: 1490
# diff: -2.0600000000000023
# pct diff: -0.00675653514382237
# next iteration: 1491
#
#
# current iteration: 1491
# diff: 1.8799999999999955
# pct diff: 0.006128369788440837
# next iteration: 1492
#
#
# current iteration: 1492
# diff: 0.5600000000000023
# pct diff: 0.0018221455764162375
# next iteration: 1493
#
#
# current iteration: 1493
# diff: 2.8000000000000114
# pct diff: 0.009028471931125694
# next iteration: 1494
#
#
# current iteration: 1494
# diff: -0.9699999999999704
# pct diff: -0.003137533962996411
# next iteration: 1495
#
#
# current iteration: 1495
# diff: -0.35000000000002274
# pct diff: -0.0011333829863023307
# next iteration: 1496
#
#
# current iteration: 1496
# diff: 0.8799999999999955
# pct diff: 0.002841551228647988
# next iteration: 1497
#
#
# current iteration: 1497
# diff: 2.670000000000016
# pct diff: 0.008547829427583607
# next iteration: 1498
#
#
# current iteration: 1498
# diff: 0.18999999999999773
# pct diff: 0.0006079027355623027
# next iteration: 1499
#
#
# current iteration: 1499
# diff: 2.1399999999999864
# pct diff: 0.006800343194890166
# next iteration: 1500
#
#
# current iteration: 1500
# diff: 0.06999999999999318
# pct diff: 0.00022239166348962124
# next iteration: 1501
#
#
# current iteration: 1501
# diff: 0.01999999999998181
# pct diff: 6.353643814721969e-05
# next iteration: 1502
#
#
# current iteration: 1502
# diff: 1.2900000000000205
# pct diff: 0.004081374379093304
# next iteration: 1503
#
#
# current iteration: 1503
# diff: 1.3899999999999864
# pct diff: 0.004378504378504336
# next iteration: 1504
#
#
# current iteration: 1504
# diff: 0.4800000000000182
# pct diff: 0.0015097188148707876
# next iteration: 1505
#
#
# current iteration: 1505
# diff: 0.009999999999990905
# pct diff: 3.1451486082688803e-05
# next iteration: 1506
#
#
# current iteration: 1506
# diff: 1.6999999999999886
# pct diff: 0.005318316909119314
# next iteration: 1507
#
#
# current iteration: 1507
# diff: -0.07999999999998408
# pct diff: -0.0002503363895233723
# next iteration: 1508
#
#
# current iteration: 1508
# diff: -1.7699999999999818
# pct diff: -0.005569540591566966
# next iteration: 1509
#
#
# current iteration: 1509
# diff: 0.7799999999999727
# pct diff: 0.0024483646179922556
# next iteration: 1510

# %%
# containers for returns by day of the week and year
mon_2016 = []
tue_2016 = []
wed_2016 = []
thu_2016 = []
fri_2016 = []

mon_2017 = []
tue_2017 = []
wed_2017 = []
thu_2017 = []
fri_2017 = []

mon_2018 = []
tue_2018 = []
wed_2018 = []
thu_2018 = []
fri_2018 = []

mon_2019 = []
tue_2019 = []
wed_2019 = []
thu_2019 = []
fri_2019 = []

mon_2020 = []
tue_2020 = []
wed_2020 = []
thu_2020 = []
fri_2020 = []

# %%
len(pct_diff_l)
# Out:
# 1510

# %%
for i in range(len(spy_ac_l)):
    year = spy_year_l[i]
    weekday = spy_weekday_l[i]
    ret = pct_diff_l[i]
    
    # 2016
    if year == '2016' and weekday == 'Monday':
        mon_2016.append(ret)
    if year == '2016' and weekday == 'Tuesday':
        tue_2016.append(ret)
    if year == '2016' and weekday == 'Wednesday':
        wed_2016.append(ret)
    if year == '2016' and weekday == 'Thursday':
        thu_2016.append(ret)
    if year == '2016' and weekday == 'Friday':
        fri_2016.append(ret)
    
    # 2017       
    if year == '2017' and weekday == 'Monday':
        mon_2017.append(ret)
    if year == '2017' and weekday == 'Tuesday':
        tue_2017.append(ret)
    if year == '2017' and weekday == 'Wednesday':
        wed_2017.append(ret)       
    if year == '2017' and weekday == 'Thursday':
        thu_2017.append(ret)
    if year == '2017' and weekday == 'Friday':
        fri_2017.append(ret)
        
     # 2018       
    if year == '2018' and weekday == 'Monday':
        mon_2018.append(ret)
    if year == '2018' and weekday == 'Tuesday':
        tue_2018.append(ret)
    if year == '2018' and weekday == 'Wednesday':
        wed_2018.append(ret)
    if year == '2018' and weekday == 'Thursday':
        thu_2018.append(ret)
    if year == '2018' and weekday == 'Friday':
        fri_2018.append(ret)
        
    # 2019       
    if year == '2019' and weekday == 'Monday':
        mon_2019.append(ret)
    if year == '2019' and weekday == 'Tuesday':
        tue_2019.append(ret)
    if year == '2019' and weekday == 'Wednesday':
        wed_2019.append(ret)
    if year == '2019' and weekday == 'Thursday':
        thu_2019.append(ret)
    if year == '2019' and weekday == 'Friday':
        fri_2019.append(ret)
        
    # 2020       
    if year == '2020' and weekday == 'Monday':
        mon_2020.append(ret)
    if year == '2020' and weekday == 'Tuesday':
        tue_2020.append(ret)
    if year == '2020' and weekday == 'Wednesday':
        wed_2020.append(ret)
    if year == '2020' and weekday == 'Thursday':
        thu_2020.append(ret)
    if year == '2020' and weekday == 'Friday':
        fri_2020.append(ret)

# %%
# containers for returns by day of the week, year, and sign of the return

# 2016
mon_2016_pos = [x for x in mon_2016 if x > 0]
tue_2016_pos = [x for x in tue_2016 if x > 0]
wed_2016_pos = [x for x in wed_2016 if x > 0]
thu_2016_pos = [x for x in thu_2016 if x > 0]
fri_2016_pos = [x for x in fri_2016 if x > 0]

mon_2016_neg = [x for x in mon_2016 if x < 0]
tue_2016_neg = [x for x in tue_2016 if x < 0]
wed_2016_neg = [x for x in wed_2016 if x < 0]
thu_2016_neg = [x for x in thu_2016 if x < 0]
fri_2016_neg = [x for x in fri_2016 if x < 0] 

# 2017
mon_2017_pos = [x for x in mon_2017 if x > 0]
tue_2017_pos = [x for x in tue_2017 if x > 0]
wed_2017_pos = [x for x in wed_2017 if x > 0]
thu_2017_pos = [x for x in thu_2017 if x > 0]
fri_2017_pos = [x for x in fri_2017 if x > 0]

mon_2017_neg = [x for x in mon_2017 if x < 0]
tue_2017_neg = [x for x in tue_2017 if x < 0]
wed_2017_neg = [x for x in wed_2017 if x < 0]
thu_2017_neg = [x for x in thu_2017 if x < 0]
fri_2017_neg = [x for x in fri_2017 if x < 0] 

# 2018
mon_2018_pos = [x for x in mon_2018 if x > 0]
tue_2018_pos = [x for x in tue_2018 if x > 0]
wed_2018_pos = [x for x in wed_2018 if x > 0]
thu_2018_pos = [x for x in thu_2018 if x > 0]
fri_2018_pos = [x for x in fri_2018 if x > 0]

mon_2018_neg = [x for x in mon_2018 if x < 0]
tue_2018_neg = [x for x in tue_2018 if x < 0]
wed_2018_neg = [x for x in wed_2018 if x < 0]
thu_2018_neg = [x for x in thu_2018 if x < 0]
fri_2018_neg = [x for x in fri_2018 if x < 0] 

# 2019
mon_2019_pos = [x for x in mon_2019 if x > 0]
tue_2019_pos = [x for x in tue_2019 if x > 0]
wed_2019_pos = [x for x in wed_2019 if x > 0]
thu_2019_pos = [x for x in thu_2019 if x > 0]
fri_2019_pos = [x for x in fri_2019 if x > 0]

mon_2019_neg = [x for x in mon_2019 if x < 0]
tue_2019_neg = [x for x in tue_2019 if x < 0]
wed_2019_neg = [x for x in wed_2019 if x < 0]
thu_2019_neg = [x for x in thu_2019 if x < 0]
fri_2019_neg = [x for x in fri_2019 if x < 0]

# 2020
mon_2020_pos = [x for x in mon_2020 if x > 0]
tue_2020_pos = [x for x in tue_2020 if x > 0]
wed_2020_pos = [x for x in wed_2020 if x > 0]
thu_2020_pos = [x for x in thu_2020 if x > 0]
fri_2020_pos = [x for x in fri_2020 if x > 0]

mon_2020_neg = [x for x in mon_2020 if x < 0]
tue_2020_neg = [x for x in tue_2020 if x < 0]
wed_2020_neg = [x for x in wed_2020 if x < 0]
thu_2020_neg = [x for x in thu_2020 if x < 0]
fri_2020_neg = [x for x in fri_2020 if x < 0]

# %%
# calculate mean and standard deviation of returns by day of the week and by year

# 2016 
avg_mon_2016 = stats.mean(mon_2016)
stdev_mon_2016 = stats.stdev(mon_2016)

avg_tue_2016 = stats.mean(tue_2016)
stdev_tue_2016 = stats.stdev(tue_2016)

avg_wed_2016 = stats.mean(wed_2016)
stdev_wed_2016 = stats.stdev(wed_2016)

avg_thu_2016 = stats.mean(thu_2016)
stdev_thu_2016 = stats.stdev(thu_2016)

avg_fri_2016 = stats.mean(fri_2016)
stdev_fri_2016 = stats.stdev(fri_2016)

# 2017 
avg_mon_2017 = stats.mean(mon_2017)
stdev_mon_2017 = stats.stdev(mon_2017)

avg_tue_2017 = stats.mean(tue_2017)
stdev_tue_2017 = stats.stdev(tue_2017)

avg_wed_2017 = stats.mean(wed_2017)
stdev_wed_2017 = stats.stdev(wed_2017)

avg_thu_2017 = stats.mean(thu_2017)
stdev_thu_2017 = stats.stdev(thu_2017)

avg_fri_2017 = stats.mean(fri_2017)
stdev_fri_2017 = stats.stdev(fri_2017)

# 2018 
avg_mon_2018 = stats.mean(mon_2018)
stdev_mon_2018 = stats.stdev(mon_2018)

avg_tue_2018 = stats.mean(tue_2018)
stdev_tue_2018 = stats.stdev(tue_2018)

avg_wed_2018 = stats.mean(wed_2018)
stdev_wed_2018 = stats.stdev(wed_2018)

avg_thu_2018 = stats.mean(thu_2018)
stdev_thu_2018 = stats.stdev(thu_2018)

avg_fri_2018 = stats.mean(fri_2018)
stdev_fri_2018 = stats.stdev(fri_2018)

# 2019 
avg_mon_2019 = stats.mean(mon_2019)
stdev_mon_2019 = stats.stdev(mon_2019)

avg_tue_2019 = stats.mean(tue_2019)
stdev_tue_2019 = stats.stdev(tue_2019)

avg_wed_2019 = stats.mean(wed_2019)
stdev_wed_2019 = stats.stdev(wed_2019)

avg_thu_2019 = stats.mean(thu_2019)
stdev_thu_2019 = stats.stdev(thu_2019)

avg_fri_2019 = stats.mean(fri_2019)
stdev_fri_2019 = stats.stdev(fri_2019)

# %%
# calculate average returns and length

# 2016 - positive returns
avg_mon_2016_pos = stats.mean(mon_2016_pos)
num_mon_2016_pos = len(mon_2016_pos)
stdev_mon_2016_pos = stats.stdev(mon_2016_pos)

avg_tue_2016_pos = stats.mean(tue_2016_pos)
num_tue_2016_pos = len(tue_2016_pos)
stdev_tue_2016_pos = stats.stdev(tue_2016_pos)

avg_wed_2016_pos = stats.mean(wed_2016_pos)
num_wed_2016_pos = len(wed_2016_pos)
stdev_wed_2016_pos = stats.stdev(wed_2016_pos)

avg_thu_2016_pos = stats.mean(thu_2016_pos)
num_thu_2016_pos = len(thu_2016_pos)
stdev_thu_2016_pos = stats.stdev(thu_2016_pos)

avg_fri_2016_pos = stats.mean(fri_2016_pos)
num_fri_2016_pos = len(fri_2016_pos)
stdev_fri_2016_pos = stats.stdev(fri_2016_pos)

#2016 - negative returns
avg_mon_2016_neg = stats.mean(mon_2016_neg)
num_mon_2016_neg = len(mon_2016_neg)
stdev_mon_2016_neg = stats.stdev(mon_2016_neg)

avg_tue_2016_neg = stats.mean(tue_2016_neg)
num_tue_2016_neg = len(tue_2016_neg)
stdev_tue_2016_neg = stats.stdev(tue_2016_neg)

avg_wed_2016_neg = stats.mean(wed_2016_neg)
num_wed_2016_neg = len(wed_2016_neg)
stdev_wed_2016_neg = stats.stdev(wed_2016_neg)

avg_thu_2016_neg = stats.mean(thu_2016_neg)
num_thu_2016_neg = len(thu_2016_neg)
stdev_thu_2016_neg = stats.stdev(thu_2016_neg)

avg_fri_2016_neg = stats.mean(fri_2016_neg)
num_fri_2016_neg = len(fri_2016_neg)
stdev_fri_2016_neg = stats.stdev(fri_2016_neg)

# %%
# calculate average returns and length

# 2017 - positive returns
avg_mon_2017_pos = stats.mean(mon_2017_pos)
num_mon_2017_pos = len(mon_2017_pos)
stdev_mon_2017_pos = stats.stdev(mon_2017_pos)

avg_tue_2017_pos = stats.mean(tue_2017_pos)
num_tue_2017_pos = len(tue_2017_pos)
stdev_tue_2017_pos = stats.stdev(tue_2017_pos)

avg_wed_2017_pos = stats.mean(wed_2017_pos)
num_wed_2017_pos = len(wed_2017_pos)
stdev_wed_2017_pos = stats.stdev(wed_2017_pos)

avg_thu_2017_pos = stats.mean(thu_2017_pos)
num_thu_2017_pos = len(thu_2017_pos)
stdev_thu_2017_pos = stats.stdev(thu_2017_pos)

avg_fri_2017_pos = stats.mean(fri_2017_pos)
num_fri_2017_pos = len(fri_2017_pos)
stdev_fri_2017_pos = stats.stdev(fri_2017_pos)

#2017 - negative returns
avg_mon_2017_neg = stats.mean(mon_2017_neg)
num_mon_2017_neg = len(mon_2017_neg)
stdev_mon_2017_neg = stats.stdev(mon_2017_neg)

avg_tue_2017_neg = stats.mean(tue_2017_neg)
num_tue_2017_neg = len(tue_2017_neg)
stdev_tue_2017_neg = stats.stdev(tue_2017_neg)

avg_wed_2017_neg = stats.mean(wed_2017_neg)
num_wed_2017_neg = len(wed_2017_neg)
stdev_wed_2017_neg = stats.stdev(wed_2017_neg)

avg_thu_2017_neg = stats.mean(thu_2017_neg)
num_thu_2017_neg = len(thu_2017_neg)
stdev_thu_2017_neg = stats.stdev(thu_2017_neg)

avg_fri_2017_neg = stats.mean(fri_2017_neg)
num_fri_2017_neg = len(fri_2017_neg)
stdev_fri_2017_neg = stats.stdev(fri_2017_neg)

# %%
# calculate average returns and length

# 2018 - positive returns
avg_mon_2018_pos = stats.mean(mon_2018_pos)
num_mon_2018_pos = len(mon_2018_pos)
stdev_mon_2018_pos = stats.stdev(mon_2018_pos)

avg_tue_2018_pos = stats.mean(tue_2018_pos)
num_tue_2018_pos = len(tue_2018_pos)
stdev_tue_2018_pos = stats.stdev(tue_2018_pos)

avg_wed_2018_pos = stats.mean(wed_2018_pos)
num_wed_2018_pos = len(wed_2018_pos)
stdev_wed_2018_pos = stats.stdev(wed_2018_pos)

avg_thu_2018_pos = stats.mean(thu_2018_pos)
num_thu_2018_pos = len(thu_2018_pos)
stdev_thu_2018_pos = stats.stdev(thu_2018_pos)

avg_fri_2018_pos = stats.mean(fri_2018_pos)
num_fri_2018_pos = len(fri_2018_pos)
stdev_fri_2018_pos = stats.stdev(fri_2018_pos)

#2018 - negative returns
avg_mon_2018_neg = stats.mean(mon_2018_neg)
num_mon_2018_neg = len(mon_2018_neg)
stdev_mon_2018_neg = stats.stdev(mon_2018_neg)

avg_tue_2018_neg = stats.mean(tue_2018_neg)
num_tue_2018_neg = len(tue_2018_neg)
stdev_tue_2018_neg = stats.stdev(tue_2018_neg)

avg_wed_2018_neg = stats.mean(wed_2018_neg)
num_wed_2018_neg = len(wed_2018_neg)
stdev_wed_2018_neg = stats.stdev(wed_2018_neg)

avg_thu_2018_neg = stats.mean(thu_2018_neg)
num_thu_2018_neg = len(thu_2018_neg)
stdev_thu_2018_neg = stats.stdev(thu_2018_neg)

avg_fri_2018_neg = stats.mean(fri_2018_neg)
num_fri_2018_neg = len(fri_2018_neg)
stdev_fri_2018_neg = stats.stdev(fri_2018_neg)

# %%
# calculate average returns and length

# 2019 - positive returns
avg_mon_2019_pos = stats.mean(mon_2019_pos)
num_mon_2019_pos = len(mon_2019_pos)
stdev_mon_2019_pos = stats.stdev(mon_2019_pos)

avg_tue_2019_pos = stats.mean(tue_2019_pos)
num_tue_2019_pos = len(tue_2019_pos)
stdev_tue_2019_pos = stats.stdev(tue_2019_pos)

avg_wed_2019_pos = stats.mean(wed_2019_pos)
num_wed_2019_pos = len(wed_2019_pos)
stdev_wed_2019_pos = stats.stdev(wed_2019_pos)

avg_thu_2019_pos = stats.mean(thu_2019_pos)
num_thu_2019_pos = len(thu_2019_pos)
stdev_thu_2019_pos = stats.stdev(thu_2019_pos)

avg_fri_2019_pos = stats.mean(fri_2019_pos)
num_fri_2019_pos = len(fri_2019_pos)
stdev_fri_2019_pos = stats.stdev(fri_2019_pos)

#2019 - negative returns
avg_mon_2019_neg = stats.mean(mon_2019_neg)
num_mon_2019_neg = len(mon_2019_neg)
stdev_mon_2019_neg = stats.stdev(mon_2019_neg)

avg_tue_2019_neg = stats.mean(tue_2019_neg)
num_tue_2019_neg = len(tue_2019_neg)
stdev_tue_2019_neg = stats.stdev(tue_2019_neg)

avg_wed_2019_neg = stats.mean(wed_2019_neg)
num_wed_2019_neg = len(wed_2019_neg)
stdev_wed_2019_neg = stats.stdev(wed_2019_neg)

avg_thu_2019_neg = stats.mean(thu_2019_neg)
num_thu_2019_neg = len(thu_2019_neg)
stdev_thu_2019_neg = stats.stdev(thu_2019_neg)

avg_fri_2019_neg = stats.mean(fri_2019_neg)
num_fri_2019_neg = len(fri_2019_neg)
stdev_fri_2019_neg = stats.stdev(fri_2019_neg)

# %% [markdown]
# ### Create a summary table

# %%
# create a dataframe with all the results per year
cols = ['day','avg_return','stdev_return','num_neg','avg_neg','stdev_neg','num_pos','avg_pos','stdev_pos']

# 2016
res_2016 = pd.DataFrame(columns=cols)
res_2016['day'] = ['Mon','Tue','Wed','Thu','Fri']

res_2016['avg_return'] = [avg_mon_2016, avg_tue_2016, avg_wed_2016, avg_thu_2016, avg_fri_2016]

res_2016['stdev_return'] = [stdev_mon_2016, stdev_tue_2016, stdev_wed_2016, stdev_thu_2016, stdev_fri_2016]

res_2016['num_neg'] = [num_mon_2016_neg,
                       num_tue_2016_neg,
                       num_wed_2016_neg,
                       num_thu_2016_neg,
                       num_fri_2016_neg]

res_2016['avg_neg'] = [avg_mon_2016_neg,
                       avg_tue_2016_neg,
                       avg_wed_2016_neg,
                       avg_thu_2016_neg,
                       avg_fri_2016_neg]

res_2016['stdev_neg'] = [stdev_mon_2016_neg,
                       stdev_tue_2016_neg,
                       stdev_wed_2016_neg,
                       stdev_thu_2016_neg,
                       stdev_fri_2016_neg]

res_2016['num_pos'] = [num_mon_2016_pos,
                       num_tue_2016_pos,
                       num_wed_2016_pos,
                       num_thu_2016_pos,
                       num_fri_2016_pos]

res_2016['avg_pos'] = [avg_mon_2016_pos,
                       avg_tue_2016_pos,
                       avg_wed_2016_pos,
                       avg_thu_2016_pos,
                       avg_fri_2016_pos]

res_2016['stdev_pos'] = [stdev_mon_2016_pos,
                       stdev_tue_2016_pos,
                       stdev_wed_2016_pos,
                       stdev_thu_2016_pos,
                       stdev_fri_2016_pos]

# %%
res_2016.head()
# Out:
#    day  avg_return  stdev_return  num_neg   avg_neg  stdev_neg  num_pos  \
# 0  Mon    0.000418      0.007520       21 -0.005302   0.005588       24
# 1  Tue    0.000978      0.008423       20 -0.007064   0.005107       32
# 2  Wed    0.000588      0.007655       24 -0.005489   0.005865       28
# 3  Thu    0.000369      0.006881       23 -0.004831   0.005652       28
# 4  Fri   -0.000288      0.010496       26 -0.006964   0.009025       24
#
#     avg_pos  stdev_pos
# 0  0.005441   0.005224
# 1  0.006004   0.005739
# 2  0.005798   0.004517
# 3  0.004641   0.004438
# 4  0.006932   0.006796

# %%
# create a dataframe with all the results per year
cols = ['day','avg_return','stdev_return','num_neg','avg_neg','stdev_neg','num_pos','avg_pos','stdev_pos']

# 2017
res_2017 = pd.DataFrame(columns=cols)
res_2017['day'] = ['Mon','Tue','Wed','Thu','Fri']

res_2017['avg_return'] = [avg_mon_2017, avg_tue_2017, avg_wed_2017, avg_thu_2017, avg_fri_2017]

res_2017['stdev_return'] = [stdev_mon_2017, stdev_tue_2017, stdev_wed_2017, stdev_thu_2017, stdev_fri_2017]

res_2017['num_neg'] = [num_mon_2017_neg,
                       num_tue_2017_neg,
                       num_wed_2017_neg,
                       num_thu_2017_neg,
                       num_fri_2017_neg]

res_2017['avg_neg'] = [avg_mon_2017_neg,
                       avg_tue_2017_neg,
                       avg_wed_2017_neg,
                       avg_thu_2017_neg,
                       avg_fri_2017_neg]

res_2017['stdev_neg'] = [stdev_mon_2017_neg,
                       stdev_tue_2017_neg,
                       stdev_wed_2017_neg,
                       stdev_thu_2017_neg,
                       stdev_fri_2017_neg]

res_2017['num_pos'] = [num_mon_2017_pos,
                       num_tue_2017_pos,
                       num_wed_2017_pos,
                       num_thu_2017_pos,
                       num_fri_2017_pos]

res_2017['avg_pos'] = [avg_mon_2017_pos,
                       avg_tue_2017_pos,
                       avg_wed_2017_pos,
                       avg_thu_2017_pos,
                       avg_fri_2017_pos]

res_2017['stdev_pos'] = [stdev_mon_2017_pos,
                       stdev_tue_2017_pos,
                       stdev_wed_2017_pos,
                       stdev_thu_2017_pos,
                       stdev_fri_2017_pos]

# %%
res_2017.head()
# Out:
#    day  avg_return  stdev_return  num_neg   avg_neg  stdev_neg  num_pos  \
# 0  Mon    0.001324      0.003906       20 -0.001792   0.001591       26
# 1  Tue    0.000397      0.004459       23 -0.003195   0.003066       27
# 2  Wed    0.001064      0.004502       19 -0.002596   0.004093       33
# 3  Thu   -0.000240      0.005001       25 -0.003808   0.004216       26
# 4  Fri    0.001370      0.003014       20 -0.001575   0.000975       31
#
#     avg_pos  stdev_pos
# 0  0.003721   0.003433
# 1  0.003472   0.003006
# 2  0.003170   0.003218
# 3  0.003192   0.002824
# 4  0.003270   0.002242

# %%
# create a dataframe with all the results per year
cols = ['day','avg_return','stdev_return','num_neg','avg_neg','stdev_neg','num_pos','avg_pos','stdev_pos']

# 2018
res_2018 = pd.DataFrame(columns=cols)
res_2018['day'] = ['Mon','Tue','Wed','Thu','Fri']

res_2018['avg_return'] = [avg_mon_2018, avg_tue_2018, avg_wed_2018, avg_thu_2018, avg_fri_2018]

res_2018['stdev_return'] = [stdev_mon_2018, stdev_tue_2018, stdev_wed_2018, stdev_thu_2018, stdev_fri_2018]

res_2018['num_neg'] = [num_mon_2018_neg,
                       num_tue_2018_neg,
                       num_wed_2018_neg,
                       num_thu_2018_neg,
                       num_fri_2018_neg]

res_2018['avg_neg'] = [avg_mon_2018_neg,
                       avg_tue_2018_neg,
                       avg_wed_2018_neg,
                       avg_thu_2018_neg,
                       avg_fri_2018_neg]

res_2018['stdev_neg'] = [stdev_mon_2018_neg,
                       stdev_tue_2018_neg,
                       stdev_wed_2018_neg,
                       stdev_thu_2018_neg,
                       stdev_fri_2018_neg]

res_2018['num_pos'] = [num_mon_2018_pos,
                       num_tue_2018_pos,
                       num_wed_2018_pos,
                       num_thu_2018_pos,
                       num_fri_2018_pos]

res_2018['avg_pos'] = [avg_mon_2018_pos,
                       avg_tue_2018_pos,
                       avg_wed_2018_pos,
                       avg_thu_2018_pos,
                       avg_fri_2018_pos]

res_2018['stdev_pos'] = [stdev_mon_2018_pos,
                       stdev_tue_2018_pos,
                       stdev_wed_2018_pos,
                       stdev_thu_2018_pos,
                       stdev_fri_2018_pos]

# %%
res_2018.head()
# Out:
#    day  avg_return  stdev_return  num_neg   avg_neg  stdev_neg  num_pos  \
# 0  Mon   -0.000994      0.012154       21 -0.010897   0.010838       26
# 1  Tue    0.000054      0.009436       21 -0.007814   0.008057       29
# 2  Wed    0.000910      0.012009       24 -0.006912   0.008498       26
# 3  Thu   -0.000193      0.010324       27 -0.007030   0.009403       24
# 4  Fri   -0.001020      0.010190       23 -0.009283   0.008497       28
#
#     avg_pos  stdev_pos
# 0  0.006966   0.005951
# 1  0.005753   0.005704
# 2  0.008130   0.010161
# 3  0.007499   0.003894
# 4  0.005768   0.005245

# %%
# create a dataframe with all the results per year
cols = ['day','avg_return','stdev_return','num_neg','avg_neg','stdev_neg','num_pos','avg_pos','stdev_pos']

# 2019
res_2019 = pd.DataFrame(columns=cols)
res_2019['day'] = ['Mon','Tue','Wed','Thu','Fri']

res_2019['avg_return'] = [avg_mon_2019, avg_tue_2019, avg_wed_2019, avg_thu_2019, avg_fri_2019]

res_2019['stdev_return'] = [stdev_mon_2019, stdev_tue_2019, stdev_wed_2019, stdev_thu_2019, stdev_fri_2019]

res_2019['num_neg'] = [num_mon_2019_neg,
                       num_tue_2019_neg,
                       num_wed_2019_neg,
                       num_thu_2019_neg,
                       num_fri_2019_neg]

res_2019['avg_neg'] = [avg_mon_2019_neg,
                       avg_tue_2019_neg,
                       avg_wed_2019_neg,
                       avg_thu_2019_neg,
                       avg_fri_2019_neg]

res_2019['stdev_neg'] = [stdev_mon_2019_neg,
                       stdev_tue_2019_neg,
                       stdev_wed_2019_neg,
                       stdev_thu_2019_neg,
                       stdev_fri_2019_neg]

res_2019['num_pos'] = [num_mon_2019_pos,
                       num_tue_2019_pos,
                       num_wed_2019_pos,
                       num_thu_2019_pos,
                       num_fri_2019_pos]

res_2019['avg_pos'] = [avg_mon_2019_pos,
                       avg_tue_2019_pos,
                       avg_wed_2019_pos,
                       avg_thu_2019_pos,
                       avg_fri_2019_pos]

res_2019['stdev_pos'] = [stdev_mon_2019_pos,
                       stdev_tue_2019_pos,
                       stdev_wed_2019_pos,
                       stdev_thu_2019_pos,
                       stdev_fri_2019_pos]

# %%
res_2019.head()
# Out:
#    day  avg_return  stdev_return  num_neg   avg_neg  stdev_neg  num_pos  \
# 0  Mon   -0.000221      0.008246       22 -0.006263   0.007787       26
# 1  Tue    0.000756      0.007887       24 -0.005452   0.005196       28
# 2  Wed    0.000636      0.007330       19 -0.006001   0.007296       32
# 3  Thu    0.001728      0.007066       19 -0.004711   0.005972       31
# 4  Fri    0.002280      0.008929       18 -0.006192   0.007064       33
#
#     avg_pos  stdev_pos
# 0  0.004892   0.004195
# 1  0.006077   0.005556
# 2  0.004576   0.003566
# 3  0.005675   0.004217
# 4  0.006900   0.005974

# %%
sum_tbls = [res_2016,res_2017,res_2018,res_2019]

# %%
res_2016['year'] = 2016
res_2017['year'] = 2017
res_2018['year'] = 2018
res_2019['year'] = 2019

spy_summary_df = pd.concat(sum_tbls, axis=0).reset_index(drop=True)

# %%
spy_summary_df.head(10)
# Out:
#    day  avg_return  stdev_return  num_neg   avg_neg  stdev_neg  num_pos  \
# 0  Mon    0.000418      0.007520       21 -0.005302   0.005588       24
# 1  Tue    0.000978      0.008423       20 -0.007064   0.005107       32
# 2  Wed    0.000588      0.007655       24 -0.005489   0.005865       28
# 3  Thu    0.000369      0.006881       23 -0.004831   0.005652       28
# 4  Fri   -0.000288      0.010496       26 -0.006964   0.009025       24
# 5  Mon    0.001324      0.003906       20 -0.001792   0.001591       26
# 6  Tue    0.000397      0.004459       23 -0.003195   0.003066       27
# 7  Wed    0.001064      0.004502       19 -0.002596   0.004093       33
# 8  Thu   -0.000240      0.005001       25 -0.003808   0.004216       26
# 9  Fri    0.001370      0.003014       20 -0.001575   0.000975       31
#
#     avg_pos  stdev_pos  year
# 0  0.005441   0.005224  2016
# 1  0.006004   0.005739  2016
# 2  0.005798   0.004517  2016
# 3  0.004641   0.004438  2016
# 4  0.006932   0.006796  2016
# 5  0.003721   0.003433  2017
# 6  0.003472   0.003006  2017
# 7  0.003170   0.003218  2017
# 8  0.003192   0.002824  2017
# 9  0.003270   0.002242  2017

# %%
# average returns by year and by day
spy_summary_df.groupby(['year','day'])['avg_return'].mean()
# Out:
# year  day
# 2016  Fri   -0.000288
#       Mon    0.000418
#       Thu    0.000369
#       Tue    0.000978
#       Wed    0.000588
# 2017  Fri    0.001370
#       Mon    0.001324
#       Thu   -0.000240
#       Tue    0.000397
#       Wed    0.001064
# 2018  Fri   -0.001020
#       Mon   -0.000994
#       Thu   -0.000193
#       Tue    0.000054
#       Wed    0.000910
# 2019  Fri    0.002280
#       Mon   -0.000221
#       Thu    0.001728
#       Tue    0.000756
#       Wed    0.000636
# Name: avg_return, dtype: float64

# %% [markdown]
# 2016
# - Best Day: Tuesday
# - Worst Day: Friday
#
# 2017
# - Best Day: Monday and Friday
# - Worst Day: Thursday
#
# 2018
# - Best Day: Wednesday
# - Worst Day: Friday
#
# 2019
# - Best Day: Thursday
# - Worst Day: Monday

# %% [markdown]
# #### 3.2 are these days the same for your stock as they are for S&P-500?
# - No, these results are not the same. No day stood at as the best year over year. However, the beggining and end of the week seem to be worst days for trading on the S&P 500 (Monday, Thursday, and Friday)

# %% [markdown]
# #### 4.1 You listen to the oracle and follow its advice. How much much money will you have on the last trading day of 2019?

# %%
dis_diff_l, dis_pct_diff_l = daily_ret_pct_diff(ac_l)
spy_diff_l, spy_pct_diff_l = daily_ret_pct_diff(spy_ac_l)
# Out:
# current iteration: 0
# diff: 0
# pct diff: 0
# next iteration: 1
#
#
# current iteration: 1
# diff: -1.9699999999999989
# pct diff: -0.020275833676410036
# next iteration: 2
#
#
# current iteration: 2
# diff: -0.5099999999999909
# pct diff: -0.005386565272496735
# next iteration: 3
#
#
# current iteration: 3
# diff: -0.8100000000000023
# pct diff: -0.008628954937679794
# next iteration: 4
#
#
# current iteration: 4
# diff: -0.23000000000000398
# pct diff: -0.002456215292610038
# next iteration: 5
#
#
# current iteration: 5
# diff: 0.6299999999999955
# pct diff: 0.006682932003818771
# next iteration: 6
#
#
# current iteration: 6
# diff: 1.4500000000000028
# pct diff: 0.015148349352277506
# next iteration: 7
#
#
# current iteration: 7
# diff: -2.8100000000000023
# pct diff: -0.030244322462598238
# next iteration: 8
#
#
# current iteration: 8
# diff: 0.5900000000000034
# pct diff: 0.006310160427807523
# next iteration: 9
#
#
# current iteration: 9
# diff: -4.909999999999997
# pct diff: -0.05542386273845802
# next iteration: 10
#
#
# current iteration: 10
# diff: 0.06999999999999318
# pct diff: 0.0007895330475974869
# next iteration: 11
#
#
# current iteration: 11
# diff: -1.3499999999999943
# pct diff: -0.015462146374985618
# next iteration: 12
#
#
# current iteration: 12
# diff: 1.3900000000000006
# pct diff: 0.015670800450958294
# next iteration: 13
#
#
# current iteration: 13
# diff: 2.719999999999999
# pct diff: 0.02975278932399911
# next iteration: 14
#
#
# current iteration: 14
# diff: -1.519999999999996
# pct diff: -0.016907675194660687
# next iteration: 15
#
#
# current iteration: 15
# diff: 0.9299999999999926
# pct diff: 0.01023890784982927
# next iteration: 16
#
#
# current iteration: 16
# diff: -1.8400000000000034
# pct diff: -0.02067648050342739
# next iteration: 17
#
#
# current iteration: 17
# diff: -0.75
# pct diff: -0.008499546690843155
# next iteration: 18
#
#
# current iteration: 18
# diff: 2.160000000000011
# pct diff: 0.02389380530973463
# next iteration: 19
#
#
# current iteration: 19
# diff: -0.6300000000000097
# pct diff: -0.007017934722067614
# next iteration: 20
#
#
# current iteration: 20
# diff: -1.9200000000000017
# pct diff: -0.021855435401252156
# next iteration: 21
#
#
# current iteration: 21
# diff: 1.9100000000000108
# pct diff: 0.021278966131907426
# next iteration: 22
#
#
# current iteration: 22
# diff: 0.269999999999996
# pct diff: 0.002999000333222215
# next iteration: 23
#
#
# current iteration: 23
# diff: -1.4399999999999977
# pct diff: -0.01625465628174735
# next iteration: 24
#
#
# current iteration: 24
# diff: -1.6800000000000068
# pct diff: -0.01933034173282714
# next iteration: 25
#
#
# current iteration: 25
# diff: 0.18999999999999773
# pct diff: 0.0021814006888633496
# next iteration: 26
#
#
# current iteration: 26
# diff: -3.280000000000001
# pct diff: -0.03913147220233836
# next iteration: 27
#
#
# current iteration: 27
# diff: 1.3800000000000097
# pct diff: 0.016197183098591663
# next iteration: 28
#
#
# current iteration: 28
# diff: 0.789999999999992
# pct diff: 0.009187114780788371
# next iteration: 29
#
#
# current iteration: 29
# diff: 1.6700000000000017
# pct diff: 0.019050878393794227
# next iteration: 30
#
#
# current iteration: 30
# diff: 2.4399999999999977
# pct diff: 0.027081021087680332
# next iteration: 31
#
#
# current iteration: 31
# diff: -0.30999999999998806
# pct diff: -0.003452500278427309
# next iteration: 32
#
#
# current iteration: 32
# diff: -0.15000000000000568
# pct diff: -0.0016733601070951102
# next iteration: 33
#
#
# current iteration: 33
# diff: 1.2800000000000011
# pct diff: 0.014078310602727686
# next iteration: 34
#
#
# current iteration: 34
# diff: -0.9300000000000068
# pct diff: -0.01033448160906775
# next iteration: 35
#
#
# current iteration: 35
# diff: 0.04000000000000625
# pct diff: 0.00044429634566262635
# next iteration: 36
#
#
# current iteration: 36
# diff: 0.20999999999999375
# pct diff: 0.002327127659574399
# next iteration: 37
#
#
# current iteration: 37
# diff: -0.3199999999999932
# pct diff: -0.0035587188612098883
# next iteration: 38
#
#
# current iteration: 38
# diff: 0.20000000000000284
# pct diff: 0.0022192632046160988
# next iteration: 39
#
#
# current iteration: 39
# diff: 2.009999999999991
# pct diff: 0.02181699772061208
# next iteration: 40
#
#
# current iteration: 40
# diff: -0.6199999999999903
# pct diff: -0.006775215823407172
# next iteration: 41
#
#
# current iteration: 41
# diff: 1.7199999999999989
# pct diff: 0.01844899710393649
# next iteration: 42
#
#
# current iteration: 42
# diff: -0.3200000000000074
# pct diff: -0.0034441933053493425
# next iteration: 43
#
#
# current iteration: 43
# diff: 0.8599999999999994
# pct diff: 0.009171376772955098
# next iteration: 44
#
#
# current iteration: 44
# diff: -1.4799999999999898
# pct diff: -0.016036406978004007
# next iteration: 45
#
#
# current iteration: 45
# diff: -0.15000000000000568
# pct diff: -0.0016279574560452105
# next iteration: 46
#
#
# current iteration: 46
# diff: -0.5900000000000034
# pct diff: -0.006444565811032261
# next iteration: 47
#
#
# current iteration: 47
# diff: 0.8500000000000085
# pct diff: 0.00919913419913429
# next iteration: 48
#
#
# current iteration: 48
# diff: 0.8199999999999932
# pct diff: 0.008796395623256738
# next iteration: 49
#
#
# current iteration: 49
# diff: -0.539999999999992
# pct diff: -0.005826499784203625
# next iteration: 50
#
#
# current iteration: 50
# diff: 0.18999999999999773
# pct diff: 0.0020458705717669614
# next iteration: 51
#
#
# current iteration: 51
# diff: 1.0999999999999943
# pct diff: 0.011705863573480838
# next iteration: 52
#
#
# current iteration: 52
# diff: -0.37999999999999545
# pct diff: -0.0040602628485948864
# next iteration: 53
#
#
# current iteration: 53
# diff: -0.7000000000000028
# pct diff: -0.007535795026375313
# next iteration: 54
#
#
# current iteration: 54
# diff: -0.8299999999999983
# pct diff: -0.009015859222246342
# next iteration: 55
#
#
# current iteration: 55
# diff: -0.710000000000008
# pct diff: -0.0077723043240285495
# next iteration: 56
#
#
# current iteration: 56
# diff: 0.37000000000000455
# pct diff: 0.004034016572176238
# next iteration: 57
#
#
# current iteration: 57
# diff: 0.8200000000000074
# pct diff: 0.008861033066782011
# next iteration: 58
#
#
# current iteration: 58
# diff: 0.06999999999999318
# pct diff: 0.000755857898714968
# next iteration: 59
#
#
# current iteration: 59
# diff: 0.7099999999999937
# pct diff: 0.007608229747106663
# next iteration: 60
#
#
# current iteration: 60
# diff: 0.37000000000000455
# pct diff: 0.0039491941509233065
# next iteration: 61
#
#
# current iteration: 61
# diff: -0.21999999999999886
# pct diff: -0.0023536963731678492
# next iteration: 62
#
#
# current iteration: 62
# diff: -0.37000000000000455
# pct diff: -0.003974221267454399
# next iteration: 63
#
#
# current iteration: 63
# diff: -1.5899999999999892
# pct diff: -0.017375150256802415
# next iteration: 64
#
#
# current iteration: 64
# diff: 0.45999999999999375
# pct diff: 0.005001630966619482
# next iteration: 65
#
#
# current iteration: 65
# diff: -1.25
# pct diff: -0.013778659611992946
# next iteration: 66
#
#
# current iteration: 66
# diff: 0.25
# pct diff: 0.0027481587336484555
# next iteration: 67
#
#
# current iteration: 67
# diff: -0.14000000000000057
# pct diff: -0.001541340966640984
# next iteration: 68
#
#
# current iteration: 68
# diff: 1.0100000000000051
# pct diff: 0.010997386759581937
# next iteration: 69
#
#
# current iteration: 69
# diff: 2.009999999999991
# pct diff: 0.021417155034629633
# next iteration: 70
#
#
# current iteration: 70
# diff: -0.7999999999999972
# pct diff: -0.00859752821063941
# next iteration: 71
#
#
# current iteration: 71
# diff: -0.03999999999999204
# pct diff: -0.0004300612837328464
# next iteration: 72
#
#
# current iteration: 72
# diff: 2.7299999999999898
# pct diff: 0.028514727386672132
# next iteration: 73
#
#
# current iteration: 73
# diff: 1.1000000000000085
# pct diff: 0.011358942585708473
# next iteration: 74
#
#
# current iteration: 74
# diff: 0.5900000000000034
# pct diff: 0.00605562968284926
# next iteration: 75
#
#
# current iteration: 75
# diff: -0.3400000000000034
# pct diff: -0.003501905448552924
# next iteration: 76
#
#
# current iteration: 76
# diff: 0.8100000000000023
# pct diff: 0.008273748723186949
# next iteration: 77
#
#
# current iteration: 77
# diff: 0.7599999999999909
# pct diff: 0.007703223190756041
# next iteration: 78
#
#
# current iteration: 78
# diff: 0.29999999999999716
# pct diff: 0.00303152789005656
# next iteration: 79
#
#
# current iteration: 79
# diff: 0.37000000000000455
# pct diff: 0.003724957213329352
# next iteration: 80
#
#
# current iteration: 80
# diff: -1.1799999999999926
# pct diff: -0.012022414671421218
# next iteration: 81
#
#
# current iteration: 81
# diff: -0.730000000000004
# pct diff: -0.007493327858755943
# next iteration: 82
#
#
# current iteration: 82
# diff: 1.039999999999992
# pct diff: 0.010562665041641196
# next iteration: 83
#
#
# current iteration: 83
# diff: -0.5499999999999972
# pct diff: -0.005617403738126823
# next iteration: 84
#
#
# current iteration: 84
# diff: -0.09999999999999432
# pct diff: -0.0010223903486350507
# next iteration: 85
#
#
# current iteration: 85
# diff: 1.1899999999999977
# pct diff: 0.012020202020201997
# next iteration: 86
#
#
# current iteration: 86
# diff: 0.5699999999999932
# pct diff: 0.005724615848146964
# next iteration: 87
#
#
# current iteration: 87
# diff: -0.18999999999999773
# pct diff: -0.0019118534916481961
# next iteration: 88
#
#
# current iteration: 88
# diff: 1.1899999999999977
# pct diff: 0.011832554439693724
# next iteration: 89
#
#
# current iteration: 89
# diff: -4.069999999999993
# pct diff: -0.04217616580310874
# next iteration: 90
#
#
# current iteration: 90
# diff: -0.5400000000000063
# pct diff: -0.005627344726969636
# next iteration: 91
#
#
# current iteration: 91
# diff: -1.1299999999999955
# pct diff: -0.011916060318464573
# next iteration: 92
#
#
# current iteration: 92
# diff: -0.14999999999999147
# pct diff: -0.0015842839036754484
# next iteration: 93
#
#
# current iteration: 93
# diff: -0.39000000000000057
# pct diff: -0.004136175628380534
# next iteration: 94
#
#
# current iteration: 94
# diff: -0.8900000000000006
# pct diff: -0.009528907922912212
# next iteration: 95
#
#
# current iteration: 95
# diff: -0.5600000000000023
# pct diff: -0.006031882809134018
# next iteration: 96
#
#
# current iteration: 96
# diff: 1.2999999999999972
# pct diff: 0.013809220310176304
# next iteration: 97
#
#
# current iteration: 97
# diff: -0.5700000000000074
# pct diff: -0.006091696056428422
# next iteration: 98
#
#
# current iteration: 98
# diff: 0.3100000000000023
# pct diff: 0.0033020877716233733
# next iteration: 99
#
#
# current iteration: 99
# diff: 0.3299999999999983
# pct diff: 0.003502812864876322
# next iteration: 100
#
#
# current iteration: 100
# diff: -0.03999999999999204
# pct diff: -0.0004247637251777853
# next iteration: 101
#
#
# current iteration: 101
# diff: 0.45000000000000284
# pct diff: 0.004755865567533321
# next iteration: 102
#
#
# current iteration: 102
# diff: -1.0100000000000051
# pct diff: -0.010789445572054322
# next iteration: 103
#
#
# current iteration: 103
# diff: -0.6599999999999966
# pct diff: -0.007100591715976295
# next iteration: 104
#
#
# current iteration: 104
# diff: 0.18999999999999773
# pct diff: 0.002039939875456278
# next iteration: 105
#
#
# current iteration: 105
# diff: 0.030000000000001137
# pct diff: 0.0003219920575292598
# next iteration: 106
#
#
# current iteration: 106
# diff: 0.01999999999999602
# pct diff: 0.00021461530207099499
# next iteration: 107
#
#
# current iteration: 107
# diff: -0.3999999999999915
# pct diff: -0.004310809354456207
# next iteration: 108
#
#
# current iteration: 108
# diff: -0.29000000000000625
# pct diff: -0.0031351351351352028
# next iteration: 109
#
#
# current iteration: 109
# diff: -0.18999999999999773
# pct diff: -0.0020582818762864014
# next iteration: 110
#
#
# current iteration: 110
# diff: -0.480000000000004
# pct diff: -0.005227049983665512
# next iteration: 111
#
#
# current iteration: 111
# diff: 0.21999999999999886
# pct diff: 0.0023900054318305147
# next iteration: 112
#
#
# current iteration: 112
# diff: 0.7800000000000011
# pct diff: 0.008402456102553066
# next iteration: 113
#
#
# current iteration: 113
# diff: -0.12000000000000455
# pct diff: -0.001294358753101117
# next iteration: 114
#
#
# current iteration: 114
# diff: 0.10999999999999943
# pct diff: 0.001185089420383532
# next iteration: 115
#
#
# current iteration: 115
# diff: 0.5800000000000125
# pct diff: 0.006209850107066515
# next iteration: 116
#
#
# current iteration: 116
# diff: 0.539999999999992
# pct diff: 0.005748350010645008
# next iteration: 117
#
#
# current iteration: 117
# diff: -0.7099999999999937
# pct diff: -0.007615574385927209
# next iteration: 118
#
#
# current iteration: 118
# diff: -0.030000000000001137
# pct diff: -0.0003218884120171796
# next iteration: 119
#
#
# current iteration: 119
# diff: 0.21999999999999886
# pct diff: 0.0023549561121815337
# next iteration: 120
#
#
# current iteration: 120
# diff: -3.1099999999999994
# pct diff: -0.03443693943084929
# next iteration: 121
#
#
# current iteration: 121
# diff: -1.269999999999996
# pct diff: -0.014263252470799594
# next iteration: 122
#
#
# current iteration: 122
# diff: 1.5799999999999983
# pct diff: 0.017435444714191107
# next iteration: 123
#
#
# current iteration: 123
# diff: 0.8799999999999955
# pct diff: 0.009617486338797764
# next iteration: 124
#
#
# current iteration: 124
# diff: 0.7900000000000063
# pct diff: 0.008559973995015778
# next iteration: 125
#
#
# current iteration: 125
# diff: 0.19999999999998863
# pct diff: 0.00216239593469552
# next iteration: 126
#
#
# current iteration: 126
# diff: -0.3499999999999943
# pct diff: -0.0037985673974386186
# next iteration: 127
#
#
# current iteration: 127
# diff: 0.7399999999999949
# pct diff: 0.007967269595176516
# next iteration: 128
#
#
# current iteration: 128
# diff: 0.6400000000000006
# pct diff: 0.006843455945252359
# next iteration: 129
#
#
# current iteration: 129
# diff: 1.1500000000000057
# pct diff: 0.01214745959649314
# next iteration: 130
#
#
# current iteration: 130
# diff: 0.3400000000000034
# pct diff: 0.003578570676770902
# next iteration: 131
#
#
# current iteration: 131
# diff: 0.20999999999999375
# pct diff: 0.0022054190296155614
# next iteration: 132
#
#
# current iteration: 132
# diff: -0.29999999999999716
# pct diff: -0.0031605562579013606
# next iteration: 133
#
#
# current iteration: 133
# diff: 0.0799999999999983
# pct diff: 0.0008421052631578768
# next iteration: 134
#
#
# current iteration: 134
# diff: -0.1599999999999966
# pct diff: -0.001687051876845177
# next iteration: 135
#
#
# current iteration: 135
# diff: 0.3299999999999983
# pct diff: 0.0034674792476620604
# next iteration: 136
#
#
# current iteration: 136
# diff: -0.6400000000000006
# pct diff: -0.006770337459007728
# next iteration: 137
#
#
# current iteration: 137
# diff: -1.1899999999999977
# pct diff: -0.012749089350760636
# next iteration: 138
#
#
# current iteration: 138
# diff: -0.20000000000000284
# pct diff: -0.002147305132059296
# next iteration: 139
#
#
# current iteration: 139
# diff: -0.29000000000000625
# pct diff: -0.003123317178244548
# next iteration: 140
#
#
# current iteration: 140
# diff: -0.29999999999999716
# pct diff: -0.0032414910858994833
# next iteration: 141
#
#
# current iteration: 141
# diff: -0.6700000000000017
# pct diff: -0.007292120156726183
# next iteration: 142
#
#
# current iteration: 142
# diff: -0.3399999999999892
# pct diff: -0.0037142232903647496
# next iteration: 143
#
#
# current iteration: 143
# diff: -0.4000000000000057
# pct diff: -0.004388852315119658
# next iteration: 144
#
#
# current iteration: 144
# diff: 0.04000000000000625
# pct diff: 0.00043869269576668403
# next iteration: 145
#
#
# current iteration: 145
# diff: -0.39000000000000057
# pct diff: -0.004295627271725967
# next iteration: 146
#
#
# current iteration: 146
# diff: -0.5
# pct diff: -0.005537711817477018
# next iteration: 147
#
#
# current iteration: 147
# diff: 1.019999999999996
# pct diff: 0.011170737049611171
# next iteration: 148
#
#
# current iteration: 148
# diff: -0.8799999999999955
# pct diff: -0.00973128386597363
# next iteration: 149
#
#
# current iteration: 149
# diff: 0.6399999999999864
# pct diff: 0.0070275612166463865
# next iteration: 150
#
#
# current iteration: 150
# diff: -0.0799999999999983
# pct diff: -0.0008792174964281603
# next iteration: 151
#
#
# current iteration: 151
# diff: 0.8800000000000097
# pct diff: 0.009578752585174807
# next iteration: 152
#
#
# current iteration: 152
# diff: 1.1299999999999955
# pct diff: 0.012150537634408553
# next iteration: 153
#
#
# current iteration: 153
# diff: -0.09000000000000341
# pct diff: -0.0009686793671295169
# next iteration: 154
#
#
# current iteration: 154
# diff: -0.8799999999999955
# pct diff: -0.009562099315440567
# next iteration: 155
#
#
# current iteration: 155
# diff: 0.23999999999999488
# pct diff: 0.0026010621003575906
# next iteration: 156
#
#
# current iteration: 156
# diff: -0.20999999999999375
# pct diff: -0.002281121008038168
# next iteration: 157
#
#
# current iteration: 157
# diff: 0.0
# pct diff: 0.0
# next iteration: 158
#
#
# current iteration: 158
# diff: -0.21000000000000796
# pct diff: -0.002286336418073032
# next iteration: 159
#
#
# current iteration: 159
# diff: -0.25
# pct diff: -0.0027292576419213977
# next iteration: 160
#
#
# current iteration: 160
# diff: -0.5
# pct diff: -0.005488474204171241
# next iteration: 161
#
#
# current iteration: 161
# diff: 0.10000000000000853
# pct diff: 0.0010964912280702688
# next iteration: 162
#
#
# current iteration: 162
# diff: -0.14000000000000057
# pct diff: -0.0015374478365912647
# next iteration: 163
#
#
# current iteration: 163
# diff: -0.2600000000000051
# pct diff: -0.002863436123348074
# next iteration: 164
#
#
# current iteration: 164
# diff: -0.3199999999999932
# pct diff: -0.00353669319186553
# next iteration: 165
#
#
# current iteration: 165
# diff: -0.3299999999999983
# pct diff: -0.003660565723793658
# next iteration: 166
#
#
# current iteration: 166
# diff: 0.0
# pct diff: 0.0
# next iteration: 167
#
#
# current iteration: 167
# diff: -0.38000000000000966
# pct diff: -0.004233039991088445
# next iteration: 168
#
#
# current iteration: 168
# diff: -0.20000000000000284
# pct diff: -0.0022328904767221487
# next iteration: 169
#
#
# current iteration: 169
# diff: 0.1600000000000108
# pct diff: 0.0017831271592556647
# next iteration: 170
#
#
# current iteration: 170
# diff: -0.5900000000000034
# pct diff: -0.006618801884675829
# next iteration: 171
#
#
# current iteration: 171
# diff: -0.09000000000000341
# pct diff: -0.0010106681639528738
# next iteration: 172
#
#
# current iteration: 172
# diff: 0.35999999999999943
# pct diff: 0.004026395257801135
# next iteration: 173
#
#
# current iteration: 173
# diff: -1.5799999999999983
# pct diff: -0.01798929750654672
# next iteration: 174
#
#
# current iteration: 174
# diff: 1.1599999999999966
# pct diff: 0.013035172491291118
# next iteration: 175
#
#
# current iteration: 175
# diff: -0.8999999999999915
# pct diff: -0.010216823703030894
# next iteration: 176
#
#
# current iteration: 176
# diff: -0.4200000000000017
# pct diff: -0.00479069236911146
# next iteration: 177
#
#
# current iteration: 177
# diff: 0.23000000000000398
# pct diff: 0.002616609783845324
# next iteration: 178
#
#
# current iteration: 178
# diff: 0.05999999999998806
# pct diff: 0.0006821282401090049
# next iteration: 179
#
#
# current iteration: 179
# diff: 0.07000000000000739
# pct diff: 0.0007951834601841121
# next iteration: 180
#
#
# current iteration: 180
# diff: 0.29999999999999716
# pct diff: 0.003396354579418059
# next iteration: 181
#
#
# current iteration: 181
# diff: -0.5300000000000011
# pct diff: -0.006036446469248305
# next iteration: 182
#
#
# current iteration: 182
# diff: 0.9699999999999989
# pct diff: 0.010927115016334334
# next iteration: 183
#
#
# current iteration: 183
# diff: -0.14000000000000057
# pct diff: -0.001579600586708796
# next iteration: 184
#
#
# current iteration: 184
# diff: -1.2399999999999949
# pct diff: -0.014189266506465213
# next iteration: 185
#
#
# current iteration: 185
# diff: -0.23000000000000398
# pct diff: -0.0026388251491510323
# next iteration: 186
#
#
# current iteration: 186
# diff: 0.46000000000000796
# pct diff: 0.0052499429354029665
# next iteration: 187
#
#
# current iteration: 187
# diff: -0.38000000000000966
# pct diff: -0.004355800091701166
# next iteration: 188
#
#
# current iteration: 188
# diff: 1.0
# pct diff: 0.011332728921124207
# next iteration: 189
#
#
# current iteration: 189
# diff: -0.3499999999999943
# pct diff: -0.003982250540448223
# next iteration: 190
#
#
# current iteration: 190
# diff: 0.09999999999999432
# pct diff: 0.0011364927832707616
# next iteration: 191
#
#
# current iteration: 191
# diff: -0.14000000000000057
# pct diff: -0.0015936254980079747
# next iteration: 192
#
#
# current iteration: 192
# diff: 0.37000000000000455
# pct diff: 0.004194060303786041
# next iteration: 193
#
#
# current iteration: 193
# diff: -0.3299999999999983
# pct diff: -0.003754693366708366
# next iteration: 194
#
#
# current iteration: 194
# diff: 0.0
# pct diff: 0.0
# next iteration: 195
#
#
# current iteration: 195
# diff: -0.5999999999999943
# pct diff: -0.006873639592163985
# next iteration: 196
#
#
# current iteration: 196
# diff: -0.4200000000000017
# pct diff: -0.00483481063658342
# next iteration: 197
#
#
# current iteration: 197
# diff: -0.28000000000000114
# pct diff: -0.0032336297493937073
# next iteration: 198
#
#
# current iteration: 198
# diff: 0.1700000000000017
# pct diff: 0.0019594283079760453
# next iteration: 199
#
#
# current iteration: 199
# diff: -0.44000000000001194
# pct diff: -0.0050973123262281275
# next iteration: 200
#
#
# current iteration: 200
# diff: 0.3200000000000074
# pct diff: 0.0036934441366575184
# next iteration: 201
#
#
# current iteration: 201
# diff: 0.7199999999999989
# pct diff: 0.008241758241758228
# next iteration: 202
#
#
# current iteration: 202
# diff: 0.09999999999999432
# pct diff: 0.0011433798307797201
# next iteration: 203
#
#
# current iteration: 203
# diff: 0.9500000000000028
# pct diff: 0.010745390792896764
# next iteration: 204
#
#
# current iteration: 204
# diff: 0.3200000000000074
# pct diff: 0.003606446523160232
# next iteration: 205
#
#
# current iteration: 205
# diff: -0.5900000000000034
# pct diff: -0.006693896074427086
# next iteration: 206
#
#
# current iteration: 206
# diff: 0.7000000000000028
# pct diff: 0.007879333633498456
# next iteration: 207
#
#
# current iteration: 207
# diff: 0.5099999999999909
# pct diff: 0.00570789031897024
# next iteration: 208
#
#
# current iteration: 208
# diff: -0.1599999999999966
# pct diff: -0.001793923085547669
# next iteration: 209
#
#
# current iteration: 209
# diff: -1.1099999999999994
# pct diff: -0.012602179836512255
# next iteration: 210
#
#
# current iteration: 210
# diff: -0.28000000000000114
# pct diff: -0.0031890660592255255
# next iteration: 211
#
#
# current iteration: 211
# diff: -0.45999999999999375
# pct diff: -0.005266773528738193
# next iteration: 212
#
#
# current iteration: 212
# diff: 1.3900000000000006
# pct diff: 0.015665502084976902
# next iteration: 213
#
#
# current iteration: 213
# diff: -0.8800000000000097
# pct diff: -0.01001707455890734
# next iteration: 214
#
#
# current iteration: 214
# diff: 1.8900000000000006
# pct diff: 0.021060842433697356
# next iteration: 215
#
#
# current iteration: 215
# diff: -0.04999999999999716
# pct diff: -0.0005574757498048518
# next iteration: 216
#
#
# current iteration: 216
# diff: 0.25
# pct diff: 0.0027796308650211254
# next iteration: 217
#
#
# current iteration: 217
# diff: 0.29999999999999716
# pct diff: 0.0033244680851063518
# next iteration: 218
#
#
# current iteration: 218
# diff: 2.5799999999999983
# pct diff: 0.027795733678086604
# next iteration: 219
#
#
# current iteration: 219
# diff: 0.23000000000000398
# pct diff: 0.002471789360558882
# next iteration: 220
#
#
# current iteration: 220
# diff: -0.20999999999999375
# pct diff: -0.0022619560534251804
# next iteration: 221
#
#
# current iteration: 221
# diff: 1.3499999999999943
# pct diff: 0.01433273171249596
# next iteration: 222
#
#
# current iteration: 222
# diff: 0.2400000000000091
# pct diff: 0.0025415651805571226
# next iteration: 223
#
#
# current iteration: 223
# diff: -1.0700000000000074
# pct diff: -0.011461011139674458
# next iteration: 224
#
#
# current iteration: 224
# diff: -0.5799999999999983
# pct diff: -0.006251347273119188
# next iteration: 225
#
#
# current iteration: 225
# diff: 0.06999999999999318
# pct diff: 0.0007539041464727322
# next iteration: 226
#
#
# current iteration: 226
# diff: 0.5300000000000011
# pct diff: 0.005675733561790546
# next iteration: 227
#
#
# current iteration: 227
# diff: 0.5300000000000011
# pct diff: 0.005643701416249613
# next iteration: 228
#
#
# current iteration: 228
# diff: 0.14000000000000057
# pct diff: 0.0014885699096225473
# next iteration: 229
#
#
# current iteration: 229
# diff: 0.6700000000000017
# pct diff: 0.007073479729729748
# next iteration: 230
#
#
# current iteration: 230
# diff: -0.5300000000000011
# pct diff: -0.005626924301942894
# next iteration: 231
#
#
# current iteration: 231
# diff: -0.1700000000000017
# pct diff: -0.0018081259306530707
# next iteration: 232
#
#
# current iteration: 232
# diff: -0.4200000000000017
# pct diff: -0.004487179487179506
# next iteration: 233
#
#
# current iteration: 233
# diff: 1.3900000000000006
# pct diff: 0.01463311927571324
# next iteration: 234
#
#
# current iteration: 234
# diff: 0.6700000000000017
# pct diff: 0.007003972402258015
# next iteration: 235
#
#
# current iteration: 235
# diff: 1.2600000000000051
# pct diff: 0.013000412711514704
# next iteration: 236
#
#
# current iteration: 236
# diff: 2.0799999999999983
# pct diff: 0.021010101010100993
# next iteration: 237
#
#
# current iteration: 237
# diff: 1.4200000000000017
# pct diff: 0.014140609440350544
# next iteration: 238
#
#
# current iteration: 238
# diff: -0.769999999999996
# pct diff: -0.007727044656296999
# next iteration: 239
#
#
# current iteration: 239
# diff: -0.20000000000000284
# pct diff: -0.0020110608345902748
# next iteration: 240
#
#
# current iteration: 240
# diff: 0.18999999999999773
# pct diff: 0.0019068647129666572
# next iteration: 241
#
#
# current iteration: 241
# diff: 0.3299999999999983
# pct diff: 0.0033009902970891096
# next iteration: 242
#
#
# current iteration: 242
# diff: -0.45999999999999375
# pct diff: -0.004622650989850203
# next iteration: 243
#
#
# current iteration: 243
# diff: 1.3299999999999983
# pct diff: 0.013189210630702084
# next iteration: 244
#
#
# current iteration: 244
# diff: 0.14999999999999147
# pct diff: 0.0014852955738191057
# next iteration: 245
#
#
# current iteration: 245
# diff: 0.10000000000000853
# pct diff: 0.000989217528934697
# next iteration: 246
#
#
# current iteration: 246
# diff: -0.14000000000000057
# pct diff: -0.0013868251609707833
# next iteration: 247
#
#
# current iteration: 247
# diff: -0.2600000000000051
# pct diff: -0.002582182937729716
# next iteration: 248
#
#
# current iteration: 248
# diff: 0.01999999999999602
# pct diff: 0.0001985900109224111
# next iteration: 249
#
#
# current iteration: 249
# diff: -0.8299999999999983
# pct diff: -0.008309971966359615
# next iteration: 250
#
#
# current iteration: 250
# diff: 0.25
# pct diff: 0.002496754219514631
# next iteration: 251
#
#
# current iteration: 251
# diff: -0.3299999999999983
# pct diff: -0.003306613226452889
# next iteration: 252
#
#
# current iteration: 252
# diff: 1.7800000000000011
# pct diff: 0.017523134475290424
# next iteration: 253
#
#
# current iteration: 253
# diff: 1.3100000000000023
# pct diff: 0.01273204393041114
# next iteration: 254
#
#
# current iteration: 254
# diff: -0.060000000000002274
# pct diff: -0.0005834873091510481
# next iteration: 255
#
#
# current iteration: 255
# diff: 1.5300000000000011
# pct diff: 0.014660789574549646
# next iteration: 256
#
#
# current iteration: 256
# diff: -0.5900000000000034
# pct diff: -0.005685650958851339
# next iteration: 257
#
#
# current iteration: 257
# diff: 0.020000000000010232
# pct diff: 0.00019269679159851846
# next iteration: 258
#
#
# current iteration: 258
# diff: 1.009999999999991
# pct diff: 0.009637404580152584
# next iteration: 259
#
#
# current iteration: 259
# diff: -1.8299999999999983
# pct diff: -0.017772166650480706
# next iteration: 260
#
#
# current iteration: 260
# diff: 0.5100000000000051
# pct diff: 0.004928488596830354
# next iteration: 261
#
#
# current iteration: 261
# diff: -0.09000000000000341
# pct diff: -0.0008704903762453178
# next iteration: 262
#
#
# current iteration: 262
# diff: 0.18999999999999773
# pct diff: 0.0018343309519211985
# next iteration: 263
#
#
# current iteration: 263
# diff: -0.8499999999999943
# pct diff: -0.008274116616372961
# next iteration: 264
#
#
# current iteration: 264
# diff: 0.36999999999999034
# pct diff: 0.0035887487875847757
# next iteration: 265
#
#
# current iteration: 265
# diff: -0.519999999999996
# pct diff: -0.005069214271787834
# next iteration: 266
#
#
# current iteration: 266
# diff: 0.75
# pct diff: 0.007258298654795316
# next iteration: 267
#
#
# current iteration: 267
# diff: 0.12999999999999545
# pct diff: 0.0012565242605837566
# next iteration: 268
#
#
# current iteration: 268
# diff: 0.020000000000010232
# pct diff: 0.00019327406262089516
# next iteration: 269
#
#
# current iteration: 269
# diff: 1.1899999999999977
# pct diff: 0.011369064679468785
# next iteration: 270
#
#
# current iteration: 270
# diff: 1.5699999999999932
# pct diff: 0.014777861445783068
# next iteration: 271
#
#
# current iteration: 271
# diff: -0.28000000000000114
# pct diff: -0.0026425066062665268
# next iteration: 272
#
#
# current iteration: 272
# diff: 0.6200000000000045
# pct diff: 0.005817226496528472
# next iteration: 273
#
#
# current iteration: 273
# diff: -0.6599999999999966
# pct diff: -0.006231117824773382
# next iteration: 274
#
#
# current iteration: 274
# diff: -0.29000000000000625
# pct diff: -0.0027454321688914728
# next iteration: 275
#
#
# current iteration: 275
# diff: -0.6999999999999886
# pct diff: -0.006671114076050592
# next iteration: 276
#
#
# current iteration: 276
# diff: -0.5500000000000114
# pct diff: -0.005269208660663071
# next iteration: 277
#
#
# current iteration: 277
# diff: 0.0
# pct diff: 0.0
# next iteration: 278
#
#
# current iteration: 278
# diff: 0.46999999999999886
# pct diff: 0.004482594182164987
# next iteration: 279
#
#
# current iteration: 279
# diff: -0.21999999999999886
# pct diff: -0.0021026474242568944
# next iteration: 280
#
#
# current iteration: 280
# diff: 0.37000000000000455
# pct diff: 0.003523809523809567
# next iteration: 281
#
#
# current iteration: 281
# diff: 0.6500000000000057
# pct diff: 0.0061523899668718
# next iteration: 282
#
#
# current iteration: 282
# diff: -0.14000000000000057
# pct diff: -0.0013268884465927454
# next iteration: 283
#
#
# current iteration: 283
# diff: 0.5099999999999909
# pct diff: 0.0048104131295981034
# next iteration: 284
#
#
# current iteration: 284
# diff: -0.6199999999999903
# pct diff: -0.0058823529411763786
# next iteration: 285
#
#
# current iteration: 285
# diff: -0.05000000000001137
# pct diff: -0.0004746084480304829
# next iteration: 286
#
#
# current iteration: 286
# diff: 0.10000000000000853
# pct diff: 0.0009483167377905028
# next iteration: 287
#
#
# current iteration: 287
# diff: -0.37000000000000455
# pct diff: -0.0035211267605634237
# next iteration: 288
#
#
# current iteration: 288
# diff: 0.5600000000000023
# pct diff: 0.00530102234002274
# next iteration: 289
#
#
# current iteration: 289
# diff: -0.0799999999999983
# pct diff: -0.0007578628268283279
# next iteration: 290
#
#
# current iteration: 290
# diff: -0.14000000000000057
# pct diff: -0.0013280212483399788
# next iteration: 291
#
#
# current iteration: 291
# diff: 0.9099999999999966
# pct diff: 0.00855826201448318
# next iteration: 292
#
#
# current iteration: 292
# diff: -0.4299999999999926
# pct diff: -0.004060434372049033
# next iteration: 293
#
#
# current iteration: 293
# diff: 0.6299999999999955
# pct diff: 0.00591382709096025
# next iteration: 294
#
#
# current iteration: 294
# diff: -0.5499999999999972
# pct diff: -0.0051896584261181085
# next iteration: 295
#
#
# current iteration: 295
# diff: 0.1799999999999926
# pct diff: 0.001695553880934369
# next iteration: 296
#
#
# current iteration: 296
# diff: -0.01999999999999602
# pct diff: -0.0001884303749764087
# next iteration: 297
#
#
# current iteration: 297
# diff: 0.1799999999999926
# pct diff: 0.0016930022573362737
# next iteration: 298
#
#
# current iteration: 298
# diff: -0.09999999999999432
# pct diff: -0.0009414422895875948
# next iteration: 299
#
#
# current iteration: 299
# diff: 0.5700000000000074
# pct diff: 0.005337578424946225
# next iteration: 300
#
#
# current iteration: 300
# diff: 0.7599999999999909
# pct diff: 0.007066480706647987
# next iteration: 301
#
#
# current iteration: 301
# diff: -0.4200000000000017
# pct diff: -0.00392047045645479
# next iteration: 302
#
#
# current iteration: 302
# diff: -0.14999999999999147
# pct diff: -0.001402131239483936
# next iteration: 303
#
#
# current iteration: 303
# diff: 0.03999999999999204
# pct diff: 0.00037376191366092357
# next iteration: 304
#
#
# current iteration: 304
# diff: 0.9100000000000108
# pct diff: 0.008431390716205047
# next iteration: 305
#
#
# current iteration: 305
# diff: -0.9200000000000017
# pct diff: -0.008597327352583886
# next iteration: 306
#
#
# current iteration: 306
# diff: 0.3199999999999932
# pct diff: 0.0029814590515232758
# next iteration: 307
#
#
# current iteration: 307
# diff: 0.15000000000000568
# pct diff: 0.0013956084852996434
# next iteration: 308
#
#
# current iteration: 308
# diff: -0.09000000000000341
# pct diff: -0.0008380668591116809
# next iteration: 309
#
#
# current iteration: 309
# diff: 0.23000000000000398
# pct diff: 0.002137149228767924
# next iteration: 310
#
#
# current iteration: 310
# diff: 0.6400000000000006
# pct diff: 0.0059116940698318915
# next iteration: 311
#
#
# current iteration: 311
# diff: -0.5
# pct diff: -0.0046399406087602076
# next iteration: 312
#
#
# current iteration: 312
# diff: 0.6199999999999903
# pct diff: 0.005720612659162118
# next iteration: 313
#
#
# current iteration: 313
# diff: 0.20000000000000284
# pct diff: 0.0018419598452753992
# next iteration: 314
#
#
# current iteration: 314
# diff: -0.1799999999999926
# pct diff: -0.0016605166051659834
# next iteration: 315
#
#
# current iteration: 315
# diff: -0.15000000000000568
# pct diff: -0.0013856812933025929
# next iteration: 316
#
#
# current iteration: 316
# diff: -0.04000000000000625
# pct diff: -0.0003696516033638874
# next iteration: 317
#
#
# current iteration: 317
# diff: 0.05000000000001137
# pct diff: 0.0004618510992057211
# next iteration: 318
#
#
# current iteration: 318
# diff: -0.45000000000000284
# pct diff: -0.004174009832112076
# next iteration: 319
#
#
# current iteration: 319
# diff: -0.14000000000000057
# pct diff: -0.0013002693415064602
# next iteration: 320
#
#
# current iteration: 320
# diff: 0.6099999999999994
# pct diff: 0.005633542667159212
# next iteration: 321
#
#
# current iteration: 321
# diff: -0.030000000000001137
# pct diff: -0.0002771362586605186
# next iteration: 322
#
#
# current iteration: 322
# diff: 0.15000000000000568
# pct diff: 0.0013837638376384288
# next iteration: 323
#
#
# current iteration: 323
# diff: 0.5599999999999881
# pct diff: 0.005139500734214281
# next iteration: 324
#
#
# current iteration: 324
# diff: 0.39000000000000057
# pct diff: 0.003566529492455424
# next iteration: 325
#
#
# current iteration: 325
# diff: -0.4399999999999977
# pct diff: -0.004040033054815882
# next iteration: 326
#
#
# current iteration: 326
# diff: 1.0200000000000102
# pct diff: 0.009278631856636134
# next iteration: 327
#
#
# current iteration: 327
# diff: -0.3400000000000034
# pct diff: -0.003102472853362564
# next iteration: 328
#
#
# current iteration: 328
# diff: -0.710000000000008
# pct diff: -0.006520940484937619
# next iteration: 329
#
#
# current iteration: 329
# diff: 1.4200000000000017
# pct diff: 0.012873980054397115
# next iteration: 330
#
#
# current iteration: 330
# diff: 0.38000000000000966
# pct diff: 0.003433321286592064
# next iteration: 331
#
#
# current iteration: 331
# diff: 0.25
# pct diff: 0.0022536734877850895
# next iteration: 332
#
#
# current iteration: 332
# diff: -0.23000000000000398
# pct diff: -0.0020776874435411378
# next iteration: 333
#
#
# current iteration: 333
# diff: -0.8299999999999983
# pct diff: -0.007554382451988698
# next iteration: 334
#
#
# current iteration: 334
# diff: -0.3500000000000085
# pct diff: -0.003195763330898544
# next iteration: 335
#
#
# current iteration: 335
# diff: -2.6299999999999955
# pct diff: -0.024604733838525544
# next iteration: 336
#
#
# current iteration: 336
# diff: -0.4300000000000068
# pct diff: -0.0040390757091866136
# next iteration: 337
#
#
# current iteration: 337
# diff: 0.7800000000000011
# pct diff: 0.007273405445729217
# next iteration: 338
#
#
# current iteration: 338
# diff: -0.539999999999992
# pct diff: -0.005060918462980244
# next iteration: 339
#
#
# current iteration: 339
# diff: 0.6199999999999903
# pct diff: 0.005777115169586194
# next iteration: 340
#
#
# current iteration: 340
# diff: -2.309999999999988
# pct diff: -0.02199790496143213
# next iteration: 341
#
#
# current iteration: 341
# diff: -0.07000000000000739
# pct diff: -0.000667047836859228
# next iteration: 342
#
#
# current iteration: 342
# diff: 0.10000000000000853
# pct diff: 0.0009520182787510331
# next iteration: 343
#
#
# current iteration: 343
# diff: -0.5300000000000011
# pct diff: -0.00507128504449336
# next iteration: 344
#
#
# current iteration: 344
# diff: -1.1099999999999994
# pct diff: -0.010735009671179878
# next iteration: 345
#
#
# current iteration: 345
# diff: -1.6000000000000085
# pct diff: -0.01571709233791757
# next iteration: 346
#
#
# current iteration: 346
# diff: 0.35999999999999943
# pct diff: 0.0035238841033672615
# next iteration: 347
#
#
# current iteration: 347
# diff: 0.7999999999999972
# pct diff: 0.007770007770007743
# next iteration: 348
#
#
# current iteration: 348
# diff: 0.10999999999999943
# pct diff: 0.0010672358591248612
# next iteration: 349
#
#
# current iteration: 349
# diff: -0.5899999999999892
# pct diff: -0.005757220921155242
# next iteration: 350
#
#
# current iteration: 350
# diff: 0.6700000000000017
# pct diff: 0.006495395055744078
# next iteration: 351
#
#
# current iteration: 351
# diff: -0.4300000000000068
# pct diff: -0.004186137071651157
# next iteration: 352
#
#
# current iteration: 352
# diff: 1.0999999999999943
# pct diff: 0.010595261028703472
# next iteration: 353
#
#
# current iteration: 353
# diff: -0.06999999999999318
# pct diff: -0.0006746987951806572
# next iteration: 354
#
#
# current iteration: 354
# diff: -0.37999999999999545
# pct diff: -0.0036761149269613565
# next iteration: 355
#
#
# current iteration: 355
# diff: 0.25
# pct diff: 0.002412661648330438
# next iteration: 356
#
#
# current iteration: 356
# diff: -0.980000000000004
# pct diff: -0.009547934528448987
# next iteration: 357
#
#
# current iteration: 357
# diff: -0.6299999999999955
# pct diff: -0.0061758651112635565
# next iteration: 358
#
#
# current iteration: 358
# diff: -0.980000000000004
# pct diff: -0.009700089082450796
# next iteration: 359
#
#
# current iteration: 359
# diff: 0.4000000000000057
# pct diff: 0.003943606428078533
# next iteration: 360
#
#
# current iteration: 360
# diff: -1.5300000000000011
# pct diff: -0.015315315315315325
# next iteration: 361
#
#
# current iteration: 361
# diff: 1.2399999999999949
# pct diff: 0.012260233339924806
# next iteration: 362
#
#
# current iteration: 362
# diff: 1.3599999999999994
# pct diff: 0.013268292682926824
# next iteration: 363
#
#
# current iteration: 363
# diff: -0.45999999999999375
# pct diff: -0.004508036064288453
# next iteration: 364
#
#
# current iteration: 364
# diff: -0.4000000000000057
# pct diff: -0.003935458480913082
# next iteration: 365
#
#
# current iteration: 365
# diff: -0.15000000000000568
# pct diff: -0.0014779781259237925
# next iteration: 366
#
#
# current iteration: 366
# diff: -0.44999999999998863
# pct diff: -0.004453681710213664
# next iteration: 367
#
#
# current iteration: 367
# diff: -0.14000000000000057
# pct diff: -0.0013875123885034744
# next iteration: 368
#
#
# current iteration: 368
# diff: -1.3599999999999994
# pct diff: -0.013662849105887075
# next iteration: 369
#
#
# current iteration: 369
# diff: 0.8199999999999932
# pct diff: 0.008170585890793077
# next iteration: 370
#
#
# current iteration: 370
# diff: -0.5600000000000023
# pct diff: -0.005611222444889803
# next iteration: 371
#
#
# current iteration: 371
# diff: 0.14000000000000057
# pct diff: 0.0014008405043025873
# next iteration: 372
#
#
# current iteration: 372
# diff: 1.1599999999999966
# pct diff: 0.011473788328387701
# next iteration: 373
#
#
# current iteration: 373
# diff: -0.1599999999999966
# pct diff: -0.0015851000594412185
# next iteration: 374
#
#
# current iteration: 374
# diff: 1.3900000000000006
# pct diff: 0.013583504348675859
# next iteration: 375
#
#
# current iteration: 375
# diff: -1.0999999999999943
# pct diff: -0.010866343969179041
# next iteration: 376
#
#
# current iteration: 376
# diff: 0.519999999999996
# pct diff: 0.005110565110565071
# next iteration: 377
#
#
# current iteration: 377
# diff: 1.1599999999999966
# pct diff: 0.011271985229812424
# next iteration: 378
#
#
# current iteration: 378
# diff: -1.759999999999991
# pct diff: -0.01739990113692527
# next iteration: 379
#
#
# current iteration: 379
# diff: -1.440000000000012
# pct diff: -0.014441881456223167
# next iteration: 380
#
#
# current iteration: 380
# diff: -0.029999999999986926
# pct diff: -0.00030096308186182706
# next iteration: 381
#
#
# current iteration: 381
# diff: 0.2599999999999909
# pct diff: 0.002601560936561846
# next iteration: 382
#
#
# current iteration: 382
# diff: 0.2400000000000091
# pct diff: 0.0023956877620284396
# next iteration: 383
#
#
# current iteration: 383
# diff: 0.519999999999996
# pct diff: 0.005163853028798371
# next iteration: 384
#
#
# current iteration: 384
# diff: -0.09000000000000341
# pct diff: -0.0008945432859557044
# next iteration: 385
#
#
# current iteration: 385
# diff: 0.769999999999996
# pct diff: 0.007595186427303177
# next iteration: 386
#
#
# current iteration: 386
# diff: -0.28000000000000114
# pct diff: -0.002769535113748775
# next iteration: 387
#
#
# current iteration: 387
# diff: 0.9200000000000017
# pct diff: 0.00901783963928643
# next iteration: 388
#
#
# current iteration: 388
# diff: 1.0300000000000011
# pct diff: 0.009995147986414373
# next iteration: 389
#
#
# current iteration: 389
# diff: 0.519999999999996
# pct diff: 0.0050207589070193695
# next iteration: 390
#
#
# current iteration: 390
# diff: -0.2599999999999909
# pct diff: -0.002516697318749307
# next iteration: 391
#
#
# current iteration: 391
# diff: -0.0799999999999983
# pct diff: -0.0007749685169039843
# next iteration: 392
#
#
# current iteration: 392
# diff: -0.5600000000000023
# pct diff: -0.005454368364663507
# next iteration: 393
#
#
# current iteration: 393
# diff: 0.5
# pct diff: 0.004846370068818455
# next iteration: 394
#
#
# current iteration: 394
# diff: 2.950000000000003
# pct diff: 0.02779871843196384
# next iteration: 395
#
#
# current iteration: 395
# diff: -0.04000000000000625
# pct diff: -0.00037707390648573013
# next iteration: 396
#
#
# current iteration: 396
# diff: -0.030000000000001137
# pct diff: -0.0002828854314002936
# next iteration: 397
#
#
# current iteration: 397
# diff: 0.6599999999999966
# pct diff: 0.006184987348889482
# next iteration: 398
#
#
# current iteration: 398
# diff: -1.8699999999999903
# pct diff: -0.01783670354826393
# next iteration: 399
#
#
# current iteration: 399
# diff: 0.4299999999999926
# pct diff: 0.004084734492257933
# next iteration: 400
#
#
# current iteration: 400
# diff: -1.3799999999999955
# pct diff: -0.01328328039272303
# next iteration: 401
#
#
# current iteration: 401
# diff: -1.2900000000000063
# pct diff: -0.01257309941520474
# next iteration: 402
#
#
# current iteration: 402
# diff: 0.6099999999999994
# pct diff: 0.0059102800116267755
# next iteration: 403
#
#
# current iteration: 403
# diff: -4.009999999999991
# pct diff: -0.0404233870967741
# next iteration: 404
#
#
# current iteration: 404
# diff: -1.4200000000000017
# pct diff: -0.014522397218245057
# next iteration: 405
#
#
# current iteration: 405
# diff: 0.6099999999999994
# pct diff: 0.006199817054578711
# next iteration: 406
#
#
# current iteration: 406
# diff: -0.5600000000000023
# pct diff: -0.005724215475825435
# next iteration: 407
#
#
# current iteration: 407
# diff: 0.10000000000000853
# pct diff: 0.0010211375472276986
# next iteration: 408
#
#
# current iteration: 408
# diff: 0.6699999999999875
# pct diff: 0.006795131845841658
# next iteration: 409
#
#
# current iteration: 409
# diff: -0.789999999999992
# pct diff: -0.008076883754217279
# next iteration: 410
#
#
# current iteration: 410
# diff: -0.6599999999999966
# pct diff: -0.006793618116314942
# next iteration: 411
#
#
# current iteration: 411
# diff: 0.44999999999998863
# pct diff: 0.004610655737704802
# next iteration: 412
#
#
# current iteration: 412
# diff: 1.5500000000000114
# pct diff: 0.015632879475542222
# next iteration: 413
#
#
# current iteration: 413
# diff: -1.230000000000004
# pct diff: -0.012561274509803962
# next iteration: 414
#
#
# current iteration: 414
# diff: 0.01999999999999602
# pct diff: 0.00020420665713698205
# next iteration: 415
#
#
# current iteration: 415
# diff: 0.8599999999999994
# pct diff: 0.008704453441295541
# next iteration: 416
#
#
# current iteration: 416
# diff: 0.14000000000000057
# pct diff: 0.001414998989286442
# next iteration: 417
#
#
# current iteration: 417
# diff: 0.010000000000005116
# pct diff: 0.0001010611419909562
# next iteration: 418
#
#
# current iteration: 418
# diff: 0.28999999999999204
# pct diff: 0.0029222087867794445
# next iteration: 419
#
#
# current iteration: 419
# diff: -1.6099999999999994
# pct diff: -0.01649083273583939
# next iteration: 420
#
#
# current iteration: 420
# diff: 0.29000000000000625
# pct diff: 0.002961601307189606
# next iteration: 421
#
#
# current iteration: 421
# diff: 0.09999999999999432
# pct diff: 0.0010201999591919436
# next iteration: 422
#
#
# current iteration: 422
# diff: -0.09999999999999432
# pct diff: -0.0010212418300653014
# next iteration: 423
#
#
# current iteration: 423
# diff: -4.280000000000001
# pct diff: -0.045706962836394714
# next iteration: 424
#
#
# current iteration: 424
# diff: 0.010000000000005116
# pct diff: 0.00010678056593705409
# next iteration: 425
#
#
# current iteration: 425
# diff: 0.01999999999999602
# pct diff: 0.00021351553325500182
# next iteration: 426
#
#
# current iteration: 426
# diff: 0.769999999999996
# pct diff: 0.008153324862346422
# next iteration: 427
#
#
# current iteration: 427
# diff: 0.9000000000000057
# pct diff: 0.009439899307740777
# next iteration: 428
#
#
# current iteration: 428
# diff: -0.8900000000000006
# pct diff: -0.009422975119110647
# next iteration: 429
#
#
# current iteration: 429
# diff: 0.5999999999999943
# pct diff: 0.00631246712256701
# next iteration: 430
#
#
# current iteration: 430
# diff: -0.4099999999999966
# pct diff: -0.004332206255283143
# next iteration: 431
#
#
# current iteration: 431
# diff: 0.3199999999999932
# pct diff: 0.0033698399326031296
# next iteration: 432
#
#
# current iteration: 432
# diff: 0.75
# pct diff: 0.007836171768885174
# next iteration: 433
#
#
# current iteration: 433
# diff: -0.30999999999998806
# pct diff: -0.0032494758909851996
# next iteration: 434
#
#
# current iteration: 434
# diff: -0.28000000000000114
# pct diff: -0.002943650126156446
# next iteration: 435
#
#
# current iteration: 435
# diff: 0.9399999999999977
# pct diff: 0.009785550697480718
# next iteration: 436
#
#
# current iteration: 436
# diff: -0.9099999999999966
# pct diff: -0.009563846558066174
# next iteration: 437
#
#
# current iteration: 437
# diff: 0.5899999999999892
# pct diff: 0.006162523501148833
# next iteration: 438
#
#
# current iteration: 438
# diff: -1.1499999999999915
# pct diff: -0.01215773337562101
# next iteration: 439
#
#
# current iteration: 439
# diff: 0.5
# pct diff: 0.005258176464402145
# next iteration: 440
#
#
# current iteration: 440
# diff: 1.25
# pct diff: 0.012974880631098194
# next iteration: 441
#
#
# current iteration: 441
# diff: 0.8999999999999915
# pct diff: 0.009255450431920933
# next iteration: 442
#
#
# current iteration: 442
# diff: -0.22999999999998977
# pct diff: -0.0023708895990103055
# next iteration: 443
#
#
# current iteration: 443
# diff: -0.4300000000000068
# pct diff: -0.004452267550217507
# next iteration: 444
#
#
# current iteration: 444
# diff: -0.03999999999999204
# pct diff: -0.00041433602651742325
# next iteration: 445
#
#
# current iteration: 445
# diff: -0.480000000000004
# pct diff: -0.004996876951905101
# next iteration: 446
#
#
# current iteration: 446
# diff: 0.009999999999990905
# pct diff: 0.00010409076714885922
# next iteration: 447
#
#
# current iteration: 447
# diff: -0.9899999999999949
# pct diff: -0.010412284392090817
# next iteration: 448
#
#
# current iteration: 448
# diff: -1.5699999999999932
# pct diff: -0.01678964816597148
# next iteration: 449
#
#
# current iteration: 449
# diff: 0.4399999999999977
# pct diff: 0.004683342203299603
# next iteration: 450
#
#
# current iteration: 450
# diff: 0.7199999999999989
# pct diff: 0.007605366008239135
# next iteration: 451
#
#
# current iteration: 451
# diff: 0.21999999999999886
# pct diff: 0.002318474022552417
# next iteration: 452
#
#
# current iteration: 452
# diff: -0.09999999999999432
# pct diff: -0.0010549636037556103
# next iteration: 453
#
#
# current iteration: 453
# diff: 0.7299999999999898
# pct diff: 0.00764237855946388
# next iteration: 454
#
#
# current iteration: 454
# diff: 0.38000000000000966
# pct diff: 0.003962460896767567
# next iteration: 455
#
#
# current iteration: 455
# diff: -0.6800000000000068
# pct diff: -0.007141356857803054
# next iteration: 456
#
#
# current iteration: 456
# diff: -0.4000000000000057
# pct diff: -0.0042185192997258565
# next iteration: 457
#
#
# current iteration: 457
# diff: -0.46999999999999886
# pct diff: -0.004981452040275558
# next iteration: 458
#
#
# current iteration: 458
# diff: 0.7400000000000091
# pct diff: 0.007782101167315271
# next iteration: 459
#
#
# current iteration: 459
# diff: -0.25
# pct diff: -0.002636018557570645
# next iteration: 460
#
#
# current iteration: 460
# diff: -0.2600000000000051
# pct diff: -0.00274899555931492
# next iteration: 461
#
#
# current iteration: 461
# diff: -0.21999999999999886
# pct diff: -0.002331496396778284
# next iteration: 462
#
#
# current iteration: 462
# diff: 1.1800000000000068
# pct diff: 0.012350847812434652
# next iteration: 463
#
#
# current iteration: 463
# diff: -0.6600000000000108
# pct diff: -0.006956155143339068
# next iteration: 464
#
#
# current iteration: 464
# diff: 0.28000000000000114
# pct diff: 0.0029424127784783644
# next iteration: 465
#
#
# current iteration: 465
# diff: 1.9300000000000068
# pct diff: 0.019878463281491468
# next iteration: 466
#
#
# current iteration: 466
# diff: 0.9399999999999977
# pct diff: 0.009588901356727509
# next iteration: 467
#
#
# current iteration: 467
# diff: -0.4200000000000017
# pct diff: -0.004302837823993461
# next iteration: 468
#
#
# current iteration: 468
# diff: 1.4500000000000028
# pct diff: 0.014637593377750887
# next iteration: 469
#
#
# current iteration: 469
# diff: 2.030000000000001
# pct diff: 0.02008111583737265
# next iteration: 470
#
#
# current iteration: 470
# diff: -0.04000000000000625
# pct diff: -0.0003958436417615661
# next iteration: 471
#
#
# current iteration: 471
# diff: -1.519999999999996
# pct diff: -0.0152717773535617
# next iteration: 472
#
#
# current iteration: 472
# diff: 0.5
# pct diff: 0.0049985004498650405
# next iteration: 473
#
#
# current iteration: 473
# diff: -0.0799999999999983
# pct diff: -0.0008004002001000329
# next iteration: 474
#
#
# current iteration: 474
# diff: -0.1599999999999966
# ...
# next iteration: 1356
#
#
# current iteration: 1356
# diff: -3.400000000000034
# pct diff: -0.012351060738157638
# next iteration: 1357
#
#
# current iteration: 1357
# diff: 0.6200000000000045
# pct diff: 0.0022471910112359717
# next iteration: 1358
#
#
# current iteration: 1358
# diff: -2.5600000000000023
# pct diff: -0.009365625228652969
# next iteration: 1359
#
#
# current iteration: 1359
# diff: -1.839999999999975
# pct diff: -0.006777163904235635
# next iteration: 1360
#
#
# current iteration: 1360
# diff: 0.7400000000000091
# pct diff: 0.002718189832500768
# next iteration: 1361
#
#
# current iteration: 1361
# diff: -3.660000000000025
# pct diff: -0.013627224663042763
# next iteration: 1362
#
#
# current iteration: 1362
# diff: -0.6899999999999977
# pct diff: -0.0025756840494232623
# next iteration: 1363
#
#
# current iteration: 1363
# diff: 5.819999999999993
# pct diff: 0.021263380950641165
# next iteration: 1364
#
#
# current iteration: 1364
# diff: 2.3700000000000045
# pct diff: 0.008584468270066665
# next iteration: 1365
#
#
# current iteration: 1365
# diff: 1.7900000000000205
# pct diff: 0.006441861302047794
# next iteration: 1366
#
#
# current iteration: 1366
# diff: 2.7900000000000205
# pct diff: 0.009940853701988243
# next iteration: 1367
#
#
# current iteration: 1367
# diff: 1.2799999999999727
# pct diff: 0.004539973043909955
# next iteration: 1368
#
#
# current iteration: 1368
# diff: -0.06999999999999318
# pct diff: -0.0002483414339943704
# next iteration: 1369
#
#
# current iteration: 1369
# diff: -0.4900000000000091
# pct diff: -0.0017414173004478254
# next iteration: 1370
#
#
# current iteration: 1370
# diff: 1.160000000000025
# pct diff: 0.004105613364479454
# next iteration: 1371
#
#
# current iteration: 1371
# diff: -0.3100000000000023
# pct diff: -0.0010983949261240912
# next iteration: 1372
#
#
# current iteration: 1372
# diff: 0.0999999999999659
# pct diff: 0.0003541954450464559
# next iteration: 1373
#
#
# current iteration: 1373
# diff: 2.9600000000000364
# pct diff: 0.010375407480108087
# next iteration: 1374
#
#
# current iteration: 1374
# diff: 0.6399999999999864
# pct diff: 0.002238310075892653
# next iteration: 1375
#
#
# current iteration: 1375
# diff: 2.740000000000009
# pct diff: 0.009491807253957837
# next iteration: 1376
#
#
# current iteration: 1376
# diff: -0.4200000000000159
# pct diff: -0.0014570685169124577
# next iteration: 1377
#
#
# current iteration: 1377
# diff: -0.36000000000001364
# pct diff: -0.0012504776129772263
# next iteration: 1378
#
#
# current iteration: 1378
# diff: -2.819999999999993
# pct diff: -0.009892307152629155
# next iteration: 1379
#
#
# current iteration: 1379
# diff: -0.2799999999999727
# pct diff: -0.0009831805892059858
# next iteration: 1380
#
#
# current iteration: 1380
# diff: 1.0
# pct diff: 0.0034990727457223834
# next iteration: 1381
#
#
# current iteration: 1381
# diff: 1.4799999999999613
# pct diff: 0.005151947645072446
# next iteration: 1382
#
#
# current iteration: 1382
# diff: 2.6000000000000227
# pct diff: 0.008969538068789536
# next iteration: 1383
#
#
# current iteration: 1383
# diff: 0.7599999999999909
# pct diff: 0.002615008774042566
# next iteration: 1384
#
#
# current iteration: 1384
# diff: 2.319999999999993
# pct diff: 0.00791944017750467
# next iteration: 1385
#
#
# current iteration: 1385
# diff: -0.3299999999999841
# pct diff: -0.001127742464629841
# next iteration: 1386
#
#
# current iteration: 1386
# diff: -1.6100000000000136
# pct diff: -0.005532455929349554
# next iteration: 1387
#
#
# current iteration: 1387
# diff: 0.36000000000001364
# pct diff: 0.001235542437450711
# next iteration: 1388
#
#
# current iteration: 1388
# diff: 1.3999999999999773
# pct diff: 0.0047819107148955745
# next iteration: 1389
#
#
# current iteration: 1389
# diff: 0.6800000000000068
# pct diff: 0.002317260180610008
# next iteration: 1390
#
#
# current iteration: 1390
# diff: 1.3199999999999932
# pct diff: 0.004478067645961235
# next iteration: 1391
#
#
# current iteration: 1391
# diff: 0.09000000000003183
# pct diff: 0.0003052296004884753
# next iteration: 1392
#
#
# current iteration: 1392
# diff: -0.9499999999999886
# pct diff: -0.0032322819910856676
# next iteration: 1393
#
#
# current iteration: 1393
# diff: -2.0
# pct diff: -0.006851426809633105
# next iteration: 1394
#
#
# current iteration: 1394
# diff: 1.0699999999999932
# pct diff: 0.0036521264250119227
# next iteration: 1395
#
#
# current iteration: 1395
# diff: -1.6299999999999955
# pct diff: -0.005594645615239387
# next iteration: 1396
#
#
# current iteration: 1396
# diff: 0.7199999999999704
# pct diff: 0.002465162461053756
# next iteration: 1397
#
#
# current iteration: 1397
# diff: 2.090000000000032
# pct diff: 0.007104976883328908
# next iteration: 1398
#
#
# current iteration: 1398
# diff: 1.3799999999999955
# pct diff: 0.004669418691209296
# next iteration: 1399
#
#
# current iteration: 1399
# diff: -1.410000000000025
# pct diff: -0.004793798660456346
# next iteration: 1400
#
#
# current iteration: 1400
# diff: 1.9700000000000273
# pct diff: 0.006653157716987596
# next iteration: 1401
#
#
# current iteration: 1401
# diff: -0.5400000000000205
# pct diff: -0.0018270401948843567
# next iteration: 1402
#
#
# current iteration: 1402
# diff: -0.7300000000000182
# pct diff: -0.0024760031204423506
# next iteration: 1403
#
#
# current iteration: 1403
# diff: -3.2199999999999704
# pct diff: -0.011042145331092797
# next iteration: 1404
#
#
# current iteration: 1404
# diff: -2.5400000000000205
# pct diff: -0.008786799045214034
# next iteration: 1405
#
#
# current iteration: 1405
# diff: -2.180000000000007
# pct diff: -0.007598731221025504
# next iteration: 1406
#
#
# current iteration: 1406
# diff: -8.620000000000005
# pct diff: -0.030977108563625275
# next iteration: 1407
#
#
# current iteration: 1407
# diff: 3.900000000000034
# pct diff: 0.013821455151150136
# next iteration: 1408
#
#
# current iteration: 1408
# diff: 0.15999999999996817
# pct diff: 0.00056671271207441
# next iteration: 1409
#
#
# current iteration: 1409
# diff: 5.5400000000000205
# pct diff: 0.019244797999096886
# next iteration: 1410
#
#
# current iteration: 1410
# diff: -1.9599999999999795
# pct diff: -0.006855304116680002
# next iteration: 1411
#
#
# current iteration: 1411
# diff: -3.480000000000018
# pct diff: -0.01232163721984215
# next iteration: 1412
#
#
# current iteration: 1412
# diff: 4.389999999999986
# pct diff: 0.015305766682936987
# next iteration: 1413
#
#
# current iteration: 1413
# diff: -8.480000000000018
# pct diff: -0.03046633613566149
# next iteration: 1414
#
#
# current iteration: 1414
# diff: 0.7400000000000091
# pct diff: 0.0026515694424538096
# next iteration: 1415
#
#
# current iteration: 1415
# diff: 4.1200000000000045
# pct diff: 0.014548022598870072
# next iteration: 1416
#
#
# current iteration: 1416
# diff: 3.410000000000025
# pct diff: 0.01189770070827963
# next iteration: 1417
#
#
# current iteration: 1417
# diff: -2.1999999999999886
# pct diff: -0.007735311697900877
# next iteration: 1418
#
#
# current iteration: 1418
# diff: 2.319999999999993
# pct diff: 0.008091235657238493
# next iteration: 1419
#
#
# current iteration: 1419
# diff: -0.09000000000003183
# pct diff: -0.00031398269606486127
# next iteration: 1420
#
#
# current iteration: 1420
# diff: -7.360000000000014
# pct diff: -0.026353480378115204
# next iteration: 1421
#
#
# current iteration: 1421
# diff: 3.080000000000041
# pct diff: 0.010908060631817682
# next iteration: 1422
#
#
# current iteration: 1422
# diff: -1.1000000000000227
# pct diff: -0.003910972054327038
# next iteration: 1423
#
#
# current iteration: 1423
# diff: 1.9800000000000182
# pct diff: 0.006990538059596166
# next iteration: 1424
#
#
# current iteration: 1424
# diff: 3.6100000000000136
# pct diff: 0.012584974725466318
# next iteration: 1425
#
#
# current iteration: 1425
# diff: -0.12000000000000455
# pct diff: -0.00041851218916752535
# next iteration: 1426
#
#
# current iteration: 1426
# diff: -1.6800000000000068
# pct diff: -0.005893702859147542
# next iteration: 1427
#
#
# current iteration: 1427
# diff: 3.240000000000009
# pct diff: 0.011238683270318113
# next iteration: 1428
#
#
# current iteration: 1428
# diff: 3.6999999999999886
# pct diff: 0.012671666837905368
# next iteration: 1429
#
#
# current iteration: 1429
# diff: 0.2300000000000182
# pct diff: 0.0007870782287318397
# next iteration: 1430
#
#
# current iteration: 1430
# diff: 0.13999999999998636
# pct diff: 0.00047886167738400037
# next iteration: 1431
#
#
# current iteration: 1431
# diff: -0.060000000000002274
# pct diff: -0.00020526855969894722
# next iteration: 1432
#
#
# current iteration: 1432
# diff: 2.069999999999993
# pct diff: 0.007031966572680617
# next iteration: 1433
#
#
# current iteration: 1433
# diff: 1.0199999999999818
# pct diff: 0.003453062053556254
# next iteration: 1434
#
#
# current iteration: 1434
# diff: -0.18999999999999773
# pct diff: -0.0006436314363143555
# next iteration: 1435
#
#
# current iteration: 1435
# diff: -0.9099999999999682
# pct diff: -0.0030921879778448747
# next iteration: 1436
#
#
# current iteration: 1436
# diff: 0.7399999999999523
# pct diff: 0.0025082195031012177
# next iteration: 1437
#
#
# current iteration: 1437
# diff: 0.18000000000000682
# pct diff: 0.0006097354425663319
# next iteration: 1438
#
#
# current iteration: 1438
# diff: -0.01999999999998181
# pct diff: -6.775297266161391e-05
# next iteration: 1439
#
#
# current iteration: 1439
# diff: -1.3999999999999773
# pct diff: -0.004765308553728777
# next iteration: 1440
#
#
# current iteration: 1440
# diff: -0.06999999999999318
# pct diff: -0.0002383222116301007
# next iteration: 1441
#
#
# current iteration: 1441
# diff: -2.3000000000000114
# pct diff: -0.007892388991833131
# next iteration: 1442
#
#
# current iteration: 1442
# diff: 1.7199999999999704
# pct diff: 0.005867503581906156
# next iteration: 1443
#
#
# current iteration: 1443
# diff: -0.6100000000000136
# pct diff: -0.0020852562130380258
# next iteration: 1444
#
#
# current iteration: 1444
# diff: -1.5699999999999932
# pct diff: -0.005395930712125355
# next iteration: 1445
#
#
# current iteration: 1445
# diff: 1.3500000000000227
# pct diff: 0.00461838459170067
# next iteration: 1446
#
#
# current iteration: 1446
# diff: -3.480000000000018
# pct diff: -0.01204860990894304
# next iteration: 1447
#
#
# current iteration: 1447
# diff: -5.099999999999966
# pct diff: -0.01797483523067693
# next iteration: 1448
#
#
# current iteration: 1448
# diff: 2.319999999999993
# pct diff: 0.008110470197517892
# next iteration: 1449
#
#
# current iteration: 1449
# diff: 3.8700000000000045
# pct diff: 0.013348509933774849
# next iteration: 1450
#
#
# current iteration: 1450
# diff: -1.25
# pct diff: -0.004330204039214328
# next iteration: 1451
#
#
# current iteration: 1451
# diff: -4.480000000000018
# pct diff: -0.01576410148140335
# next iteration: 1452
#
#
# current iteration: 1452
# diff: 2.6999999999999886
# pct diff: 0.009411272613196657
# next iteration: 1453
#
#
# current iteration: 1453
# diff: 1.9399999999999977
# pct diff: 0.0067167537998130316
# next iteration: 1454
#
#
# current iteration: 1454
# diff: 2.990000000000009
# pct diff: 0.010246042080734732
# next iteration: 1455
#
#
# current iteration: 1455
# diff: -0.3199999999999932
# pct diff: -0.0010977701543739046
# next iteration: 1456
#
#
# current iteration: 1456
# diff: 2.8799999999999955
# pct diff: 0.009783273320198368
# next iteration: 1457
#
#
# current iteration: 1457
# diff: -0.46999999999997044
# pct diff: -0.001599128985063354
# next iteration: 1458
#
#
# current iteration: 1458
# diff: 0.8699999999999477
# pct diff: 0.0029513535518011663
# next iteration: 1459
#
#
# current iteration: 1459
# diff: -1.2899999999999636
# pct diff: -0.004395379740365817
# next iteration: 1460
#
#
# current iteration: 1460
# diff: 1.990000000000009
# pct diff: 0.006734804386083691
# next iteration: 1461
#
#
# current iteration: 1461
# diff: -0.9700000000000273
# pct diff: -0.0032936063291569974
# next iteration: 1462
#
#
# current iteration: 1462
# diff: 0.8600000000000136
# pct diff: 0.0029116023969936473
# next iteration: 1463
#
#
# current iteration: 1463
# diff: 0.4800000000000182
# pct diff: 0.001622443805982823
# next iteration: 1464
#
#
# current iteration: 1464
# diff: 1.2099999999999795
# pct diff: 0.004073251195044703
# next iteration: 1465
#
#
# current iteration: 1465
# diff: 1.6800000000000068
# pct diff: 0.005623619200642722
# next iteration: 1466
#
#
# current iteration: 1466
# diff: -0.09000000000003183
# pct diff: -0.00030135610246118143
# next iteration: 1467
#
#
# current iteration: 1467
# diff: 0.910000000000025
# pct diff: 0.003037788756843454
# next iteration: 1468
#
#
# current iteration: 1468
# diff: -0.7900000000000205
# pct diff: -0.0026441744485725493
# next iteration: 1469
#
#
# current iteration: 1469
# diff: 2.759999999999991
# pct diff: 0.009153318077803174
# next iteration: 1470
#
#
# current iteration: 1470
# diff: 1.2200000000000273
# pct diff: 0.004029727497935681
# next iteration: 1471
#
#
# current iteration: 1471
# diff: -0.339999999999975
# pct diff: -0.001124301445057951
# next iteration: 1472
#
#
# current iteration: 1472
# diff: 0.06999999999999318
# pct diff: 0.00023142025919066774
# next iteration: 1473
#
#
# current iteration: 1473
# diff: 1.0600000000000023
# pct diff: 0.0034921262436581743
# next iteration: 1474
#
#
# current iteration: 1474
# diff: 0.75
# pct diff: 0.0024647540175490486
# next iteration: 1475
#
#
# current iteration: 1475
# diff: -0.5800000000000409
# pct diff: -0.001909716505877452
# next iteration: 1476
#
#
# current iteration: 1476
# diff: 0.6400000000000432
# pct diff: 0.002102842122556409
# next iteration: 1477
#
#
# current iteration: 1477
# diff: 0.0999999999999659
# pct diff: 0.0003284611594677809
# next iteration: 1478
#
#
# current iteration: 1478
# diff: 0.4399999999999977
# pct diff: 0.0014431434287775844
# next iteration: 1479
#
#
# current iteration: 1479
# diff: 2.2100000000000364
# pct diff: 0.007196352979485628
# next iteration: 1480
#
#
# current iteration: 1480
# diff: 0.22999999999996135
# pct diff: 0.0007483812188851116
# next iteration: 1481
#
#
# current iteration: 1481
# diff: -0.08999999999997499
# pct diff: -0.0002929306079936694
# next iteration: 1482
#
#
# current iteration: 1482
# diff: -1.150000000000034
# pct diff: -0.0037570649155478264
# next iteration: 1483
#
#
# current iteration: 1483
# diff: -0.48999999999995225
# pct diff: -0.0016034031413611001
# next iteration: 1484
#
#
# current iteration: 1484
# diff: 0.67999999999995
# pct diff: 0.0022201906751990012
# next iteration: 1485
#
#
# current iteration: 1485
# diff: 2.3800000000000523
# pct diff: 0.007710749692218143
# next iteration: 1486
#
#
# current iteration: 1486
# diff: 0.6899999999999977
# pct diff: 0.0022304832713754574
# next iteration: 1487
#
#
# current iteration: 1487
# diff: 1.3799999999999955
# pct diff: 0.004441154700222043
# next iteration: 1488
#
#
# current iteration: 1488
# diff: -1.150000000000034
# pct diff: -0.0037147102526004076
# next iteration: 1489
#
#
# current iteration: 1489
# diff: -2.6299999999999955
# pct diff: -0.008568170711842306
# next iteration: 1490
#
#
# current iteration: 1490
# diff: -2.0600000000000023
# pct diff: -0.00675653514382237
# next iteration: 1491
#
#
# current iteration: 1491
# diff: 1.8799999999999955
# pct diff: 0.006128369788440837
# next iteration: 1492
#
#
# current iteration: 1492
# diff: 0.5600000000000023
# pct diff: 0.0018221455764162375
# next iteration: 1493
#
#
# current iteration: 1493
# diff: 2.8000000000000114
# pct diff: 0.009028471931125694
# next iteration: 1494
#
#
# current iteration: 1494
# diff: -0.9699999999999704
# pct diff: -0.003137533962996411
# next iteration: 1495
#
#
# current iteration: 1495
# diff: -0.35000000000002274
# pct diff: -0.0011333829863023307
# next iteration: 1496
#
#
# current iteration: 1496
# diff: 0.8799999999999955
# pct diff: 0.002841551228647988
# next iteration: 1497
#
#
# current iteration: 1497
# diff: 2.670000000000016
# pct diff: 0.008547829427583607
# next iteration: 1498
#
#
# current iteration: 1498
# diff: 0.18999999999999773
# pct diff: 0.0006079027355623027
# next iteration: 1499
#
#
# current iteration: 1499
# diff: 2.1399999999999864
# pct diff: 0.006800343194890166
# next iteration: 1500
#
#
# current iteration: 1500
# diff: 0.06999999999999318
# pct diff: 0.00022239166348962124
# next iteration: 1501
#
#
# current iteration: 1501
# diff: 0.01999999999998181
# pct diff: 6.353643814721969e-05
# next iteration: 1502
#
#
# current iteration: 1502
# diff: 1.2900000000000205
# pct diff: 0.004081374379093304
# next iteration: 1503
#
#
# current iteration: 1503
# diff: 1.3899999999999864
# pct diff: 0.004378504378504336
# next iteration: 1504
#
#
# current iteration: 1504
# diff: 0.4800000000000182
# pct diff: 0.0015097188148707876
# next iteration: 1505
#
#
# current iteration: 1505
# diff: 0.009999999999990905
# pct diff: 3.1451486082688803e-05
# next iteration: 1506
#
#
# current iteration: 1506
# diff: 1.6999999999999886
# pct diff: 0.005318316909119314
# next iteration: 1507
#
#
# current iteration: 1507
# diff: -0.07999999999998408
# pct diff: -0.0002503363895233723
# next iteration: 1508
#
#
# current iteration: 1508
# diff: -1.7699999999999818
# pct diff: -0.005569540591566966
# next iteration: 1509
#
#
# current iteration: 1509
# diff: 0.7799999999999727
# pct diff: 0.0024483646179922556
# next iteration: 1510

# %%
# if we listen to the advice, we only see positive increases and we avoid taking any losses

spy_cash = 100

for pct in spy_pct_diff_l:
    if pct >= 0:
        spy_cash = spy_cash*(1+pct)
    else:
        spy_cash = spy_cash*(1)

print("On the last day, with the Oracle's help, $100 investment in SPY yields, ${}".format(round(spy_cash),2))
# Out:
# On the last day, with the Oracle's help, $100 investment in SPY yields, $9983

# %%
# if we listen to the advice, we only see positive increases and we avoid taking any losses

dis_cash = 100

for pct in dis_pct_diff_l:
    if pct >= 0:
        dis_cash = dis_cash*(1+pct)
    else:
        dis_cash = dis_cash*(1)

print("On the last day, with the Oracle's help, $100 investment in DIS yields, ${}".format(round(dis_cash),2))
# Out:
# On the last day, with the Oracle's help, $100 investment in DIS yields, $92142

# %% [markdown]
# #### 5.1 Consider a "buy-and-hold" strategy. you buy on the first trading day and sell on the last day. So you do not listen to your oracle at all. As before, assume that you start with $100 for both your stock and "spy".

# %%
spy_cash = 100

for pct in spy_pct_diff_l:
    spy_cash = spy_cash*(1+pct)

print("On the last day, without the Oracle's help, $100 investment in SPY yields, ${}".format(round(spy_cash),2))
# Out:
# On the last day, without the Oracle's help, $100 investment in SPY yields, $179

# %%
dis_cash = 100

for pct in dis_pct_diff_l:
    dis_cash = dis_cash*(1+pct)

print("On the last day, with the Oracle's help, $100 investment in DIS yields, ${}".format(round(dis_cash),2))
# Out:
# On the last day, with the Oracle's help, $100 investment in DIS yields, $127

# %% [markdown]
# #### 5.2 How do these results compare with the results obtained in question 4?
# - Orders of magnitude different. The buy-and-hold strategy yields minimal returns.

# %% [markdown]
# Question 6: Your oracle got very upset that you did not follow its advice. It decided to take revenge by giving you
# wrong advice from time to time. Speci cally, let us consider the following three scenarios:
# * (a) Oracle gave you wrong results for the best 10 trading days. In other words, you missed the best 10 days and your overall profit will be lower.
#
# * (b) Oracle gave you wrong results for worst 10 trading days. In other words, you missed the worst 10 days and your overall profit will be higher.
#
# * (c) Oracle gave you wrong results for best 5 days and for the worst 5 days.

# %%
# find the worst 10 trading  and remove them from the dataset then run cals

# %% [markdown]
# #### 6.1 For each of the scenarios above (a,b and c), compute the final amount that you will have for both your stock and "spy"

# %% [markdown]
# #### a. Find the best 10 trading days for SPY and DIS and remove them from the dataset then run calcs

# %%
# a. find the best 10 trading days for SPY and remove them from the dataset then run calcs
spy_pct_diff_idx = []
for i in range(len(spy_pct_diff_l)):
    spy_pct_diff_idx.append([spy_pct_diff_l[i],i])

spy_pct_diff_idx.sort()

sort_index = [] 
for x in spy_pct_diff_idx:
      sort_index.append(x[1])

# print(sort_index)

# %%
# remove the top ten from the list
excl_sort_index_a = sort_index[-10:]

# %%
sorted(excl_sort_index_a)
# Out:
# [243, 415, 416, 423, 522, 543, 1064, 1236, 1254, 1260]

# %%
# find the daily returns without the top ten days
a_spy_pct_diff_l = []
for i in range(len(spy_pct_diff_l)):
    if i not in excl_sort_index_a:
        a_spy_pct_diff_l.append(spy_pct_diff_l[i])

# %%
# if we listen to the advice, we only see positive increases and we avoid taking any losses
# we will run this strategy on the new list

spy_cash = 100

for pct in a_spy_pct_diff_l:
    if pct >= 0:
        spy_cash = spy_cash*(1+pct)
    else:
        spy_cash = spy_cash*(1)

print("With scenario (a), $100 investment in SPY yields, ${}".format(round(spy_cash),2))
# Out:
# With scenario (a), $100 investment in SPY yields, $7531

# %%
dis_pct_diff_idx = []
for i in range(len(dis_pct_diff_l)):
    dis_pct_diff_idx.append([dis_pct_diff_l[i],i])

dis_pct_diff_idx.sort()

sort_index = [] 
for x in dis_pct_diff_idx:
      sort_index.append(x[1])

# print(sort_index)

# remove the top ten from the list
excl_sort_index_a = sort_index[-10:]

# find the daily returns without the top ten days
a_dis_pct_diff_l = []
for i in range(len(dis_pct_diff_l)):
    if i not in excl_sort_index_a:
        a_dis_pct_diff_l.append(dis_pct_diff_l[i])
        
# if we listen to the advice, we only see positive increases and we avoid taking any losses
# we will run this strategy on the new list

dis_cash = 100

for pct in a_dis_pct_diff_l:
    if pct >= 0:
        dis_cash = dis_cash*(1+pct)
    else:
        dis_cash = dis_cash*(1)

print("With scenario (a), $100 investment in DIS yields, ${}".format(round(dis_cash),2))
# Out:
# With scenario (a), $100 investment in DIS yields, $38868

# %% [markdown]
# #### b. Find the worst 10 trading days for SPY and DIS and include them in the dataset then run calcs

# %%
spy_pct_diff_idx = []
for i in range(len(spy_pct_diff_l)):
    spy_pct_diff_idx.append([spy_pct_diff_l[i],i])

spy_pct_diff_idx.sort()

sort_index = [] 
for x in spy_pct_diff_idx:
      sort_index.append(x[1])

# include the bottom ten from the list
incl_sort_index_b = sort_index[10:]

# find the change in $100 invested in SPY with the worst ten days included with the best days
spy_cash = 100

for i in range(len(spy_pct_diff_l)):
    pct = spy_pct_diff_l[i]
    if (pct > 0) | (i in incl_sort_index_b):
        spy_cash = spy_cash*(1+pct)
    else:
        spy_cash = spy_cash*(1)
        
print("With scenario (b), $100 investment in SPY yields, ${}".format(round(spy_cash),2))
# Out:
# With scenario (b), $100 investment in SPY yields, $256

# %%
dis_pct_diff_idx = []
for i in range(len(dis_pct_diff_l)):
    dis_pct_diff_idx.append([spy_pct_diff_l[i],i])

dis_pct_diff_idx.sort()

sort_index = [] 
for x in dis_pct_diff_idx:
      sort_index.append(x[1])

# print(sort_index)

# include the bottom ten from the list
incl_sort_index_b = sort_index[10:]

# find the change in $100 invested in DIS with the worst ten days included with the best days
dis_cash = 100

for i in range(len(spy_pct_diff_l)):
    pct = spy_pct_diff_l[i]
    if (pct > 0) | (i in incl_sort_index_b):
        spy_cash = spy_cash*(1+pct)
    else:
        spy_cash = spy_cash*(1)
        
print("With scenario (b), $100 investment in DIS yields, ${}".format(round(dis_cash),2))
# Out:
# With scenario (b), $100 investment in DIS yields, $100

# %% [markdown]
# #### c. Find the best 5 trading days for SPY and DIS and remove them from the dataset then run calcs. Find the worst 5 trading days for SPY and DIS and include them from the dataset.

# %%
# find the 5 best days for SPY and remove them from the dataset
spy_pct_diff_idx = []
for i in range(len(spy_pct_diff_l)):
    spy_pct_diff_idx.append([spy_pct_diff_l[i],i])

spy_pct_diff_idx.sort()

sort_index = [] 
for x in spy_pct_diff_idx:
      sort_index.append(x[1])

# print(sort_index)

# remove the top ten from the list
excl_sort_index_c = sort_index[-5:]

# include the bottom five from the list
incl_sort_index_c = sort_index[5:]

# find the change in $100 invested in SPY with the worst five days included with the five best days removed
spy_cash = 100

for i in range(len(spy_pct_diff_l)):
    if i not in excl_sort_index_c:
        pct = spy_pct_diff_l[i]
        if (pct > 0) | (i in incl_sort_index_c):
            spy_cash = spy_cash*(1+pct)
        else:
            spy_cash = spy_cash*(1)
        
print("With scenario (c), $100 investment in SPY yields, ${}".format(round(spy_cash),2))
# Out:
# With scenario (c), $100 investment in SPY yields, $185

# %%
# find the 5 best days for DIS and remove them from the dataset
dis_pct_diff_idx = []
for i in range(len(dis_pct_diff_l)):
    dis_pct_diff_idx.append([dis_pct_diff_l[i],i])

dis_pct_diff_idx.sort()

sort_index = [] 
for x in dis_pct_diff_idx:
      sort_index.append(x[1])

# print(sort_index)

# remove the top ten from the list
excl_sort_index_c = sort_index[-5:]

# include the bottom five from the list
incl_sort_index_c = sort_index[5:]

# find the change in $100 invested in SPY with the worst five days included with the five best days removed
dis_cash = 100

for i in range(len(dis_pct_diff_l)):
    if i not in excl_sort_index_c:
        pct = dis_pct_diff_l[i]
        if (pct > 0) | (i in incl_sort_index_c):
            dis_cash = dis_cash*(1+pct)
        else:
            dis_cash = dis_cash*(1)
        
print("With scenario (c), $100 investment in DIS yields, ${}".format(round(dis_cash),2))
# Out:
# With scenario (c), $100 investment in DIS yields, $132

# %% [markdown]
# #### 6.2 Do you gain more by missing the worst days? Or the best days?
# - You gain more money by missing the 10 best days.

# %% [markdown]
# #### 6.3 are the results in part (c) di erent from results that you obtained in question 4?
# - Yes, question 4 results are significantly higher; we did not miss any good days with question 4 scenario so the stock value continuously compounds by an average increase in return of almost .2 percentage points each year.
