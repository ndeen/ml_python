# %%
import os

# %%
input_dir = os.path.abspath('')
ticker = 'DIS'
ticker_file = os.path.join(input_dir, ticker + '.csv')

# %%
try:
    with open(ticker_file) as f:
        lines = f.read().splitlines()
    print('opened file for ticker: ', ticker)
    print(lines[0])
except Exception as e:
    print(e)
    print('failed to read stock data for ticker: ', ticker)
# Out:
# opened file for ticker:  DIS
# Date,Year,Month,Day,Weekday,Week_Number,Year_Week,Open,High,Low,Close,Volume,Adj Close,Return,Short_MA,Long_MA

# %%
# each line represents a row of data
# the first line represents the columns
cols = lines[0].split(',')

# %%
cols
# Out:
# ['Date',
#  'Year',
#  'Month',
#  'Day',
#  'Weekday',
#  'Week_Number',
#  'Year_Week',
#  'Open',
#  'High',
#  'Low',
#  'Close',
#  'Volume',
#  'Adj Close',
#  'Return',
#  'Short_MA',
#  'Long_MA']

# %%
date_l = []
year_l = []
weekday_l = []
ac_l = []

for row in lines[1:]:
    date = row.split(',')[0]
    date_l.append(date)
    
    year = row.split(',')[1]
    year_l.append(year)
    
    weekday = row.split(',')[4]
    weekday_l.append(weekday)
    
    ac = float(row.split(',')[12])
    ac_l.append(ac)

# %%
ac_l
# Out:
# [97.16,
#  95.19,
#  94.68,
#  93.87,
#  93.64,
#  94.27,
#  95.72,
#  92.91,
#  93.5,
#  88.59,
#  88.66,
#  87.31,
#  88.7,
#  91.42,
#  89.9,
#  90.83,
#  88.99,
#  88.24,
#  90.4,
#  89.77,
#  87.85,
#  89.76,
#  90.03,
#  88.59,
#  86.91,
#  87.1,
#  83.82,
#  85.2,
#  85.99,
#  87.66,
#  90.1,
#  89.79,
#  89.64,
#  90.92,
#  89.99,
#  90.03,
#  90.24,
#  89.92,
#  90.12,
#  92.13,
#  91.51,
#  93.23,
#  92.91,
#  93.77,
#  92.29,
#  92.14,
#  91.55,
#  92.4,
#  93.22,
#  92.68,
#  92.87,
#  93.97,
#  93.59,
#  92.89,
#  92.06,
#  91.35,
#  91.72,
#  92.54,
#  92.61,
#  93.32,
#  93.69,
#  93.47,
#  93.1,
#  91.51,
#  91.97,
#  90.72,
#  90.97,
#  90.83,
#  91.84,
#  93.85,
#  93.05,
#  93.01,
#  95.74,
#  96.84,
#  97.43,
#  97.09,
#  97.9,
#  98.66,
#  98.96,
#  99.33,
#  98.15,
#  97.42,
#  98.46,
#  97.91,
#  97.81,
#  99.0,
#  99.57,
#  99.38,
#  100.57,
#  96.5,
#  95.96,
#  94.83,
#  94.68,
#  94.29,
#  93.4,
#  92.84,
#  94.14,
#  93.57,
#  93.88,
#  94.21,
#  94.17,
# ...

# %%
def daily_ret_pct_diff(l):
    '''
    calculates the daily return and pct diff between a value and its predecessor in a list.
    '''
    
    ret_l = [] # create an empty list to hold the results
    pct_diff_l = [] # create an empty list to hold the results
    i = 0 # identify starting point
    
    # loop through list
    for val in l[i:(len(l)-1)]: # iterater from the starting point to the last value in list
        print("current iteration:",i)
        
        if i == 0:
            ret = 0
            pct_diff = 0
        
        elif i == 1:
            ret = round(l[i] - l[0],2) # calculate diff b/w values
            pct_diff = round((ret / l[0]),2) # calcuate the pct diff
        
        else:
            ret = round((l[i+1] - l[i]),2) # calculate diff b/w values
            pct_diff = round((ret / l[i]),2) # calculate the pct diff
        
        ret_l.append(ret)
        pct_diff_l.append(pct_diff) # append results to container
        i+=1 # increment from starting point
        
        print("return:",ret)
        print("pct diff:", pct_diff)
        print("next iteration:",i)
        print("\n")
    return r_l , pct_diff_l # return the results

# %%
r_l, pct_diff_l = daily_ret_pct_diff(ac_l)
# Out:
# current iteration: 0
# return: 0
# pct diff: 0
# next iteration: 1
#
#
# current iteration: 1
# return: -1.97
# pct diff: -0.02
# next iteration: 2
#
#
# current iteration: 2
# return: -0.81
# pct diff: -0.01
# next iteration: 3
#
#
# current iteration: 3
# return: -0.23
# pct diff: -0.0
# next iteration: 4
#
#
# current iteration: 4
# return: 0.63
# pct diff: 0.01
# next iteration: 5
#
#
# current iteration: 5
# return: 1.45
# pct diff: 0.02
# next iteration: 6
#
#
# current iteration: 6
# return: -2.81
# pct diff: -0.03
# next iteration: 7
#
#
# current iteration: 7
# return: 0.59
# pct diff: 0.01
# next iteration: 8
#
#
# current iteration: 8
# return: -4.91
# pct diff: -0.05
# next iteration: 9
#
#
# current iteration: 9
# return: 0.07
# pct diff: 0.0
# next iteration: 10
#
#
# current iteration: 10
# return: -1.35
# pct diff: -0.02
# next iteration: 11
#
#
# current iteration: 11
# return: 1.39
# pct diff: 0.02
# next iteration: 12
#
#
# current iteration: 12
# return: 2.72
# ...

# %% [markdown]
# - split the dataset into years
# - for each year, calculate the mean and standard deviation for the sets R, R-, and R+
