# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ### 1. Exploratory Data Analysis

# %% [markdown]
# #### 1.1 Import data

# %%
heart_raw = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/00519/heart_failure_clinical_records_dataset.csv")
heart_df = heart_raw.copy()[["creatinine_phosphokinase","serum_creatinine", "serum_sodium","platelets", "DEATH_EVENT"]]
heart_df.head()
# Out:
#    creatinine_phosphokinase  serum_creatinine  serum_sodium  platelets  \
# 0                       582               1.9           130  265000.00
# 1                      7861               1.1           136  263358.03
# 2                       146               1.3           129  162000.00
# 3                       111               1.9           137  210000.00
# 4                       160               2.7           116  327000.00
#
#    DEATH_EVENT
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
df_0 = heart_df[heart_df["DEATH_EVENT"]==0][["creatinine_phosphokinase","serum_creatinine", "serum_sodium","platelets"]]
df_0.head()
# Out:
#     creatinine_phosphokinase  serum_creatinine  serum_sodium  platelets
# 14                        80               1.0           138   427000.0
# 20                        52               1.3           137   276000.0
# 23                        63               0.8           135   368000.0
# 33                       159               1.2           138   302000.0
# 38                      2656               2.3           137   305000.0

# %% [markdown]
# #### 1.2 - Create visual representations of correlation

# %%
M0 = df_0.corr()
M0.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_629ff_row0_col0, #T_629ff_row1_col1, #T_629ff_row2_col2, #T_629ff_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_629ff_row0_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_629ff_row0_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_629ff_row0_col3 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_629ff_row1_col0, #T_629ff_row1_col2, #T_629ff_row1_col3, #T_629ff_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_629ff_row2_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_629ff_row2_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_629ff_row3_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_629ff_row3_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_629ff_row3_col2 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_629ff_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >creatinine_phosphokinase</th>
#       <th class="col_heading level0 col1" >serum_creatinine</th>
#       <th class="col_heading level0 col2" >serum_sodium</th>
#       <th class="col_heading level0 col3" >platelets</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_629ff_level0_row0" class="row_heading level0 row0" >creatinine_phosphokinase</th>
#       <td id="T_629ff_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_629ff_row0_col1" class="data row0 col1" >-0.043110</td>
#       <td id="T_629ff_row0_col2" class="data row0 col2" >-0.002474</td>
#       <td id="T_629ff_row0_col3" class="data row0 col3" >-0.012940</td>
#     </tr>
#     <tr>
#       <th id="T_629ff_level0_row1" class="row_heading level0 row1" >serum_creatinine</th>
#       <td id="T_629ff_row1_col0" class="data row1 col0" >-0.043110</td>
#       <td id="T_629ff_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_629ff_row1_col2" class="data row1 col2" >-0.215651</td>
#       <td id="T_629ff_row1_col3" class="data row1 col3" >-0.031217</td>
#     </tr>
#     <tr>
#       <th id="T_629ff_level0_row2" class="row_heading level0 row2" >serum_sodium</th>
#       <td id="T_629ff_row2_col0" class="data row2 col0" >-0.002474</td>
#       <td id="T_629ff_row2_col1" class="data row2 col1" >-0.215651</td>
#       <td id="T_629ff_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_629ff_row2_col3" class="data row2 col3" >0.001807</td>
#     </tr>
#     <tr>
#       <th id="T_629ff_level0_row3" class="row_heading level0 row3" >platelets</th>
#       <td id="T_629ff_row3_col0" class="data row3 col0" >-0.012940</td>
#       <td id="T_629ff_row3_col1" class="data row3 col1" >-0.031217</td>
#       <td id="T_629ff_row3_col2" class="data row3 col2" >0.001807</td>
#       <td id="T_629ff_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.pairplot(df_0)

# %%
df_1 = heart_df[heart_df["DEATH_EVENT"]==1][["creatinine_phosphokinase","serum_creatinine", "serum_sodium","platelets"]]
df_1.head()
# Out:
#    creatinine_phosphokinase  serum_creatinine  serum_sodium  platelets
# 0                       582               1.9           130  265000.00
# 1                      7861               1.1           136  263358.03
# 2                       146               1.3           129  162000.00
# 3                       111               1.9           137  210000.00
# 4                       160               2.7           116  327000.00

# %%
M1 = df_1.corr()
M1.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_10a0d_row0_col0, #T_10a0d_row1_col1, #T_10a0d_row2_col2, #T_10a0d_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_10a0d_row0_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_10a0d_row0_col2 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_10a0d_row0_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_10a0d_row1_col0, #T_10a0d_row1_col2, #T_10a0d_row1_col3, #T_10a0d_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_10a0d_row2_col0 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_10a0d_row2_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_10a0d_row3_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_10a0d_row3_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_10a0d_row3_col2 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_10a0d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >creatinine_phosphokinase</th>
#       <th class="col_heading level0 col1" >serum_creatinine</th>
#       <th class="col_heading level0 col2" >serum_sodium</th>
#       <th class="col_heading level0 col3" >platelets</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10a0d_level0_row0" class="row_heading level0 row0" >creatinine_phosphokinase</th>
#       <td id="T_10a0d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_10a0d_row0_col1" class="data row0 col1" >-0.033407</td>
#       <td id="T_10a0d_row0_col2" class="data row0 col2" >0.148823</td>
#       <td id="T_10a0d_row0_col3" class="data row0 col3" >0.078808</td>
#     </tr>
#     <tr>
#       <th id="T_10a0d_level0_row1" class="row_heading level0 row1" >serum_creatinine</th>
#       <td id="T_10a0d_row1_col0" class="data row1 col0" >-0.033407</td>
#       <td id="T_10a0d_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_10a0d_row1_col2" class="data row1 col2" >-0.094011</td>
#       <td id="T_10a0d_row1_col3" class="data row1 col3" >-0.029384</td>
#     </tr>
#     <tr>
#       <th id="T_10a0d_level0_row2" class="row_heading level0 row2" >serum_sodium</th>
#       <td id="T_10a0d_row2_col0" class="data row2 col0" >0.148823</td>
#       <td id="T_10a0d_row2_col1" class="data row2 col1" >-0.094011</td>
#       <td id="T_10a0d_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_10a0d_row2_col3" class="data row2 col3" >0.141284</td>
#     </tr>
#     <tr>
#       <th id="T_10a0d_level0_row3" class="row_heading level0 row3" >platelets</th>
#       <td id="T_10a0d_row3_col0" class="data row3 col0" >0.078808</td>
#       <td id="T_10a0d_row3_col1" class="data row3 col1" >-0.029384</td>
#       <td id="T_10a0d_row3_col2" class="data row3 col2" >0.141284</td>
#       <td id="T_10a0d_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.pairplot(df_1)

# %% [markdown]
# #### 1.3 - Correlation observations

# %% [markdown]
# 3a. Which features have the highest correlation for surviving patients?
# - Serum sodium and platelets.
#
# 3b. Which features have the lowest correlation for surviving patients?
# - Serum sodium and serum creatinine
#
# 3c. Which features have the highest correlation for deceased patients?
# - Serum sodium and platelets.
#
# 3d. Which features have the lowest correlation for deceased patients?
# - Serum creatinine and creatinine phosphokinase
#
# 3e. Are results the same for both cases?
# - The results are the same for features with the highest correlation among deceased and surviving patients (serum sodium and platelets).

# %% [markdown]
# ### 2 - Building Linear Models
# (Group 2 - serum sodium and platelets)

# %% [markdown]
# #### 2.1 Simple Linear Regression

# %% [markdown]
# ##### Surviving Patients

# %% [markdown]
# ###### 2.1.a Fit the model

# %%
# visual inspection of the data
X = df_0[['platelets']].copy().to_numpy()
y = df_0[['serum_sodium']].copy().to_numpy()

plt.plot(X, y, "b.")
plt.xlabel("Predictor variable - Platelets")
plt.ylabel("Response Variable - Serum Sodium")
plt.title("Scatterplot of Data")
plt.show()

# %%
# split the data
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

# fit the model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# extract the model weights
coefs = model.coef_

# print the weights
print("weights:",coefs)
# Out:
# weights: [[1.09212711e-06]]

# %%
# create predictions
y_pred = model.predict(x_test)

# look at the first five predictions
y_pred[:5]
# Out:
# array([[136.89923723],
#        [136.91452701],
#        [137.20940133],
#        [137.03575312],
#        [136.8981451 ]])

# %%
plt.plot(y_test, y_pred, "b.")
plt.xlabel("Actual values")
plt.ylabel("Predicted values")
plt.title("Scatterplot of actual values v. predicted values")
plt.show()

# %%
SSE = sum((y_test-y_pred)**2)
print("Loss Function Estimation: ", round(SSE[0],3))
# Out:
# Loss Function Estimation:  1767.233

# %% [markdown]
# ##### Deceased Patients

# %%
# visual inspection of the data
X = df_1[['platelets']].copy().to_numpy()
y = df_1[['serum_sodium']].copy().to_numpy()

plt.plot(X, y, "b.")
plt.xlabel("Predictor variable - Platelets")
plt.ylabel("Response Variable - Serum Sodium")
plt.title("Scatterplot of Data")
plt.show()

# %%
# split the data
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

# fit the model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# extract the model weights
coefs = model.coef_

# print the weights
print("weights:",coefs)
# Out:
# weights: [[-4.89948451e-06]]

# %%
# create predictions
y_pred = model.predict(x_test)

# look at the first five predictions
y_pred[:5]
# Out:
# array([[135.45434161],
#        [134.85170501],
#        [135.44944212],
#        [135.84630037],
#        [135.72381325]])

# %%
plt.plot(y_test, y_pred, "b.")
plt.xlabel("Actual values")
plt.ylabel("Predicted values")
plt.title("Scatterplot of actual values v. predicted values")
plt.show()

# %%
SSE = sum((y_test-y_pred)**2)
print("Loss Function Estimation: ", round(SSE[0],3))
# Out:
# Loss Function Estimation:  1456.53

# %% [markdown]
# #### 2.2 Quadratic

# %% [markdown]
# ##### Surviving Patients

# %%
# visual inspection of the data
X = df_0[['platelets']].copy().to_numpy()
y = df_0[['serum_sodium']].copy().to_numpy()

plt.plot(X, y, "b.")
plt.xlabel("Predictor variable - Platelets")
plt.ylabel("Response Variable - Serum Sodium")
plt.title("Scatterplot of Data")
plt.show()

# %%
# split the data
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

# fit the model
model = LinearRegression()
poly = PolynomialFeatures(2)
X_new = poly.fit_transform(x_train)
model.fit(X_new, y_train)
# Out:
# LinearRegression()

# %%
# extract the model weights
coefs = model.coef_

# print the weights
print("weights:",coefs)
# Out:
# weights: [[ 0.00000000e+00 -2.24074583e-05  2.87115278e-11]]

# %%
# create predictions
x_test_new = poly.fit_transform(x_test)
y_pred = model.predict(x_test_new)

# look at the first five predictions
y_pred[:5]
# Out:
# array([[136.50620406],
#        [137.08577569],
#        [137.02760501],
#        [137.21055826],
#        [137.14676011]])

# %%
plt.plot(y_test, y_pred, "b.")
plt.xlabel("Actual values")
plt.ylabel("Predicted values")
plt.title("Scatterplot of actual values v. predicted values")
plt.show()

# %%
SSE = sum((y_test-y_pred)**2)
print("Loss Function Estimation: ", round(SSE[0],3))
# Out:
# Loss Function Estimation:  1339.437

# %% [markdown]
# ##### Deceased Patients

# %%
# visual inspection of the data
X = df_1[['platelets']].copy().to_numpy()
y = df_1[['serum_sodium']].copy().to_numpy()

plt.plot(X, y, "b.")
plt.xlabel("Predictor variable - Platelets")
plt.ylabel("Response Variable - Serum Sodium")
plt.title("Scatterplot of Data")
plt.show()

# %%
# split the data
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

# fit the model
model = LinearRegression()
poly = PolynomialFeatures(2)
X_new = poly.fit_transform(x_train)
model.fit(X_new, y_train)
# Out:
# LinearRegression()

# %%
# extract the model weights
coefs = model.coef_

# print the weights
print("weights:",coefs)
# Out:
# weights: [[ 0.00000000e+00  1.43130364e-05 -7.30591005e-12]]

# %%
# create predictions
x_test_new = poly.fit_transform(x_test)
y_pred = model.predict(x_test_new)

# look at the first five predictions
y_pred[:5]
# Out:
# array([[135.49112276],
#        [134.98278876],
#        [135.84083636],
#        [136.26085349],
#        [137.1361252 ]])

# %%
plt.plot(y_test, y_pred, "b.")
plt.xlabel("Actual values")
plt.ylabel("Predicted values")
plt.title("Scatterplot of actual values v. predicted values")
plt.show()

# %%
SSE = sum((y_test-y_pred)**2)
print("Loss Function Estimation: ", round(SSE[0],3))
# Out:
# Loss Function Estimation:  1488.859

# %% [markdown]
# #### 2.3 Cubic Spline

# %% [markdown]
# ##### Surviving Patients

# %%
# visual inspection of the data
X = df_0[['platelets']].copy().to_numpy()
y = df_0[['serum_sodium']].copy().to_numpy()

plt.plot(X, y, "b.")
plt.xlabel("Predictor variable - Platelets")
plt.ylabel("Response Variable - Serum Sodium")
plt.title("Scatterplot of Data")
plt.show()

# %%
# split the data
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

# fit the model
model = LinearRegression()
poly = PolynomialFeatures(3)
X_new = poly.fit_transform(x_train)
model.fit(X_new, y_train)
# Out:
# LinearRegression()

# %%
# extract the model weights
coefs = model.coef_

# print the weights
print("weights:",coefs)
# Out:
# weights: [[ 0.00000000e+00 -4.76005473e-05  1.26273080e-10 -9.34514510e-17]]

# %%
# create predictions
x_test_new = poly.fit_transform(x_test)
y_pred = model.predict(x_test_new)

# look at the first five predictions
y_pred[:5]
# Out:
# array([[136.99228217],
#        [138.15462688],
#        [137.04863588],
#        [137.85737606],
#        [137.40615701]])

# %%
plt.plot(y_test, y_pred, "b.")
plt.xlabel("Actual values")
plt.ylabel("Predicted values")
plt.title("Scatterplot of actual values v. predicted values")
plt.show()

# %%
SSE = sum((y_test-y_pred)**2)
print("Loss Function Estimation: ", round(SSE[0],3))
# Out:
# Loss Function Estimation:  1368.116

# %% [markdown]
# ##### Deceased Patients

# %%
# visual inspection of the data
X = df_1[['platelets']].copy().to_numpy()
y = df_1[['serum_sodium']].copy().to_numpy()

plt.plot(X, y, "b.")
plt.xlabel("Predictor variable - Platelets")
plt.ylabel("Response Variable - Serum Sodium")
plt.title("Scatterplot of Data")
plt.show()

# %%
# split the data
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

# fit the model
model = LinearRegression()
poly = PolynomialFeatures(3)
X_new = poly.fit_transform(x_train)
model.fit(X_new, y_train)
# Out:
# LinearRegression()

# %%
# extract the model weights
coefs = model.coef_

# print the weights
print("weights:",coefs)
# Out:
# weights: [[ 0.00000000e+00 -4.41707681e-05  1.75280951e-10 -1.95081852e-16]]

# %%
# create predictions
x_test_new = poly.fit_transform(x_test)
y_pred = model.predict(x_test_new)

# look at the first five predictions
y_pred[:5]
# Out:
# array([[135.90784047],
#        [135.93013314],
#        [135.98682227],
#        [134.77523761],
#        [134.76561654]])

# %% [markdown]
# ###### 2.3.d Plot (if possible) predicted and actual values of X test

# %%
plt.plot(y_test, y_pred, "b.")
plt.xlabel("Actual values")
plt.ylabel("Predicted values")
plt.title("Scatterplot of actual values v. predicted values")
plt.show()

# %%
SSE = sum((y_test-y_pred)**2)
print("Loss Function Estimation: ", round(SSE[0],3))
# Out:
# Loss Function Estimation:  1080.676

# %% [markdown]
# #### 2.4 Generalized Linear Model (Log X)

# %% [markdown]
# ##### Surviving Patients

# %%
# visual inspection of the data
X = df_0[['platelets']].copy().to_numpy()
y = df_0[['serum_sodium']].copy().to_numpy()

plt.plot(X, y, "b.")
plt.xlabel("Predictor variable - Platelets")
plt.ylabel("Response Variable - Serum Sodium")
plt.title("Scatterplot of Data")
plt.show()

# %%
# split the data
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

# fit the model
model = LinearRegression()
model.fit(np.log(x_train), y_train)
# Out:
# LinearRegression()

# %%
# extract the model weights
coefs = model.coef_

# print the weights
print("weights:",coefs)
# Out:
# weights: [[-0.62478179]]

# %%
# create predictions
y_pred = model.predict(np.log(x_test))

# look at the first five predictions
y_pred[:5]
# Out:
# array([[137.41512966],
#        [137.43773437],
#        [137.33791972],
#        [138.21675906],
#        [137.32341336]])

# %%
plt.plot(y_test, y_pred, "b.")
plt.xlabel("Actual values")
plt.ylabel("Predicted values")
plt.title("Scatterplot of actual values v. predicted values")
plt.show()

# %%
SSE = sum((y_test-y_pred)**2)
print("Loss Function Estimation: ", round(SSE[0],3))
# Out:
# Loss Function Estimation:  1420.211

# %% [markdown]
# ##### Deceased Patients

# %%
# visual inspection of the data
X = df_1[['platelets']].copy().to_numpy()
y = df_1[['serum_sodium']].copy().to_numpy()

plt.plot(X, y, "b.")
plt.xlabel("Predictor variable - Platelets")
plt.ylabel("Response Variable - Serum Sodium")
plt.title("Scatterplot of Data")
plt.show()

# %%
# split the data
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

# fit the model
model = LinearRegression()
model.fit(np.log(x_train), y_train)
# Out:
# LinearRegression()

# %%
# extract the model weights
coefs = model.coef_

# print the weights
print("weights:",coefs)
# Out:
# weights: [[2.53578273]]

# %%
# create predictions
y_pred = model.predict(np.log(x_test))

# look at the first five predictions
y_pred[:5]
# Out:
# array([[136.14163227],
#        [135.56420096],
#        [136.95825434],
#        [136.30576962],
#        [135.47556263]])

# %%
plt.plot(y_test, y_pred, "b.")
plt.xlabel("Actual values")
plt.ylabel("Predicted values")
plt.title("Scatterplot of actual values v. predicted values")
plt.show()

# %%
SSE = sum((y_test-y_pred)**2)
print("Loss Function Estimation: ", round(SSE[0],3))
# Out:
# Loss Function Estimation:  650.182

# %% [markdown]
# #### 2.4 Generalized Linear Model (Log Y)

# %% [markdown]
# ##### Surviving Patients

# %%
# visual inspection of the data
X = df_0[['platelets']].copy().to_numpy()
y = df_0[['serum_sodium']].copy().to_numpy()

plt.plot(X, y, "b.")
plt.xlabel("Predictor variable - Platelets")
plt.ylabel("Response Variable - Serum Sodium")
plt.title("Scatterplot of Data")
plt.show()

# %%
# split the data
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

# fit the model
model = LinearRegression()
model.fit(np.log(x_train), np.log(y_train))
# Out:
# LinearRegression()

# %%
# extract the model weights
coefs = model.coef_

# print the weights
print("weights:",coefs)
# Out:
# weights: [[0.00600607]]

# %%
# create predictions
y_pred = model.predict(np.log(x_test))

# look at the first five predictions
y_pred[:5]
# Out:
# array([[4.91340115],
#        [4.91602041],
#        [4.91567406],
#        [4.91494605],
#        [4.91359809]])

# %%
plt.plot(np.log(y_test), y_pred, "b.")
plt.xlabel("Actual values")
plt.ylabel("Predicted values")
plt.title("Scatterplot of actual values v. predicted values")
plt.show()

# %%
SSE = sum((np.log(y_test)-np.log(y_pred))**2)
print("Loss Function Estimation: ", round(SSE[0],3))
# Out:
# Loss Function Estimation:  1133.233

# %% [markdown]
# ##### Deceased Patients

# %%
# visual inspection of the data
X = df_1[['platelets']].copy().to_numpy()
y = df_1[['serum_sodium']].copy().to_numpy()

plt.plot(X, y, "b.")
plt.xlabel("Predictor variable - Platelets")
plt.ylabel("Response Variable - Serum Sodium")
plt.title("Scatterplot of Data")
plt.show()

# %%
# split the data
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

# fit the model
model = LinearRegression()
model.fit(np.log(x_train), np.log(y_train))
# Out:
# LinearRegression()

# %%
# extract the model weights
coefs = model.coef_

# print the weights
print("weights:",coefs)
# Out:
# weights: [[-0.00310494]]

# %%
# create predictions
y_pred = model.predict(np.log(x_test))

# look at the first five predictions
y_pred[:5]
# Out:
# array([[4.92240588],
#        [4.923399  ],
#        [4.92390362],
#        [4.92305995],
#        [4.92295468]])

# %%
plt.plot(np.log(y_test), y_pred, "b.")
plt.xlabel("Actual values")
plt.ylabel("Predicted values")
plt.title("Scatterplot of actual values v. predicted values")
plt.show()

# %%
SSE = sum((np.log(y_test)-np.log(y_pred))**2)
print("Loss Function Estimation: ", round(SSE[0],3))
# Out:
# Loss Function Estimation:  1127.599

# %% [markdown]
# ### 3 Model Comparison

# %% [markdown]
# #### 3.0 Summary Table

# %%
data = {'Model':['simple linear regression', 'quadratic','cubic spline','GLM-LogX','GLM-LogY'],
'SSE_DEATH_EVENT=0': [1767.233, 1339.437, 1368.116, 1420.211, 1133.233],
'SSE_DEATH_EVENT=1': [1456.53, 1488.59, 1080.676, 650.182, 1127.599]
}

summary_df = pd.DataFrame(data)
summary_df
# Out:
#                       Model  SSE_DEATH_EVENT=0  SSE_DEATH_EVENT=1
# 0  simple linear regression           1767.233           1456.530
# 1                 quadratic           1339.437           1488.590
# 2              cubic spline           1368.116           1080.676
# 3                  GLM-LogX           1420.211            650.182
# 4                  GLM-LogY           1133.233           1127.599

# %% [markdown]
# #### 3.1
# 1. Which was the best (smallest SSE) for surviving patients? Deceased patients?
# - Cubic spline was the best at predicting survival. GLM-LogX was the best at predicting death.

# %% [markdown]
# #### 3.2
# 1. Which was the worst (highest SSE) for surviving patients? Deceased patients?
# - Simple linear regression was the worst at predicting survival. Quadratic polynomial regression was the worst at predicting death.
